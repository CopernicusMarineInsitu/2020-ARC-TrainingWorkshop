# %% [markdown]
# ![header](https://i.imgur.com/I4ake6d.jpg)

# %% [markdown]
# # COPERNICUS MARINE IN SITU ARCTIC TRAINING (2/5)
# <div style="text-align: right"><i> 13-02-Part-two-out-of-five </i></div>

# %% [markdown]
# ***
# # ARC `NRT` Product/dataset Subsetting & Download

# %% [markdown]
# ***
# **General Note 1**: Execute each cell through the <button class="btn btn-default btn-xs"><i class="icon-play fa fa-play"></i></button> button from the top MENU (or keyboard shortcut `Shift` + `Enter`).<br>
# <br>
# **General Note 2**: If, for any reason, the kernel is not working anymore, in the top MENU, click on the <button class="btn btn-default btn-xs"><i class="fa fa-repeat icon-repeat"></i></button> button. Then, in the top MENU, click on "Cell" and select "Run All Above Selected Cell".<br>
# ***

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc">
#     <ul class="toc-item">
#         <li><span><a href="#1.-Introduction" data-toc-modified-id="1.-Introduction">1. Introduction</a></span></li>
#         <li>
#             <span><a href="#2.-Setup" data-toc-modified-id="2.-Setup">2. Setup</a></span>
#             <ul>
#                 <li><span><a href="#2.1.-Python-packages" data-toc-modified-id="2.1.-Python-packages">2.1. Python packages</a></span></li>
#                 <li><span><a href="#2.2.-Copernicus-Database" data-toc-modified-id="2.2.-Copernicus-Database">2.2. Copernicus database</a></span></li>
#                 <li><span><a href="#2.3.-Auxiliary-functions" data-toc-modified-id="2.3.-Setup">2.3. Auxiliary functions</a></span></li>
#             </ul>
#         </li>
#         <li><span><a href="#3.-Getting-started" data-toc-modified-id="3.-Getting-started">3. Getting started</a></span></li>
#         <li><span><a href="#4.-Operations" data-toc-modified-id="4.-Operations">4. Operations</a></span>
#         <ul>
#             <li>
#             <span><a href="#4.1.-Subsetting" data-toc-modified-id="4.1.-Subsetting">4.1. Subsetting</a></span>
#             <ul>
#                 <li><span><a href="#4.1.1.-By-collection" data-toc-modified-id="4.1.1.-By-collection">4.1.1. By collection</a></span></li>
#                 <li><span><a href="#4.1.2.-By-time-range" data-toc-modified-id="4.1.2.-By-time-range">4.1.2. By time range</a></span></li>
#                 <li><span><a href="#4.1.3.-By-bounding-box" data-toc-modified-id="4.1.3.-By-bounding-box">4.1.3. By bounding-box</a></span></li>
#                 <li><span><a href="#4.1.4.-By-last-position" data-toc-modified-id="4.1.4.-By-last-position">4.1.4. By last position</a></span></li>
#                 <li><span><a href="#4.1.5.-By-data-type" data-toc-modified-id="4.1.5.-By-data-type">4.1.5. By data type</a></span></li>
#                 <li><span><a href="#4.1.6.-By-file-type" data-toc-modified-id="4.1.6.-By-file-type">4.1.6. By file type</a></span></li>
#                 <li><span><a href="#4.1.7.-By-parameter" data-toc-modified-id="4.1.7.-By-parameter">4.1.7. By parameter</a></span></li>
#                 <li><span><a href="#4.1.8.-By-platform-code" data-toc-modified-id="4.1.8.-By-platform-code">4.1.8. By platform code</a></span></li>
#                 <li><span><a href="#4.1.9.-By-provider" data-toc-modified-id="4.1.9.-By-provider">4.1.9. By provider</a></span></li>
#                 <li><span><a href="#4.1.10.-By-several-criterias-at-once" data-toc-modified-id="4.1.10.By-several-criterias-at-once">4.1.10. By several criterias at once</a></span></li>
#             </ul>
#             </li>
#             <li><span><a href="#4.2.-Exporting" data-toc-modified-id="4.2.-Exporting">4.2. Exporting</a></span></li>
#             <li><span><a href="#4.3.-Downloading" data-toc-modified-id="4.3.-Downloading">4.3. Downloading</a></span></li>
#         </ul>
#         </li>
#         <li><span><a href="#5.-Wrap-up" data-toc-modified-id="5.-Wrap-up">5. Wrap-up</a></span></li>
#         <li><span><a href="#6.-Next-Tutorial" data-toc-modified-id="6.-Next-Tutorial">6. Next tutorial</a></span></li>
#     </ul>
# </div>

# %% [markdown]
# ***

# %% [markdown]
# ## 1. Introduction
# [Go back to the "Table of Contents"](#Table-of-Contents)
#
# This notebook focuses on getting an overview of the files available in the different collections (`latest`, `monthly` and `history`) available within the In Situ Near Real Time product/dataset covering the Arctic Regional Seas: `INSITU_ARC_NRT_OBSERVATIONS_013_031`. Click [here](https://resources.marine.copernicus.eu/?option=com_csw&task=results?option=com_csw&view=details&product_id=INSITU_ARC_NRT_OBSERVATIONS_013_031) to  view the dedicated section of this product within the [CMEMS Catalog](http://marine.copernicus.eu/services-portfolio/access-to-products/).

# %% [markdown]
# Any In Situ NRT product/dataset is just a bunch of netcdf files produced by the platforms (*drifters, profilers, gliders, moorings, HF-radars, vessels etc*) deployed in certain seas (in this case, the Arctic Regional Seas); so many files that navigation/subsetting can be challenging.

# %% [markdown]
# | ![ARCLatest.png](img/ARCLatest.png)|
# |:--:|
# | *Last location (point or trajectory) of the platforms providing near real time data in the ARC area (last 30 days)* |

# %% [markdown]
# To smooth the process of data discovery to users, the In Situ TAC provides a set of `index files` that describes the aforementioned netCDF collections. In addition to these index files, it is also possible to find further info regarding each platform contributing with files on the `index_platform.txt`.

# %% [markdown]
# | Index |  Description |
# | ------- | ----------- |
# | `index_latest.txt`  |  List of available files within the latest collection + metadata |
# | `index_monthly.txt`   | List of available files within the monthly collection + metadata |
# | `index_history.txt`   |  List of available files within the history collection + metadata |
# | `index_platform.txt`   | Full list of platforms + metadata |

# %% [markdown]
# Check more about these files in the <a href="https://archimer.ifremer.fr/doc/00324/43494/" target="_blank">Product User Manual</a>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>OBJECTIVE</b>
#
# ***
# To select and download only those netCDFs matching our needs from the whole original set of files that composes the ARC NRT product/dataset by using the aforementioned index files.

# %% [markdown]
# ## 2. Setup
# [Go back to the "Table of Contents"](#Table-of-Contents)

# %% [markdown]
# ### 2.1. Python packages

# %% [markdown]
# For the notebook to properly run we need to first load the next packages available from the Jupyter Notebook Ecosystem. Please run the `next cell`:

# %%
import warnings
warnings.filterwarnings("ignore")

import IPython
import pandas as pd
import datetime
import random
import os
from collections import namedtuple
import ftputil
from shapely.geometry import box, Point
from urllib.parse import urlparse
import folium
from folium import plugins

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>WARNING</b>
#
# ***
# If any of them raises any error it means you need to install the module first. For doing so please:
# 1. Open a new cell in the notebook
# 2. Run <i>`!conda install packageName --yes`</i> or <i>`!conda install -c conda-forge packageName --yes`</i> or <i>`!pip install packageName`</i>
# 3. Import again!
# <br><br>
# Example: <i>how-to-solve import error for json2html module </i>
#
# ![errorImporting.gif](img/errorImporting.gif)

# %% [markdown]
# ### 2.2. Copernicus Database

# %% [markdown]
# Please `set next your CMEMS User credentials` in the next cell and `run the cell` afterwards:

# %%
usr = 'inputHereYourCMEMSUser'
pas = 'inputHereYourCMEMSPassword'

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>WARNING</b>
#
# ***
# **Don't you have credentials yet?** <br>Please go [here](https://resources.marine.copernicus.eu/?option=com_sla) to get the above credentials to be able to access CMEMS secured FTP server.

# %% [markdown]
# As stated before, we will focus on the Near Real Time product/dataset covering the Arctic regional seas so, please `run the next` to load the info defining such product/dataset:

# %%
dataset = {
    'host': 'nrt.cmems-du.eu',#ftp host => nrt.cmems-du.eu for Near Real Time products
    'product': 'INSITU_ARC_NRT_OBSERVATIONS_013_031',#name of the In Situ Near Real Time product in the ARC area
    'name': 'arc_multiparameter_nrt',#name of the dataset available in the above In Situ Near Real Time product
    'index_files': ['index_latest.txt', 'index_monthly.txt', 'index_history.txt'],#files describing the content of the lastest, monthly and history netCDF file collections available withint he above dataset
    'index_platform': 'index_platform.txt',#files describing the netwotk of platforms contributting with files in the abve collections
}

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>TIP</b>
#
# ***
# In case you want to explore any other In Situ NRT product/dataset just set the above definitions accordingly and you will be able to reproduce the subsetting and downloading we will perform next.

# %% [markdown]
# ### 2.3. Auxiliary functions

# %% [markdown]
# For exploring the product/dataset we will use a set of files called `index files` located in the CMEMS FTP server.

# %% [markdown]
# 1. **Download the index files**.
# In order to download the most updated version of these files we will use the next function. <br>Please `run the next cell` to load it (the function) in memory for later use:

# %%
def getIndexFiles(usr,pas,dataset,path2indexes):
    #Provides the index files available at the ftp server
    indexes = dataset['index_files'] + [dataset['index_platform']]
    with ftputil.FTPHost(dataset['host'], usr, pas) as ftp_host:  # connect to CMEMS FTP
        for index in indexes:
            remotefile= "/".join(['Core',dataset['product'],dataset['name'],index])
            print('.....Downloading ' + index)
            localfile = os.path.join(path2indexes,index)
            ftp_host.download(remotefile,localfile)  # remote, local
    print('Ready!')

# %% [markdown]
# 2. **Index files reader**.
# In order to load the information contained in *each* of the files we will use the next function. <br>Please `run the next cell` to load it in memory for later use:

# %%
def readIndexFileFromCWD(path2file):
    #Load as pandas dataframe the file in the provided path
    with open(path2file, 'rb') as f:
        filename = os.path.basename(path2file)
        print('...Loading info from: '+filename)
        raw_index_info = pd.read_csv(path2file, skiprows=5)
    return raw_index_info

# %% [markdown]
# 3. **Index files merger**.
# In order to load the information contained in *all* the indexes in a one single entity we will use the next function. <br>Please `run the next cell` to load it in memory for later use:

# %%
def getIndexFilesInfo(usr, pas, dataset,path2indexes):
    # Load and merge in a single entity all the information contained on each file descriptor of a given dataset
    # 1) Loading the index platform info as dataframe
    path2file = os.path.join(path2indexes, dataset['index_platform'])
    indexPlatform = readIndexFileFromCWD(path2file)
    indexPlatform.rename(columns={indexPlatform.columns[0]: "platform_code" }, inplace = True)
    indexPlatform = indexPlatform.drop_duplicates(subset='platform_code', keep="first")
    # 2) Loading the index files info as dataframes
    netcdf_collections = []
    for filename in dataset['index_files']:
        path2file = os.path.join(path2indexes,filename)
        indexFile = readIndexFileFromCWD(path2file)
        netcdf_collections.append(indexFile)
    netcdf_collections = pd.concat(netcdf_collections)
    # 3) creating new columns: derived info
    netcdf_collections['netcdf'] = netcdf_collections['file_name'].str.split('/').str[-1]
    netcdf_collections['file_type'] = netcdf_collections['netcdf'].str.split('.').str[0].str.split('_').str[1]
    netcdf_collections['data_type'] = netcdf_collections['netcdf'].str.split('.').str[0].str.split('_').str[2]
    netcdf_collections['platform_code'] = netcdf_collections['netcdf'].str.split('.').str[0].str.split('_').str[3]
    # 4) Merging the information of all files
    headers = ['platform_code','wmo_platform_code', 'institution_edmo_code', 'last_latitude_observation', 'last_longitude_observation','last_date_observation']
    result = pd.merge(netcdf_collections,indexPlatform[headers],on='platform_code')
    print('Ready!')
    return result

# %% [markdown]
# Also, let's load also the next functions as they are to be used later in the subsetting processing: `run the next cells`

# %% [markdown]
# <ul><li id="TemporalOverlap"><i>Time-Overlap</i> function definition</li></ul>

# %%
def timeOverlap(row, targeted_range):
    # Checks if a file contains data in the specified time range (targeted_range)
    result = False
    try:
        date_format = "%Y-%m-%dT%H:%M:%SZ"
        targeted_ini = datetime.datetime.strptime(targeted_range.split('/')[0], date_format)
        targeted_end = datetime.datetime.strptime(targeted_range.split('/')[1], date_format)
        time_start = datetime.datetime.strptime(row['time_coverage_start'],date_format)
        time_end = datetime.datetime.strptime(row['time_coverage_end'],date_format)
        Range = namedtuple('Range', ['start', 'end'])
        r1 = Range(start=targeted_ini, end=targeted_end)
        r2 = Range(start=time_start, end=time_end)
        latest_start = max(r1.start, r2.start)
        earliest_end = min(r1.end, r2.end)
        delta = (earliest_end - latest_start).days + 1
        overlap = max(0, delta)
        if overlap != 0:
            result = True
    except Exception as e:
        pass
    return result

# %% [markdown]
# <ul><li id="SpatialOverlap"><i>Spatial-Overlap</i> function definition</li></ul>

# %%
def spatialOverlap(row, targeted_bbox):
    # Checks if a file contains data in the specified area (targeted_bbox)
    result = False
    try:
        geospatial_lat_min = float(row['geospatial_lat_min'])
        geospatial_lat_max = float(row['geospatial_lat_max'])
        geospatial_lon_min = float(row['geospatial_lon_min'])
        geospatial_lon_max = float(row['geospatial_lon_max'])
        targeted_bounding_box = box(targeted_bbox[0], targeted_bbox[1],targeted_bbox[2], targeted_bbox[3])
        bounding_box = box(geospatial_lon_min, geospatial_lat_min,geospatial_lon_max, geospatial_lat_max)
        if targeted_bounding_box.intersects(bounding_box):  # check other rules on https://shapely.readthedocs.io/en/stable/manual.html
            result = True
    except Eception as e:
        pass
    return result

# %% [markdown]
# <ul><li id="LocationInRange"><i>LocationInRange</i> function definition</li></ul>

# %%
def lastLocationInRange(row, targeted_bbox):
    # Checks if a file has been produced by a platform whose last position is within the specified area (targeted_bbox)
    result = False
    try:
        geospatial_lat = float(row['last_latitude_observation'])
        geospatial_lon = float(row['last_longitude_observation'])
        targeted_bounding_box = box(targeted_bbox[0], targeted_bbox[1],targeted_bbox[2], targeted_bbox[3])
        location = Point(geospatial_lon, geospatial_lat)
        if targeted_bounding_box.contains(location):#check other rules on https://shapely.readthedocs.io/en/stable/manual.html
            result = True
    except Exception as e:
        pass
    return result

# %% [markdown]
# ## 3. Getting started
# [Go back to the "Table of Contents"](#Table-of-Contents)

# %% [markdown]
# For the analysis to be carried out we need the most recent version of the index files. By default we will save them into the `index_files` folder available in the `data` folder. Nevertheless if you rather use a different one set it next:

# %%
path2indexes= os.path.join(os.getcwd(),'data','index_files')#default path to save the files

# %% [markdown]
# Although in such folder we have provided already a copy of the files, **if you are running this notebook later than October 2020** please `Run the next` cell and download again the index files:

# %%
getIndexFiles(usr,pas,dataset,path2indexes)
# Out:
# .....Downloading index_latest.txt
# .....Downloading index_monthly.txt
# .....Downloading index_history.txt
# .....Downloading index_platform.txt
# Ready!

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>WARNING</b>
#
# ***
# **Are you getting a `permission denied` error?**
# <br>Please be aware that no `writes` are authorized in the 'shared_notebook' folder. Make sure you run this on you own space after copying the notebooks form shared_notebooks. If you are still facing a problem contact us trough [Mattermost](https://chat-cmems.mercator-ocean.fr/).

# %% [markdown]
# Let's load now the info contained in such files by `running the next cell!`:

# %%
info = getIndexFilesInfo(usr, pas, dataset,path2indexes)
# Out:
# ...Loading info from: index_platform.txt
# ...Loading info from: index_latest.txt
# ...Loading info from: index_monthly.txt
# ...Loading info from: index_history.txt
# Ready!

# %% [markdown]
# `Run now the next cell` to see the information just loaded above:

# %%
info.transpose()
# Out:
#                                                                         0      \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                     57.001
# geospatial_lat_max                                                     57.001
# geospatial_lon_min                                                      4.696
# geospatial_lon_max                                                      4.696
# time_coverage_start                                      2021-01-13T02:13:09Z
# time_coverage_end                                        2021-01-13T02:13:09Z
# institution                             Institute of Marine Research (Norway)
# date_update                                              2021-01-13T23:15:07Z
# data_mode                                                                   R
# parameters                                        SIGMA_T PRES CNDC PSAL TEMP
# netcdf                                              AR_PR_CT_58JH_20210113.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                            58JH
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                    1351
# last_latitude_observation                                              57.001
# last_longitude_observation                                              4.696
# last_date_observation                                    2021-01-13T02:13:09Z
#
#                                                                         1      \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                     57.000
# geospatial_lat_max                                                     57.000
# geospatial_lon_min                                                      7.949
# geospatial_lon_max                                                      7.949
# time_coverage_start                                      2021-01-14T18:55:20Z
# time_coverage_end                                        2021-01-14T18:55:20Z
# institution                             Institute of Marine Research (Norway)
# date_update                                              2021-01-15T20:15:08Z
# data_mode                                                                   R
# parameters                                        SIGMA_T PRES CNDC PSAL TEMP
# netcdf                                              AR_PR_CT_58JH_20210114.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                            58JH
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                    1351
# last_latitude_observation                                              57.001
# last_longitude_observation                                              4.696
# last_date_observation                                    2021-01-13T02:13:09Z
#
#                                                                         2      \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                     63.308
# geospatial_lat_max                                                     63.308
# geospatial_lon_min                                                      3.130
# geospatial_lon_max                                                      3.130
# time_coverage_start                                      2021-01-18T22:00:29Z
# time_coverage_end                                        2021-01-18T22:00:29Z
# institution                             Institute of Marine Research (Norway)
# date_update                                              2021-01-19T23:15:16Z
# data_mode                                                                   R
# parameters                                        SIGMA_T PRES CNDC PSAL TEMP
# netcdf                                              AR_PR_CT_58JH_20210118.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                            58JH
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                    1351
# last_latitude_observation                                              57.001
# last_longitude_observation                                              4.696
# last_date_observation                                    2021-01-13T02:13:09Z
#
#                                                                         3      \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                     63.427
# geospatial_lat_max                                                     64.667
# geospatial_lon_min                                                      0.002
# geospatial_lon_max                                                      2.866
# time_coverage_start                                      2021-01-19T00:11:14Z
# time_coverage_end                                        2021-01-19T20:59:19Z
# institution                             Institute of Marine Research (Norway)
# date_update                                              2021-01-20T23:15:15Z
# data_mode                                                                   R
# parameters                                        SIGMA_T PRES CNDC PSAL TEMP
# netcdf                                              AR_PR_CT_58JH_20210119.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                            58JH
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                    1351
# last_latitude_observation                                              57.001
# last_longitude_observation                                              4.696
# last_date_observation                                    2021-01-13T02:13:09Z
#
#                                                                         4      \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                     66.005
# geospatial_lat_max                                                     66.005
# geospatial_lon_min                                                      1.998
# geospatial_lon_max                                                      1.998
# time_coverage_start                                      2021-01-20T12:02:10Z
# time_coverage_end                                        2021-01-20T12:02:10Z
# institution                             Institute of Marine Research (Norway)
# date_update                                              2021-01-21T23:15:14Z
# data_mode                                                                   R
# parameters                                        SIGMA_T PRES CNDC PSAL TEMP
# netcdf                                              AR_PR_CT_58JH_20210120.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                            58JH
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                    1351
# last_latitude_observation                                              57.001
# last_longitude_observation                                              4.696
# last_date_observation                                    2021-01-13T02:13:09Z
#
#                                                                         5      \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                     68.912
# geospatial_lat_max                                                     68.912
# geospatial_lon_min                                                     14.405
# geospatial_lon_max                                                     14.405
# time_coverage_start                                      2021-01-22T15:38:07Z
# time_coverage_end                                        2021-01-22T15:38:07Z
# institution                             Institute of Marine Research (Norway)
# date_update                                              2021-01-23T23:15:15Z
# data_mode                                                                   R
# parameters                                        SIGMA_T PRES CNDC PSAL TEMP
# netcdf                                              AR_PR_CT_58JH_20210122.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                            58JH
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                    1351
# last_latitude_observation                                              57.001
# last_longitude_observation                                              4.696
# last_date_observation                                    2021-01-13T02:13:09Z
#
#                                                                         6      \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                     70.666
# geospatial_lat_max                                                     71.501
# geospatial_lon_min                                                     19.791
# geospatial_lon_max                                                     19.962
# time_coverage_start                                      2021-01-24T02:27:03Z
# time_coverage_end                                        2021-01-24T14:54:57Z
# institution                             Institute of Marine Research (Norway)
# date_update                                              2021-01-25T23:15:16Z
# data_mode                                                                   R
# parameters                                        SIGMA_T PRES CNDC PSAL TEMP
# netcdf                                              AR_PR_CT_58JH_20210124.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                            58JH
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                    1351
# last_latitude_observation                                              57.001
# last_longitude_observation                                              4.696
# last_date_observation                                    2021-01-13T02:13:09Z
#
#                                                                         7      \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                     71.529
# geospatial_lat_max                                                     71.529
# geospatial_lon_min                                                     21.804
# geospatial_lon_max                                                     21.804
# time_coverage_start                                      2021-01-28T08:05:31Z
# time_coverage_end                                        2021-01-28T08:05:31Z
# institution                             Institute of Marine Research (Norway)
# date_update                                              2021-01-29T23:15:15Z
# data_mode                                                                   R
# parameters                                        SIGMA_T PRES CNDC PSAL TEMP
# netcdf                                              AR_PR_CT_58JH_20210128.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                            58JH
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                    1351
# last_latitude_observation                                              57.001
# last_longitude_observation                                              4.696
# last_date_observation                                    2021-01-13T02:13:09Z
#
#                                                                         8      \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                     71.222
# geospatial_lat_max                                                     71.222
# geospatial_lon_min                                                     25.250
# geospatial_lon_max                                                     25.250
# time_coverage_start                                      2021-01-31T23:48:59Z
# time_coverage_end                                        2021-01-31T23:48:59Z
# institution                             Institute of Marine Research (Norway)
# date_update                                              2021-02-01T20:15:09Z
# data_mode                                                                   R
# parameters                                        SIGMA_T PRES CNDC PSAL TEMP
# netcdf                                              AR_PR_CT_58JH_20210131.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                            58JH
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                    1351
# last_latitude_observation                                              57.001
# last_longitude_observation                                              4.696
# last_date_observation                                    2021-01-13T02:13:09Z
#
#                                                                         9      \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                     71.124
# geospatial_lat_max                                                     71.124
# geospatial_lon_min                                                     23.697
# geospatial_lon_max                                                     23.697
# time_coverage_start                                      2021-02-01T20:35:48Z
# time_coverage_end                                        2021-02-01T20:35:48Z
# institution                             Institute of Marine Research (Norway)
# date_update                                              2021-02-03T01:15:15Z
# data_mode                                                                   R
# parameters                                        SIGMA_T PRES CNDC PSAL TEMP
# netcdf                                              AR_PR_CT_58JH_20210201.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                            58JH
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                    1351
# last_latitude_observation                                              57.001
# last_longitude_observation                                              4.696
# last_date_observation                                    2021-01-13T02:13:09Z
#
#                             ...  \
# # product_id                ...
# file_name                   ...
# geospatial_lat_min          ...
# geospatial_lat_max          ...
# geospatial_lon_min          ...
# geospatial_lon_max          ...
# time_coverage_start         ...
# time_coverage_end           ...
# institution                 ...
# date_update                 ...
# data_mode                   ...
# parameters                  ...
# netcdf                      ...
# file_type                   ...
# data_type                   ...
# platform_code               ...
# wmo_platform_code           ...
# institution_edmo_code       ...
# last_latitude_observation   ...
# last_longitude_observation  ...
# last_date_observation       ...
#
#                                                                         34348  \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                      62.13
# geospatial_lat_max                                                      62.13
# geospatial_lon_min                                                      17.86
# geospatial_lon_max                                                      17.86
# time_coverage_start                                      1996-10-25T10:00:00Z
# time_coverage_end                                        1997-09-27T15:45:00Z
# institution                                                  Sweden (Unknown)
# date_update                                              2019-10-06T06:52:45Z
# data_mode                                                                   R
# parameters                                   DC_REFERENCE PRES DATA_MODE TEMP
# netcdf                                                       GL_PR_XX_SKVP.nc
# file_type                                                                  PR
# data_type                                                                  XX
# platform_code                                                            SKVP
# wmo_platform_code                                                        SKVP
# institution_edmo_code
# last_latitude_observation                                               62.13
# last_longitude_observation                                              17.86
# last_date_observation                                    1997-09-27T15:45:00Z
#
#                                                                         34349  \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                      55.00
# geospatial_lat_max                                                      62.13
# geospatial_lon_min                                                      11.66
# geospatial_lon_max                                                      17.86
# time_coverage_start                                      1996-06-02T18:20:00Z
# time_coverage_end                                        1999-09-07T12:45:00Z
# institution                                                  Sweden (Unknown)
# date_update                                              2019-10-06T06:52:44Z
# data_mode                                                                   R
# parameters                                   DC_REFERENCE PRES DATA_MODE TEMP
# netcdf                                                       GL_PR_XX_SMZT.nc
# file_type                                                                  PR
# data_type                                                                  XX
# platform_code                                                            SMZT
# wmo_platform_code                                                        SMZT
# institution_edmo_code
# last_latitude_observation                                               57.18
# last_longitude_observation                                              11.66
# last_date_observation                                    1999-09-07T12:45:00Z
#
#                                                                         34350  \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                      61.33
# geospatial_lat_max                                                      63.23
# geospatial_lon_min                                                     -19.28
# geospatial_lon_max                                                     -11.70
# time_coverage_start                                      1996-01-06T16:22:00Z
# time_coverage_end                                        1996-05-05T16:01:00Z
# institution                                                 Iceland (Unknown)
# date_update                                              2019-10-06T07:14:05Z
# data_mode                                                                   R
# parameters                                   DC_REFERENCE PRES DATA_MODE TEMP
# netcdf                                                       GL_PR_XX_TFVD.nc
# file_type                                                                  PR
# data_type                                                                  XX
# platform_code                                                            TFVD
# wmo_platform_code                                                        TFVD
# institution_edmo_code
# last_latitude_observation                                               62.25
# last_longitude_observation                                             -15.46
# last_date_observation                                    1996-05-05T16:01:00Z
#
#                                                                         34351  \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                     57.698
# geospatial_lat_max                                                     66.232
# geospatial_lon_min                                                    -69.927
# geospatial_lon_max                                                    -57.756
# time_coverage_start                                      2015-08-19T04:26:00Z
# time_coverage_end                                        2015-09-21T07:20:00Z
# institution                                               Unknown institution
# date_update                                              2019-10-06T07:59:28Z
# data_mode                                                                   R
# parameters                              PSAL DC_REFERENCE DEPH DATA_MODE TEMP
# netcdf                                                       GL_PR_XX_VAAI.nc
# file_type                                                                  PR
# data_type                                                                  XX
# platform_code                                                            VAAI
# wmo_platform_code                                                        VAAI
# institution_edmo_code
# last_latitude_observation                                              61.763
# last_longitude_observation                                            -60.956
# last_date_observation                                    2015-09-21T07:20:00Z
#
#                                                                         34352  \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                     42.920
# geospatial_lat_max                                                     60.970
# geospatial_lon_min                                                    -64.030
# geospatial_lon_max                                                    -45.230
# time_coverage_start                                      1997-03-02T00:30:00Z
# time_coverage_end                                        2004-06-17T13:00:00Z
# institution                                                  Canada (Unknown)
# date_update                                              2019-10-06T07:59:28Z
# data_mode                                                                   R
# parameters                         PSAL DC_REFERENCE PRES DEPH DATA_MODE TEMP
# netcdf                                                     GL_PR_XX_VC4959.nc
# file_type                                                                  PR
# data_type                                                                  XX
# platform_code                                                          VC4959
# wmo_platform_code                                                      VC4959
# institution_edmo_code
# last_latitude_observation                                              46.250
# last_longitude_observation                                            -51.666
# last_date_observation                                    2004-06-17T13:00:00Z
#
#                                                                         34353  \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                    -38.130
# geospatial_lat_max                                                     90.000
# geospatial_lon_min                                                   -174.100
# geospatial_lon_max                                                    153.950
# time_coverage_start                                      1985-05-04T23:00:00Z
# time_coverage_end                                        2007-12-06T11:45:00Z
# institution                                               Australia (Unknown)
# date_update                                              2019-10-06T08:04:24Z
# data_mode                                                                   R
# parameters                              DC_REFERENCE PRES DEPH DATA_MODE TEMP
# netcdf                                                       GL_PR_XX_VKLA.nc
# file_type                                                                  PR
# data_type                                                                  XX
# platform_code                                                            VKLA
# wmo_platform_code                                                        VKLA
# institution_edmo_code
# last_latitude_observation                                             -33.350
# last_longitude_observation                                            114.883
# last_date_observation                                    2007-12-06T11:45:00Z
#
#                                                                         34354  \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                    -45.233
# geospatial_lat_max                                                     62.041
# geospatial_lon_min                                                   -178.988
# geospatial_lon_max                                                    180.000
# time_coverage_start                                      2001-06-21T12:30:00Z
# time_coverage_end                                        2016-07-25T22:00:00Z
# institution                                               Australia (Unknown)
# date_update                                              2019-10-06T08:05:25Z
# data_mode                                                                   R
# parameters                                   DC_REFERENCE DEPH DATA_MODE TEMP
# netcdf                                                       GL_PR_XX_VKLD.nc
# file_type                                                                  PR
# data_type                                                                  XX
# platform_code                                                            VKLD
# wmo_platform_code                                                        VKLD
# institution_edmo_code
# last_latitude_observation                                              19.667
# last_longitude_observation                                           -157.667
# last_date_observation                                    2016-07-25T22:00:00Z
#
#                                                                         34355  \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                     49.003
# geospatial_lat_max                                                     66.232
# geospatial_lon_min                                                    -69.967
# geospatial_lon_max                                                    -49.985
# time_coverage_start                                      2012-07-20T12:01:00Z
# time_coverage_end                                        2014-09-24T07:19:00Z
# institution                                               Unknown institution
# date_update                                              2019-10-06T08:07:25Z
# data_mode                                                                   R
# parameters                              PSAL DC_REFERENCE DEPH DATA_MODE TEMP
# netcdf                                                       GL_PR_XX_VOLZ.nc
# file_type                                                                  PR
# data_type                                                                  XX
# platform_code                                                            VOLZ
# wmo_platform_code                                                        VOLZ
# institution_edmo_code
# last_latitude_observation                                              62.558
# last_longitude_observation                                            -63.009
# last_date_observation                                    2014-09-24T07:19:00Z
#
#                                                                         34356  \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                     57.717
# geospatial_lat_max                                                     65.025
# geospatial_lon_min                                                    -12.979
# geospatial_lon_max                                                      8.983
# time_coverage_start                                      2013-09-21T15:14:00Z
# time_coverage_end                                        2013-10-25T05:34:00Z
# institution                                               Unknown institution
# date_update                                              2019-10-06T08:07:25Z
# data_mode                                                                   R
# parameters                                   DC_REFERENCE DEPH DATA_MODE TEMP
# netcdf                                                    GL_PR_XX_VOZ2040.nc
# file_type                                                                  PR
# data_type                                                                  XX
# platform_code                                                         VOZ2040
# wmo_platform_code                                                     VOZ2040
# institution_edmo_code
# last_latitude_observation                                              60.987
# last_longitude_observation                                             -1.430
# last_date_observation                                    2013-10-25T05:34:00Z
#
#                                                                         34357
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                      45.40
# geospatial_lat_max                                                      62.63
# geospatial_lon_min                                                     -46.17
# geospatial_lon_max                                                     -25.33
# time_coverage_start                                      1997-03-17T13:23:00Z
# time_coverage_end                                        1997-03-23T13:17:00Z
# institution                                           United states (Unknown)
# date_update                                              2019-10-06T08:13:16Z
# data_mode                                                                   R
# parameters                                   DC_REFERENCE PRES DATA_MODE TEMP
# netcdf                                                    GL_PR_XX_WBD9290.nc
# file_type                                                                  PR
# data_type                                                                  XX
# platform_code                                                         WBD9290
# wmo_platform_code                                                     WBD9290
# institution_edmo_code
# last_latitude_observation                                               62.63
# last_longitude_observation                                             -25.33
# last_date_observation                                    1997-03-23T13:17:00Z
#
# [21 rows x 34358 columns]

# %% [markdown]
# One of the most important fields in the above info is the `file_name`. This field contains the full path to the file in the FTP server, saving users from having to know the actual FTP structure. As the above preview does not render such field completely, let's see the first file full path: `Run the next cell`

# %%
info['file_name'].tolist()[0]
# Out:
# 'ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSERVATIONS_013_031/arc_multiparameter_nrt/latest/20210113/AR_PR_CT_58JH_20210113.nc'

# %% [markdown]
# Copy the path into the browser....the file will download straightaway!<br>
# Next we will aim:
# <ul><li>the `file_name` field (file path) for downloading operations</li>
#     <li> the other fileds (file metadata) for the subsetting operations</li>
# </ul>

# %% [markdown]
# ## 4. Operations
# [Go back to the "Table of Contents"](#Table-of-Contents)

# %% [markdown]
# ### 4.1. Subsetting

# %% [markdown]
# Prior to <i>download</i> we need to select only those netCDF files that are of our interest.<br>There are many different criterias (if files contain a certain parameter, if they cover a certain area or/and a specific time range....).<br>Next we will see some examples!

# %% [markdown]
# #### 4.1.1. By collection

# %% [markdown]
# Let's select only the files that belong to one specific collection!

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>IMPORTANT</b>
#
# ***
# Please remember available options:
# <ul>
#     <li><i>latest</i>: daily files from platforms (last 30 days of data)</li>
#     <li><i>monthly</i>: monthly files from platforms (last 5 years of data)</li>
#     <li><i>history</i>: one file per platform (all platform data)</li>
# </ul>

# %% [markdown]
# `Set one collecion` next and `run the cells`:

# %%
targeted_collection = 'monthly' #try 'latest', 'monthly' or 'history'

# %%
condition = info['file_name'].str.contains(targeted_collection)
subset = info[condition]
subset.transpose()
# Out:
#                                                                         17     \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                     60.397
# geospatial_lat_max                                                     75.009
# geospatial_lon_min                                                      0.003
# geospatial_lon_max                                                     20.424
# time_coverage_start                                      2016-01-08T11:08:12Z
# time_coverage_end                                        2016-01-31T21:26:34Z
# institution                             Institute of Marine Research (Norway)
# date_update                                              2020-06-02T08:42:38Z
# data_mode                                                                   M
# parameters                                   SIGMA_T PRES PSAL TEMP CNDC DEPH
# netcdf                                                AR_PR_CT_58JH_201601.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                            58JH
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                    1351
# last_latitude_observation                                              57.001
# last_longitude_observation                                              4.696
# last_date_observation                                    2021-01-13T02:13:09Z
#
#                                                                         18     \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                     70.399
# geospatial_lat_max                                                     76.500
# geospatial_lon_min                                                     18.424
# geospatial_lon_max                                                     41.073
# time_coverage_start                                      2016-02-06T20:34:05Z
# time_coverage_end                                        2016-02-29T23:07:36Z
# institution                             Institute of Marine Research (Norway)
# date_update                                              2020-06-02T08:44:37Z
# data_mode                                                                   M
# parameters                                   SIGMA_T PRES PSAL TEMP CNDC DEPH
# netcdf                                                AR_PR_CT_58JH_201602.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                            58JH
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                    1351
# last_latitude_observation                                              57.001
# last_longitude_observation                                              4.696
# last_date_observation                                    2021-01-13T02:13:09Z
#
#                                                                         19     \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                     67.200
# geospatial_lat_max                                                     71.868
# geospatial_lon_min                                                     10.318
# geospatial_lon_max                                                     32.649
# time_coverage_start                                      2016-03-02T23:50:44Z
# time_coverage_end                                        2016-03-31T23:57:24Z
# institution                             Institute of Marine Research (Norway)
# date_update                                              2020-06-02T08:46:33Z
# data_mode                                                                   M
# parameters                                   SIGMA_T PRES PSAL TEMP CNDC DEPH
# netcdf                                                AR_PR_CT_58JH_201603.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                            58JH
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                    1351
# last_latitude_observation                                              57.001
# last_longitude_observation                                              4.696
# last_date_observation                                    2021-01-13T02:13:09Z
#
#                                                                         20     \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                     67.773
# geospatial_lat_max                                                     68.311
# geospatial_lon_min                                                     13.133
# geospatial_lon_max                                                     14.902
# time_coverage_start                                      2016-04-01T02:02:03Z
# time_coverage_end                                        2016-04-07T00:00:48Z
# institution                             Institute of Marine Research (Norway)
# date_update                                              2020-06-02T08:48:27Z
# data_mode                                                                   M
# parameters                                   SIGMA_T PRES PSAL TEMP CNDC DEPH
# netcdf                                                AR_PR_CT_58JH_201604.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                            58JH
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                    1351
# last_latitude_observation                                              57.001
# last_longitude_observation                                              4.696
# last_date_observation                                    2021-01-13T02:13:09Z
#
#                                                                         21     \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                     61.725
# geospatial_lat_max                                                     69.920
# geospatial_lon_min                                                    -13.599
# geospatial_lon_max                                                     16.075
# time_coverage_start                                      2016-05-03T06:19:57Z
# time_coverage_end                                        2016-05-23T12:00:46Z
# institution                             Institute of Marine Research (Norway)
# date_update                                              2020-06-02T08:50:38Z
# data_mode                                                                   M
# parameters                                   SIGMA_T PRES PSAL TEMP CNDC DEPH
# netcdf                                                AR_PR_CT_58JH_201605.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                            58JH
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                    1351
# last_latitude_observation                                              57.001
# last_longitude_observation                                              4.696
# last_date_observation                                    2021-01-13T02:13:09Z
#
#                                                                         22     \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                     56.688
# geospatial_lat_max                                                     60.412
# geospatial_lon_min                                                      3.543
# geospatial_lon_max                                                      5.873
# time_coverage_start                                      2016-06-27T13:35:25Z
# time_coverage_end                                        2016-06-30T23:10:06Z
# institution                             Institute of Marine Research (Norway)
# date_update                                              2020-06-02T08:55:35Z
# data_mode                                                                   M
# parameters                                   SIGMA_T PRES PSAL TEMP CNDC DEPH
# netcdf                                                AR_PR_CT_58JH_201606.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                            58JH
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                    1351
# last_latitude_observation                                              57.001
# last_longitude_observation                                              4.696
# last_date_observation                                    2021-01-13T02:13:09Z
#
#                                                                         23     \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                     56.827
# geospatial_lat_max                                                     61.919
# geospatial_lon_min                                                     -0.496
# geospatial_lon_max                                                      7.249
# time_coverage_start                                      2016-07-01T16:37:56Z
# time_coverage_end                                        2016-07-31T19:56:05Z
# institution                             Institute of Marine Research (Norway)
# date_update                                              2020-06-02T09:01:10Z
# data_mode                                                                   M
# parameters                                   SIGMA_T PRES PSAL TEMP CNDC DEPH
# netcdf                                                AR_PR_CT_58JH_201607.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                            58JH
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                    1351
# last_latitude_observation                                              57.001
# last_longitude_observation                                              4.696
# last_date_observation                                    2021-01-13T02:13:09Z
#
#                                                                         24     \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                     57.634
# geospatial_lat_max                                                     77.599
# geospatial_lon_min                                                     -2.236
# geospatial_lon_max                                                     35.804
# time_coverage_start                                      2016-08-01T05:03:00Z
# time_coverage_end                                        2016-08-27T03:35:14Z
# institution                             Institute of Marine Research (Norway)
# date_update                                              2020-06-02T09:06:58Z
# data_mode                                                                   D
# parameters                                           PRES PSAL TEMP CNDC DEPH
# netcdf                                                AR_PR_CT_58JH_201608.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                            58JH
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                    1351
# last_latitude_observation                                              57.001
# last_longitude_observation                                              4.696
# last_date_observation                                    2021-01-13T02:13:09Z
#
#                                                                         25     \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                     70.213
# geospatial_lat_max                                                     75.483
# geospatial_lon_min                                                     14.332
# geospatial_lon_max                                                     40.833
# time_coverage_start                                      2016-09-08T21:47:43Z
# time_coverage_end                                        2016-09-28T20:17:48Z
# institution                             Institute of Marine Research (Norway)
# date_update                                              2020-06-02T09:12:23Z
# data_mode                                                                   M
# parameters                                   SIGMA_T PRES PSAL TEMP CNDC DEPH
# netcdf                                                AR_PR_CT_58JH_201609.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                            58JH
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                    1351
# last_latitude_observation                                              57.001
# last_longitude_observation                                              4.696
# last_date_observation                                    2021-01-13T02:13:09Z
#
#                                                                         26     \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                     62.218
# geospatial_lat_max                                                     71.311
# geospatial_lon_min                                                      3.571
# geospatial_lon_max                                                     31.426
# time_coverage_start                                      2016-10-01T13:48:06Z
# time_coverage_end                                        2016-10-30T05:46:22Z
# institution                             Institute of Marine Research (Norway)
# date_update                                              2020-06-02T09:17:57Z
# data_mode                                                                   M
# parameters                                   SIGMA_T PRES PSAL TEMP CNDC DEPH
# netcdf                                                AR_PR_CT_58JH_201610.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                            58JH
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                    1351
# last_latitude_observation                                              57.001
# last_longitude_observation                                              4.696
# last_date_observation                                    2021-01-13T02:13:09Z
#
#                             ...  \
# # product_id                ...
# file_name                   ...
# geospatial_lat_min          ...
# geospatial_lat_max          ...
# geospatial_lon_min          ...
# geospatial_lon_max          ...
# time_coverage_start         ...
# time_coverage_end           ...
# institution                 ...
# date_update                 ...
# data_mode                   ...
# parameters                  ...
# netcdf                      ...
# file_type                   ...
# data_type                   ...
# platform_code               ...
# wmo_platform_code           ...
# institution_edmo_code       ...
# last_latitude_observation   ...
# last_longitude_observation  ...
# last_date_observation       ...
#
#                                                                         30708  \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                     75.230
# geospatial_lat_max                                                     75.230
# geospatial_lon_min                                                   -133.449
# geospatial_lon_max                                                   -133.449
# time_coverage_start                                      2016-03-27T13:00:00Z
# time_coverage_end                                        2016-03-27T13:00:00Z
# institution                                               Unknown institution
# date_update                                              2019-09-26T19:40:56Z
# data_mode                                                                   R
# parameters                                   DATA_MODE DC_REFERENCE DEPH TEMP
# netcdf                                               GL_PR_XX_48541_201603.nc
# file_type                                                                  PR
# data_type                                                                  XX
# platform_code                                                           48541
# wmo_platform_code                                                       48541
# institution_edmo_code
# last_latitude_observation                                              78.076
# last_longitude_observation                                           -132.405
# last_date_observation                                    2016-01-25T15:00:00Z
#
#                                                                         30711  \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                     57.717
# geospatial_lat_max                                                     60.073
# geospatial_lon_min                                                    -62.829
# geospatial_lon_max                                                    -59.631
# time_coverage_start                                      2016-07-22T12:20:00Z
# time_coverage_end                                        2016-07-31T22:45:00Z
# institution                                                  Canada (Unknown)
# date_update                                              2019-09-27T06:05:25Z
# data_mode                                                                   R
# parameters                              DATA_MODE DC_REFERENCE DEPH PSAL TEMP
# netcdf                                                GL_PR_XX_VOLT_201607.nc
# file_type                                                                  PR
# data_type                                                                  XX
# platform_code                                                            VOLT
# wmo_platform_code                                                        VOLT
# institution_edmo_code
# last_latitude_observation                                              60.060
# last_longitude_observation                                            -61.495
# last_date_observation                                    2016-07-31T22:45:00Z
#
#                                                                         30712  \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                     59.425
# geospatial_lat_max                                                     66.172
# geospatial_lon_min                                                    -69.921
# geospatial_lon_max                                                    -58.217
# time_coverage_start                                      2016-08-01T01:16:00Z
# time_coverage_end                                        2016-08-31T00:02:00Z
# institution                                                  Canada (Unknown)
# date_update                                              2019-09-27T06:05:25Z
# data_mode                                                                   R
# parameters                              DATA_MODE DC_REFERENCE DEPH PSAL TEMP
# netcdf                                                GL_PR_XX_VOLT_201608.nc
# file_type                                                                  PR
# data_type                                                                  XX
# platform_code                                                            VOLT
# wmo_platform_code                                                        VOLT
# institution_edmo_code
# last_latitude_observation                                              60.060
# last_longitude_observation                                            -61.495
# last_date_observation                                    2016-07-31T22:45:00Z
#
#                                                                         30714  \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                     63.089
# geospatial_lat_max                                                     66.272
# geospatial_lon_min                                                   -173.992
# geospatial_lon_max                                                   -168.663
# time_coverage_start                                      2016-08-30T02:17:00Z
# time_coverage_end                                        2016-08-31T23:08:00Z
# institution                 Japan Agency for Marine-Earth Science and Tech...
# date_update                                              2019-09-27T03:06:37Z
# data_mode                                                                   R
# parameters                                   DATA_MODE DC_REFERENCE DEPH TEMP
# netcdf                                                GL_PR_XX_JNSR_201608.nc
# file_type                                                                  PR
# data_type                                                                  XX
# platform_code                                                            JNSR
# wmo_platform_code                                                        JNSR
# institution_edmo_code                                                    1537
# last_latitude_observation                                              65.635
# last_longitude_observation                                           -168.466
# last_date_observation                                    2020-10-22T02:53:00Z
#
#                                                                         30715  \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                     65.054
# geospatial_lat_max                                                     73.861
# geospatial_lon_min                                                   -169.613
# geospatial_lon_max                                                   -151.998
# time_coverage_start                                      2016-09-01T06:42:00Z
# time_coverage_end                                        2016-09-22T18:30:00Z
# institution                 Japan Agency for Marine-Earth Science and Tech...
# date_update                                              2019-09-27T03:06:35Z
# data_mode                                                                   R
# parameters                    DATA_MODE HCSP HCDT DC_REFERENCE DEPH TEMP PSAL
# netcdf                                                GL_PR_XX_JNSR_201609.nc
# file_type                                                                  PR
# data_type                                                                  XX
# platform_code                                                            JNSR
# wmo_platform_code                                                        JNSR
# institution_edmo_code                                                    1537
# last_latitude_observation                                              65.635
# last_longitude_observation                                           -168.466
# last_date_observation                                    2020-10-22T02:53:00Z
#
#                                                                         30716  \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                     54.182
# geospatial_lat_max                                                     72.806
# geospatial_lon_min                                                   -168.842
# geospatial_lon_max                                                   -157.205
# time_coverage_start                                      2017-08-06T10:19:00Z
# time_coverage_end                                        2017-08-31T23:45:00Z
# institution                 Japan Agency for Marine-Earth Science and Tech...
# date_update                                              2019-09-27T03:07:46Z
# data_mode                                                                   R
# parameters                                   DATA_MODE DC_REFERENCE DEPH TEMP
# netcdf                                                GL_PR_XX_JNSR_201708.nc
# file_type                                                                  PR
# data_type                                                                  XX
# platform_code                                                            JNSR
# wmo_platform_code                                                        JNSR
# institution_edmo_code                                                    1537
# last_latitude_observation                                              65.635
# last_longitude_observation                                           -168.466
# last_date_observation                                    2020-10-22T02:53:00Z
#
#                                                                         30717  \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                     65.059
# geospatial_lat_max                                                     76.428
# geospatial_lon_min                                                   -178.003
# geospatial_lon_max                                                   -151.008
# time_coverage_start                                      2017-09-01T00:42:00Z
# time_coverage_end                                        2017-09-21T00:39:00Z
# institution                 Japan Agency for Marine-Earth Science and Tech...
# date_update                                              2019-09-27T03:07:46Z
# data_mode                                                                   R
# parameters                              DATA_MODE DC_REFERENCE DEPH TEMP PSAL
# netcdf                                                GL_PR_XX_JNSR_201709.nc
# file_type                                                                  PR
# data_type                                                                  XX
# platform_code                                                            JNSR
# wmo_platform_code                                                        JNSR
# institution_edmo_code                                                    1537
# last_latitude_observation                                              65.635
# last_longitude_observation                                           -168.466
# last_date_observation                                    2020-10-22T02:53:00Z
#
#                                                                         30718  \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                     57.444
# geospatial_lat_max                                                     73.998
# geospatial_lon_min                                                   -178.546
# geospatial_lon_max                                                    177.174
# time_coverage_start                                      2018-11-01T01:53:00Z
# time_coverage_end                                        2018-11-27T12:12:00Z
# institution                 Japan Agency for Marine-Earth Science and Tech...
# date_update                                              2019-09-27T03:07:43Z
# data_mode                                                                   R
# parameters                              DATA_MODE DC_REFERENCE DEPH PSAL TEMP
# netcdf                                                GL_PR_XX_JNSR_201811.nc
# file_type                                                                  PR
# data_type                                                                  XX
# platform_code                                                            JNSR
# wmo_platform_code                                                        JNSR
# institution_edmo_code                                                    1537
# last_latitude_observation                                              65.635
# last_longitude_observation                                           -168.466
# last_date_observation                                    2020-10-22T02:53:00Z
#
#                                                                         30719  \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                     49.994
# geospatial_lat_max                                                     78.085
# geospatial_lon_min                                                   -168.770
# geospatial_lon_max                                                    166.123
# time_coverage_start                                      2019-10-03T07:06:00Z
# time_coverage_end                                        2019-10-28T17:23:00Z
# institution                 Japan Agency for Marine-Earth Science and Tech...
# date_update                                              2020-03-20T12:31:01Z
# data_mode                                                                   R
# parameters                              DATA_MODE DC_REFERENCE DEPH TEMP PSAL
# netcdf                                                GL_PR_XX_JNSR_201910.nc
# file_type                                                                  PR
# data_type                                                                  XX
# platform_code                                                            JNSR
# wmo_platform_code                                                        JNSR
# institution_edmo_code                                                    1537
# last_latitude_observation                                              65.635
# last_longitude_observation                                           -168.466
# last_date_observation                                    2020-10-22T02:53:00Z
#
#                                                                         30720
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                     47.001
# geospatial_lat_max                                                     75.190
# geospatial_lon_min                                                    160.033
# geospatial_lon_max                                                   -153.500
# time_coverage_start                                      2020-10-01T04:24:00Z
# time_coverage_end                                        2020-10-22T02:53:00Z
# institution                 Japan Agency for Marine-Earth Science and Tech...
# date_update                                              2020-11-01T15:47:35Z
# data_mode                                                                   R
# parameters                    DATA_MODE HCSP HCDT DC_REFERENCE DEPH TEMP PSAL
# netcdf                                                GL_PR_XX_JNSR_202010.nc
# file_type                                                                  PR
# data_type                                                                  XX
# platform_code                                                            JNSR
# wmo_platform_code                                                        JNSR
# institution_edmo_code                                                    1537
# last_latitude_observation                                              65.635
# last_longitude_observation                                           -168.466
# last_date_observation                                    2020-10-22T02:53:00Z
#
# [21 rows x 21165 columns]

# %% [markdown]
# <div class="alert alert-block alert-info"">
# <b>TIP</b>
#
# ***
# To check if the above output only lists the files coming from a certain collection (the one set as targeted_collection') just check the `netcdf` row
# <ul><li>'latest' timestamp: netcdf file name ends with a YYYYMMDD</li></ul>
# <ul><li>'monthly' timestamp: netcdf file name ends with a YYYYMM</li></ul>
# <ul><li>'history' timestamp: netcdf file name ends with a YYYY or none timestamp</li></ul>

# %% [markdown]
# #### 4.1.2. By time range

# %% [markdown]
# Let's select only the files containing data within the next range of dates. <br>Please `set the start/end dates` you are interested in `and run the cells bellow`:

# %%
targeted_range = '2018-01-01T00:00:00Z/2019-01-01T23:59:59Z' #set your own!

# %%
info['timeOverlap'] = info.apply(timeOverlap,targeted_range=targeted_range,axis=1)
condition = info['timeOverlap'] == True
subset = info[condition]
subset.transpose()
# Out:
#                                                                         36     \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                     60.412
# geospatial_lat_max                                                     74.248
# geospatial_lon_min                                                     -0.002
# geospatial_lon_max                                                     19.997
# time_coverage_start                                      2018-01-13T08:51:51Z
# time_coverage_end                                        2018-01-24T04:54:14Z
# institution                             Institute of Marine Research (Norway)
# date_update                                              2020-06-02T09:46:34Z
# data_mode                                                                   M
# parameters                                   SIGMA_T PRES PSAL TEMP CNDC DEPH
# netcdf                                                AR_PR_CT_58JH_201801.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                            58JH
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                    1351
# last_latitude_observation                                              57.001
# last_longitude_observation                                              4.696
# last_date_observation                                    2021-01-13T02:13:09Z
# timeOverlap                                                              True
#
#                                                                         37     \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                     70.268
# geospatial_lat_max                                                     76.483
# geospatial_lon_min                                                     17.699
# geospatial_lon_max                                                     47.044
# time_coverage_start                                      2018-02-03T00:51:00Z
# time_coverage_end                                        2018-02-28T23:20:00Z
# institution                             Institute of Marine Research (Norway)
# date_update                                              2020-06-02T09:47:20Z
# data_mode                                                                   M
# parameters                                   SIGMA_T PRES PSAL TEMP CNDC DEPH
# netcdf                                                AR_PR_CT_58JH_201802.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                            58JH
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                    1351
# last_latitude_observation                                              57.001
# last_longitude_observation                                              4.696
# last_date_observation                                    2021-01-13T02:13:09Z
# timeOverlap                                                              True
#
#                                                                         38     \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                     67.630
# geospatial_lat_max                                                     74.009
# geospatial_lon_min                                                     10.971
# geospatial_lon_max                                                     32.130
# time_coverage_start                                      2018-03-01T01:52:37Z
# time_coverage_end                                        2018-03-31T22:17:03Z
# institution                             Institute of Marine Research (Norway)
# date_update                                              2020-06-02T09:47:54Z
# data_mode                                                                   M
# parameters                                   SIGMA_T PRES PSAL TEMP CNDC DEPH
# netcdf                                                AR_PR_CT_58JH_201803.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                            58JH
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                    1351
# last_latitude_observation                                              57.001
# last_longitude_observation                                              4.696
# last_date_observation                                    2021-01-13T02:13:09Z
# timeOverlap                                                              True
#
#                                                                         39     \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                     56.166
# geospatial_lat_max                                                     68.329
# geospatial_lon_min                                                     -2.517
# geospatial_lon_max                                                     14.901
# time_coverage_start                                      2018-04-01T04:36:27Z
# time_coverage_end                                        2018-04-30T03:46:19Z
# institution                             Institute of Marine Research (Norway)
# date_update                                              2020-06-02T09:48:27Z
# data_mode                                                                   M
# parameters                                   SIGMA_T PRES PSAL TEMP CNDC DEPH
# netcdf                                                AR_PR_CT_58JH_201804.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                            58JH
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                    1351
# last_latitude_observation                                              57.001
# last_longitude_observation                                              4.696
# last_date_observation                                    2021-01-13T02:13:09Z
# timeOverlap                                                              True
#
#                                                                         40     \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                     57.499
# geospatial_lat_max                                                     74.511
# geospatial_lon_min                                                     -3.675
# geospatial_lon_max                                                     20.015
# time_coverage_start                                      2018-05-01T07:12:57Z
# time_coverage_end                                        2018-05-31T22:58:08Z
# institution                             Institute of Marine Research (Norway)
# date_update                                              2020-06-02T09:49:10Z
# data_mode                                                                   M
# parameters                                   SIGMA_T PRES PSAL TEMP CNDC DEPH
# netcdf                                                AR_PR_CT_58JH_201805.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                            58JH
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                    1351
# last_latitude_observation                                              57.001
# last_longitude_observation                                              4.696
# last_date_observation                                    2021-01-13T02:13:09Z
# timeOverlap                                                              True
#
#                                                                         41     \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                     60.420
# geospatial_lat_max                                                     72.214
# geospatial_lon_min                                                      5.314
# geospatial_lon_max                                                     23.792
# time_coverage_start                                      2018-06-01T02:44:34Z
# time_coverage_end                                        2018-06-29T09:04:19Z
# institution                             Institute of Marine Research (Norway)
# date_update                                              2020-06-02T09:50:08Z
# data_mode                                                                   M
# parameters                                   SIGMA_T PRES PSAL TEMP CNDC DEPH
# netcdf                                                AR_PR_CT_58JH_201806.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                            58JH
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                    1351
# last_latitude_observation                                              57.001
# last_longitude_observation                                              4.696
# last_date_observation                                    2021-01-13T02:13:09Z
# timeOverlap                                                              True
#
#                                                                         42     \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                     56.640
# geospatial_lat_max                                                     61.943
# geospatial_lon_min                                                     -0.319
# geospatial_lon_max                                                      6.000
# time_coverage_start                                      2018-07-03T18:12:54Z
# time_coverage_end                                        2018-07-27T08:23:47Z
# institution                             Institute of Marine Research (Norway)
# date_update                                              2020-06-02T09:50:54Z
# data_mode                                                                   M
# parameters                                   SIGMA_T PRES PSAL TEMP CNDC DEPH
# netcdf                                                AR_PR_CT_58JH_201807.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                            58JH
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                    1351
# last_latitude_observation                                              57.001
# last_longitude_observation                                              4.696
# last_date_observation                                    2021-01-13T02:13:09Z
# timeOverlap                                                              True
#
#                                                                         43     \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                     62.368
# geospatial_lat_max                                                     74.509
# geospatial_lon_min                                                     -0.002
# geospatial_lon_max                                                     32.386
# time_coverage_start                                      2018-08-10T15:37:45Z
# time_coverage_end                                        2018-08-31T23:07:45Z
# institution                             Institute of Marine Research (Norway)
# date_update                                              2020-06-02T09:51:43Z
# data_mode                                                                   M
# parameters                                   SIGMA_T PRES PSAL TEMP CNDC DEPH
# netcdf                                                AR_PR_CT_58JH_201808.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                            58JH
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                    1351
# last_latitude_observation                                              57.001
# last_longitude_observation                                              4.696
# last_date_observation                                    2021-01-13T02:13:09Z
# timeOverlap                                                              True
#
#                                                                         44     \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                     72.350
# geospatial_lat_max                                                     79.378
# geospatial_lon_min                                                     13.838
# geospatial_lon_max                                                     37.904
# time_coverage_start                                      2018-09-01T06:06:51Z
# time_coverage_end                                        2018-09-30T21:50:37Z
# institution                             Institute of Marine Research (Norway)
# date_update                                              2020-06-02T09:53:00Z
# data_mode                                                                   M
# parameters                                   SIGMA_T PRES PSAL TEMP CNDC DEPH
# netcdf                                                AR_PR_CT_58JH_201809.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                            58JH
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                    1351
# last_latitude_observation                                              57.001
# last_longitude_observation                                              4.696
# last_date_observation                                    2021-01-13T02:13:09Z
# timeOverlap                                                              True
#
#                                                                         45     \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                     67.714
# geospatial_lat_max                                                     76.000
# geospatial_lon_min                                                     10.383
# geospatial_lon_max                                                     31.451
# time_coverage_start                                      2018-10-01T01:42:09Z
# time_coverage_end                                        2018-10-31T21:08:39Z
# institution                             Institute of Marine Research (Norway)
# date_update                                              2020-06-02T09:54:15Z
# data_mode                                                                   M
# parameters                                   SIGMA_T PRES PSAL TEMP CNDC DEPH
# netcdf                                                AR_PR_CT_58JH_201810.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                            58JH
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                    1351
# last_latitude_observation                                              57.001
# last_longitude_observation                                              4.696
# last_date_observation                                    2021-01-13T02:13:09Z
# timeOverlap                                                              True
#
#                             ...  \
# # product_id                ...
# file_name                   ...
# geospatial_lat_min          ...
# geospatial_lat_max          ...
# geospatial_lon_min          ...
# geospatial_lon_max          ...
# time_coverage_start         ...
# time_coverage_end           ...
# institution                 ...
# date_update                 ...
# data_mode                   ...
# parameters                  ...
# netcdf                      ...
# file_type                   ...
# data_type                   ...
# platform_code               ...
# wmo_platform_code           ...
# institution_edmo_code       ...
# last_latitude_observation   ...
# last_longitude_observation  ...
# last_date_observation       ...
# timeOverlap                 ...
#
#                                                                         33566  \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                  -12.68458
# geospatial_lat_max                                                   89.99995
# geospatial_lon_min                                                  -77.83088
# geospatial_lon_max                                                   50.68237
# time_coverage_start                                      2000-04-15T18:52:12Z
# time_coverage_end                                        2019-11-30T23:55:49Z
# institution                  GEOMAR  Helmholtz Centre for Ocean Research Kiel
# date_update                                              2019-12-07T07:03:19Z
# data_mode                                                                   R
# parameters                  PSAL CPHL TUR4 DOX2 DC_REFERENCE PRES CNDC DAT...
# netcdf                                                      GL_PR_GL_18904.nc
# file_type                                                                  PR
# data_type                                                                  GL
# platform_code                                                           18904
# wmo_platform_code                                                       18904
# institution_edmo_code                                                    2947
# last_latitude_observation                                            17.78229
# last_longitude_observation                                          -20.61112
# last_date_observation                                    2019-11-30T23:55:49Z
# timeOverlap                                                              True
#
#                                                                         33575  \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                     56.380
# geospatial_lat_max                                                     61.000
# geospatial_lon_min                                                    -23.410
# geospatial_lon_max                                                     -6.830
# time_coverage_start                                      2014-04-30T12:13:00Z
# time_coverage_end                                        2020-04-07T07:00:00Z
# institution                   National Oceanography Centre  Southampton (NOC)
# date_update                                              2020-12-06T14:23:43Z
# data_mode                                                                   R
# parameters                                        PSAL DC_REFERENCE DEPH TEMP
# netcdf                                                      GL_PR_GL_68990.nc
# file_type                                                                  PR
# data_type                                                                  GL
# platform_code                                                           68990
# wmo_platform_code                                                       68990
# institution_edmo_code                                                      17
# last_latitude_observation                                              56.940
# last_longitude_observation                                            -10.213
# last_date_observation                                    2020-04-07T07:00:00Z
# timeOverlap                                                              True
#
#                                                                         33641  \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                    46.0921
# geospatial_lat_max                                                    65.4100
# geospatial_lon_min                                                   -60.1170
# geospatial_lon_max                                                   -14.0580
# time_coverage_start                                      2011-05-28T04:09:47Z
# time_coverage_end                                        2018-11-17T03:51:34Z
# institution                               Met Office (Ocean Weather Services)
# date_update                                              2019-12-07T07:13:43Z
# data_mode                                                                   M
# parameters                  PSAL PRES_ADJUSTED VERTICAL_SAMPLING_SCHEME PS...
# netcdf                                                    GL_PR_PF_1901294.nc
# file_type                                                                  PR
# data_type                                                                  PF
# platform_code                                                         1901294
# wmo_platform_code                                                     1901294
# institution_edmo_code                                                      29
# last_latitude_observation                                             49.0288
# last_longitude_observation                                           -34.3638
# last_date_observation                                    2018-11-17T03:51:34Z
# timeOverlap                                                              True
#
#                                                                         33730  \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                   41.06255
# geospatial_lat_max                                                   60.94490
# geospatial_lon_min                                                  -57.79540
# geospatial_lon_max                                                  -30.53270
# time_coverage_start                                      2012-06-17T10:24:00Z
# time_coverage_end                                        2018-03-18T10:30:00Z
# institution                                       Fisheries and Oceans Canada
# date_update                                              2019-05-11T06:02:58Z
# data_mode                                                                   M
# parameters                  PSAL PRES_ADJUSTED VERTICAL_SAMPLING_SCHEME PS...
# netcdf                                                    GL_PR_PF_4901195.nc
# file_type                                                                  PR
# data_type                                                                  PF
# platform_code                                                         4901195
# wmo_platform_code                                                     4901195
# institution_edmo_code                                                    1979
# last_latitude_observation                                            45.08675
# last_longitude_observation                                          -46.19203
# last_date_observation                                    2018-03-18T10:30:00Z
# timeOverlap                                                              True
#
#                                                                         33988  \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                     48.664
# geospatial_lat_max                                                     65.007
# geospatial_lon_min                                                    -59.118
# geospatial_lon_max                                                    -14.749
# time_coverage_start                                      2012-06-17T16:07:00Z
# time_coverage_end                                        2018-03-21T00:18:00Z
# institution                 IFREMER  Institut Francais de Recherche pour l...
# date_update                                              2020-02-09T20:30:07Z
# data_mode                                                                   M
# parameters                  PSAL PRES_ADJUSTED VERTICAL_SAMPLING_SCHEME PS...
# netcdf                                                    GL_PR_PF_6900973.nc
# file_type                                                                  PR
# data_type                                                                  PF
# platform_code                                                         6900973
# wmo_platform_code                                                     6900973
# institution_edmo_code                                                    1054
# last_latitude_observation                                              52.325
# last_longitude_observation                                            -34.840
# last_date_observation                                    2018-03-21T00:18:00Z
# timeOverlap                                                              True
#
#                                                                         33989  \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                     48.749
# geospatial_lat_max                                                     60.605
# geospatial_lon_min                                                    -45.606
# geospatial_lon_max                                                    -19.764
# time_coverage_start                                      2012-07-13T03:07:00Z
# time_coverage_end                                        2018-03-05T23:28:00Z
# institution                 IFREMER  Institut Francais de Recherche pour l...
# date_update                                              2020-11-24T18:50:54Z
# data_mode                                                                   D
# parameters                  PSAL VERTICAL_SAMPLING_SCHEME DOX2 DOX2_ADJUST...
# netcdf                                                    GL_PR_PF_6901027.nc
# file_type                                                                  PR
# data_type                                                                  PF
# platform_code                                                         6901027
# wmo_platform_code                                                     6901027
# institution_edmo_code                                                    1054
# last_latitude_observation                                              50.872
# last_longitude_observation                                            -19.764
# last_date_observation                                    2018-03-05T23:28:00Z
# timeOverlap                                                              True
#
#                                                                         34008  \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                    52.9502
# geospatial_lat_max                                                    64.9030
# geospatial_lon_min                                                   -60.4160
# geospatial_lon_max                                                   -16.8380
# time_coverage_start                                      2013-05-14T04:45:19Z
# time_coverage_end                                        2020-12-03T10:46:16Z
# institution                               Met Office (Ocean Weather Services)
# date_update                                              2021-01-11T17:25:35Z
# data_mode                                                                   M
# parameters                  PSAL PRES_ADJUSTED VERTICAL_SAMPLING_SCHEME PS...
# netcdf                                                    GL_PR_PF_6901147.nc
# file_type                                                                  PR
# data_type                                                                  PF
# platform_code                                                         6901147
# wmo_platform_code                                                     6901147
# institution_edmo_code                                                      29
# last_latitude_observation                                             57.5758
# last_longitude_observation                                           -36.8099
# last_date_observation                                    2020-12-03T10:46:16Z
# timeOverlap                                                              True
#
#                                                                         34009  \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                    50.3410
# geospatial_lat_max                                                    64.9680
# geospatial_lon_min                                                   -53.0720
# geospatial_lon_max                                                   -13.5440
# time_coverage_start                                      2013-05-17T14:55:09Z
# time_coverage_end                                        2020-01-31T18:38:04Z
# institution                               Met Office (Ocean Weather Services)
# date_update                                              2020-02-03T03:05:16Z
# data_mode                                                                   M
# parameters                  PSAL PRES_ADJUSTED VERTICAL_SAMPLING_SCHEME PS...
# netcdf                                                    GL_PR_PF_6901149.nc
# file_type                                                                  PR
# data_type                                                                  PF
# platform_code                                                         6901149
# wmo_platform_code                                                     6901149
# institution_edmo_code                                                      29
# last_latitude_observation                                             50.8686
# last_longitude_observation                                           -39.9429
# last_date_observation                                    2020-01-31T18:38:04Z
# timeOverlap                                                              True
#
#                                                                         34058  \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                   53.86076
# geospatial_lat_max                                                   71.14296
# geospatial_lon_min                                                 -168.86269
# geospatial_lon_max                                                 -159.53271
# time_coverage_start                                      2018-07-23T12:00:00Z
# time_coverage_end                                        2018-10-05T19:50:00Z
# institution                                               Unknown institution
# date_update                                              2021-01-06T08:05:34Z
# data_mode                                                                   R
# parameters                                   DC_REFERENCE ATMS DEPH TEMP DRYT
# netcdf                                                    GL_TS_SD_4803904.nc
# file_type                                                                  TS
# data_type                                                                  SD
# platform_code                                                         4803904
# wmo_platform_code                                                     4803904
# institution_edmo_code
# last_latitude_observation                                            53.86076
# last_longitude_observation                                         -166.58109
# last_date_observation                                    2018-10-05T18:50:00Z
# timeOverlap                                                              True
#
#                                                                         34059
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                   53.84998
# geospatial_lat_max                                                   72.54484
# geospatial_lon_min                                                 -168.93102
# geospatial_lon_max                                                 -157.74821
# time_coverage_start                                      2018-07-23T12:00:00Z
# time_coverage_end                                        2018-10-05T19:50:00Z
# institution                                               Unknown institution
# date_update                                              2021-01-06T08:06:29Z
# data_mode                                                                   R
# parameters                                   DC_REFERENCE ATMS DEPH TEMP DRYT
# netcdf                                                    GL_TS_SD_4803905.nc
# file_type                                                                  TS
# data_type                                                                  SD
# platform_code                                                         4803905
# wmo_platform_code                                                     4803905
# institution_edmo_code
# last_latitude_observation                                            53.84998
# last_longitude_observation                                         -166.58157
# last_date_observation                                    2018-10-05T19:20:00Z
# timeOverlap                                                              True
#
# [22 rows x 4746 columns]

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>TIP</b>
#
# ***
# To check if the above output only lists the files containing data within a certain time range (the one set as 'targeted_range') just check `time_coverage_start` and `time_coverage_end` rows.

# %% [markdown]
# #### 4.1.3. By bounding-box

# %% [markdown]
# Let's look for files containing data from a specific area.<br>`Please set your own area limits` next `and run the cell`:

# %%
targeted_geospatial_lat_min = 70.0  # enter min latitude of your bounding box
targeted_geospatial_lat_max = 72.5  # enter max latitude of your bounding box
targeted_geospatial_lon_min = -6.5  # enter min longitude of your bounding box
targeted_geospatial_lon_max = -10.5  # enter max longitude of your bounding box
targeted_bbox = [targeted_geospatial_lon_min, targeted_geospatial_lat_min, targeted_geospatial_lon_max, targeted_geospatial_lat_max]  # (minx, miny, maxx, maxy)

# %% [markdown]
# Let's see the area you have set before: `run the next cell`

# %%
m = folium.Map(location=[39.0, 0], zoom_start=4)
upper_left = [targeted_geospatial_lat_max, targeted_geospatial_lon_min]
upper_right = [targeted_geospatial_lat_max, targeted_geospatial_lon_max]
lower_right = [targeted_geospatial_lat_min, targeted_geospatial_lon_max]
lower_left = [targeted_geospatial_lat_min, targeted_geospatial_lon_min]
edges_ = [upper_left, upper_right, lower_right, lower_left]
m.add_child(folium.vector_layers.Polygon(locations=edges_))
#Zooming closer
m.fit_bounds(edges_, max_zoom=4)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_7bb5cc65020d4c409f46e33d0d2129ef%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_7bb5cc65020d4c409f46e33d0d2129ef%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_7bb5cc65020d4c409f46e33d0d2129ef%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_7bb5cc65020d4c409f46e33d0d2129ef%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B39.0%2C%200.0%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20crs ...

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>WARNING</b>
#
# ***
# If you do not see any map when running the next cell please change your navigator (try chrome!).

# %% [markdown]
# `Run the next cell` to obtain the subset of files with data in such area:

# %%
info['spatialOverlap'] = info.apply(spatialOverlap,targeted_bbox=targeted_bbox,axis=1)
condition = info['spatialOverlap'] == True
subset = info[condition]
subset.transpose()
# Out:
#                                                                         71     \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                      0.000
# geospatial_lat_max                                                     81.011
# geospatial_lon_min                                                    -35.230
# geospatial_lon_max                                                     64.507
# time_coverage_start                                      1991-01-07T10:31:00Z
# time_coverage_end                                        2020-12-09T03:49:00Z
# institution                             Institute of Marine Research (Norway)
# date_update                                              2021-01-15T07:13:23Z
# data_mode                                                                   M
# parameters                                        PSAL PRES CNDC SIGMA_T TEMP
# netcdf                                                       AR_PR_CT_58JH.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                            58JH
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                    1351
# last_latitude_observation                                              57.001
# last_longitude_observation                                              4.696
# last_date_observation                                    2021-01-13T02:13:09Z
# timeOverlap                                                              True
# spatialOverlap                                                           True
#
#                                                                         122    \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                     66.606
# geospatial_lat_max                                                     81.200
# geospatial_lon_min                                                    -18.565
# geospatial_lon_max                                                     15.261
# time_coverage_start                                      2018-06-01T00:36:32Z
# time_coverage_end                                        2018-06-30T23:15:22Z
# institution                             Institute of Marine Research (Norway)
# date_update                                              2020-06-02T09:49:44Z
# data_mode                                                                   D
# parameters                                           PRES PSAL TEMP CNDC DEPH
# netcdf                                                AR_PR_CT_58UO_201806.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                            58UO
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                    1351
# last_latitude_observation                                              59.240
# last_longitude_observation                                              4.099
# last_date_observation                                    2021-01-13T21:54:36Z
# timeOverlap                                                              True
# spatialOverlap                                                           True
#
#                                                                         151    \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                    -26.838
# geospatial_lat_max                                                     81.410
# geospatial_lon_min                                                    -18.565
# geospatial_lon_max                                                     98.266
# time_coverage_start                                      2013-05-01T18:28:54Z
# time_coverage_end                                        2020-11-08T06:44:36Z
# institution                             Institute of Marine Research (Norway)
# date_update                                              2021-01-15T07:00:46Z
# data_mode                                                                   M
# parameters                                        PSAL PRES CNDC SIGMA_T TEMP
# netcdf                                                       AR_PR_CT_58UO.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                            58UO
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                    1351
# last_latitude_observation                                              59.240
# last_longitude_observation                                              4.099
# last_date_observation                                    2021-01-13T21:54:36Z
# timeOverlap                                                              True
# spatialOverlap                                                           True
#
#                                                                         1538   \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                     69.784
# geospatial_lat_max                                                     70.487
# geospatial_lon_min                                                     -6.673
# geospatial_lon_max                                                     -6.053
# time_coverage_start                                      2019-06-03T06:26:00Z
# time_coverage_end                                        2019-06-23T06:34:00Z
# institution                 IFREMER  Institut Francais de Recherche pour l...
# date_update                                              2019-07-09T19:00:27Z
# data_mode                                                                   R
# parameters                  DATA_MODE PRES DC_REFERENCE PSAL TEMP VERTICAL...
# netcdf                                             GL_PR_PF_6902784_201906.nc
# file_type                                                                  PR
# data_type                                                                  PF
# platform_code                                                         6902784
# wmo_platform_code                                                     6902784
# institution_edmo_code                                                    1054
# last_latitude_observation                                              67.429
# last_longitude_observation                                              0.480
# last_date_observation                                    2021-01-13T06:59:00Z
# timeOverlap                                                             False
# spatialOverlap                                                           True
#
#                                                                         1557   \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                     63.923
# geospatial_lat_max                                                     71.744
# geospatial_lon_min                                                     -8.237
# geospatial_lon_max                                                     10.980
# time_coverage_start                                      2017-10-09T08:53:00Z
# time_coverage_end                                        2020-12-24T06:57:00Z
# institution                 IFREMER  Institut Francais de Recherche pour l...
# date_update                                              2021-01-04T03:48:09Z
# data_mode                                                                   R
# parameters                  PSAL VERTICAL_SAMPLING_SCHEME DC_REFERENCE PRE...
# netcdf                                                    GL_PR_PF_6902784.nc
# file_type                                                                  PR
# data_type                                                                  PF
# platform_code                                                         6902784
# wmo_platform_code                                                     6902784
# institution_edmo_code                                                    1054
# last_latitude_observation                                              67.429
# last_longitude_observation                                              0.480
# last_date_observation                                    2021-01-13T06:59:00Z
# timeOverlap                                                              True
# spatialOverlap                                                           True
#
#                                                                         1951   \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                   71.54588
# geospatial_lat_max                                                   75.10578
# geospatial_lon_min                                                  -11.13265
# geospatial_lon_max                                                   -5.47367
# time_coverage_start                                      2020-09-01T01:00:00Z
# time_coverage_end                                        2020-09-30T23:30:00Z
# institution                                               Unknown institution
# date_update                                              2020-10-01T17:17:15Z
# data_mode                                                                   R
# parameters                               DC_REFERENCE DEPH POSITIONING_SYSTEM
# netcdf                                             GL_TS_DB_2501510_202009.nc
# file_type                                                                  TS
# data_type                                                                  DB
# platform_code                                                         2501510
# wmo_platform_code                                                     2501510
# institution_edmo_code
# last_latitude_observation                                            65.92719
# last_longitude_observation                                          -26.50037
# last_date_observation                                    2021-01-13T23:30:00Z
# timeOverlap                                                             False
# spatialOverlap                                                           True
#
#                                                                         1952   \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                   70.23213
# geospatial_lat_max                                                   72.11837
# geospatial_lon_min                                                  -17.51102
# geospatial_lon_max                                                   -8.97420
# time_coverage_start                                      2020-10-01T01:00:00Z
# time_coverage_end                                        2020-10-31T23:30:00Z
# institution                                               Unknown institution
# date_update                                              2020-11-01T16:13:54Z
# data_mode                                                                   R
# parameters                               DC_REFERENCE DEPH POSITIONING_SYSTEM
# netcdf                                             GL_TS_DB_2501510_202010.nc
# file_type                                                                  TS
# data_type                                                                  DB
# platform_code                                                         2501510
# wmo_platform_code                                                     2501510
# institution_edmo_code
# last_latitude_observation                                            65.92719
# last_longitude_observation                                          -26.50037
# last_date_observation                                    2021-01-13T23:30:00Z
# timeOverlap                                                             False
# spatialOverlap                                                           True
#
#                                                                         1955   \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                   65.01471
# geospatial_lat_max                                                   87.67605
# geospatial_lon_min                                                  -29.38914
# geospatial_lon_max                                                  119.89278
# time_coverage_start                                      2019-10-01T04:00:00Z
# time_coverage_end                                        2020-12-31T23:30:00Z
# institution                                               Unknown institution
# date_update                                              2021-01-06T08:55:58Z
# data_mode                                                                   R
# parameters                                                  DEPH DC_REFERENCE
# netcdf                                                    GL_TS_DB_2501510.nc
# file_type                                                                  TS
# data_type                                                                  DB
# platform_code                                                         2501510
# wmo_platform_code                                                     2501510
# institution_edmo_code
# last_latitude_observation                                            65.92719
# last_longitude_observation                                          -26.50037
# last_date_observation                                    2021-01-13T23:30:00Z
# timeOverlap                                                             False
# spatialOverlap                                                           True
#
#                                                                         2253   \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                    59.7740
# geospatial_lat_max                                                    70.4390
# geospatial_lon_min                                                   -12.2172
# geospatial_lon_max                                                    19.6564
# time_coverage_start                                      2020-03-09T10:00:00Z
# time_coverage_end                                        2020-12-31T23:00:00Z
# institution                 Meteo-France / Centre de Meteorologie Marine (...
# date_update                                              2021-01-06T09:42:46Z
# data_mode                                                                   R
# parameters                                        DC_REFERENCE ATMS DEPH TEMP
# netcdf                                                    GL_TS_DB_4101655.nc
# file_type                                                                  TS
# data_type                                                                  DB
# platform_code                                                         4101655
# wmo_platform_code                                                     4101655
# institution_edmo_code                                                    1190
# last_latitude_observation                                             70.3938
# last_longitude_observation                                            20.8286
# last_date_observation                                    2021-01-13T23:00:00Z
# timeOverlap                                                             False
# spatialOverlap                                                           True
#
#                                                                         2372   \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                    59.8894
# geospatial_lat_max                                                    71.9462
# geospatial_lon_min                                                   -11.9252
# geospatial_lon_max                                                    37.5920
# time_coverage_start                                      2019-12-16T13:00:00Z
# time_coverage_end                                        2020-12-31T23:00:00Z
# institution                 Meteo-France / Centre de Meteorologie Marine (...
# date_update                                              2021-01-06T09:44:45Z
# data_mode                                                                   R
# parameters                                        DC_REFERENCE ATMS DEPH TEMP
# netcdf                                                    GL_TS_DB_4101659.nc
# file_type                                                                  TS
# data_type                                                                  DB
# platform_code                                                         4101659
# wmo_platform_code                                                     4101659
# institution_edmo_code                                                    1190
# last_latitude_observation                                             70.6744
# last_longitude_observation                                            38.3560
# last_date_observation                                    2021-01-13T23:00:00Z
# timeOverlap                                                             False
# spatialOverlap                                                           True
#
#                             ...  \
# # product_id                ...
# file_name                   ...
# geospatial_lat_min          ...
# geospatial_lat_max          ...
# geospatial_lon_min          ...
# geospatial_lon_max          ...
# time_coverage_start         ...
# time_coverage_end           ...
# institution                 ...
# date_update                 ...
# data_mode                   ...
# parameters                  ...
# netcdf                      ...
# file_type                   ...
# data_type                   ...
# platform_code               ...
# wmo_platform_code           ...
# institution_edmo_code       ...
# last_latitude_observation   ...
# last_longitude_observation  ...
# last_date_observation       ...
# timeOverlap                 ...
# spatialOverlap              ...
#
#                                                                         34266  \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                     -33.42
# geospatial_lat_max                                                      89.25
# geospatial_lon_min                                                     -96.70
# geospatial_lon_max                                                      68.44
# time_coverage_start                                      1994-04-15T18:29:00Z
# time_coverage_end                                        1999-02-10T11:38:00Z
# institution                                                  Panama (Unknown)
# date_update                                              2019-05-08T10:02:22Z
# data_mode                                                                   R
# parameters                              DC_REFERENCE PRES DEPH DATA_MODE TEMP
# netcdf                                                      GL_PR_XB_3ETQ5.nc
# file_type                                                                  PR
# data_type                                                                  XB
# platform_code                                                           3ETQ5
# wmo_platform_code                                                       3ETQ5
# institution_edmo_code
# last_latitude_observation                                              -25.10
# last_longitude_observation                                              35.40
# last_date_observation                                    1999-02-10T11:38:00Z
# timeOverlap                                                             False
# spatialOverlap                                                           True
#
#                                                                         34270  \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                      58.66
# geospatial_lat_max                                                      70.89
# geospatial_lon_min                                                     -44.62
# geospatial_lon_max                                                      15.35
# time_coverage_start                                      1993-04-20T16:18:00Z
# time_coverage_end                                        1993-06-11T04:14:00Z
# institution                                                 Germany (Unknown)
# date_update                                              2019-05-08T11:57:38Z
# data_mode                                                                   R
# parameters                                   DC_REFERENCE PRES DATA_MODE TEMP
# netcdf                                                       GL_PR_XB_DIXX.nc
# file_type                                                                  PR
# data_type                                                                  XB
# platform_code                                                            DIXX
# wmo_platform_code                                                        DIXX
# institution_edmo_code
# last_latitude_observation                                               58.93
# last_longitude_observation                                             -44.62
# last_date_observation                                    1993-06-11T04:14:00Z
# timeOverlap                                                             False
# spatialOverlap                                                           True
#
#                                                                         34272  \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                     -22.25
# geospatial_lat_max                                                      71.34
# geospatial_lon_min                                                    -179.12
# geospatial_lon_max                                                     179.12
# time_coverage_start                                      1997-05-17T05:55:00Z
# time_coverage_end                                        1998-02-08T05:58:00Z
# institution                                      French Institution (Unknown)
# date_update                                              2019-05-08T14:39:58Z
# data_mode                                                                   R
# parameters                                   DC_REFERENCE PRES DATA_MODE TEMP
# netcdf                                                       GL_PR_XB_FNTL.nc
# file_type                                                                  PR
# data_type                                                                  XB
# platform_code                                                            FNTL
# wmo_platform_code                                                        FNTL
# institution_edmo_code
# last_latitude_observation                                              -22.22
# last_longitude_observation                                             168.42
# last_date_observation                                    1998-02-08T05:58:00Z
# timeOverlap                                                             False
# spatialOverlap                                                           True
#
#                                                                         34275  \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                   -77.8500
# geospatial_lat_max                                                    84.8100
# geospatial_lon_min                                                  -179.3100
# geospatial_lon_max                                                   179.9667
# time_coverage_start                                      1985-03-27T11:37:00Z
# time_coverage_end                                        1997-12-22T15:49:00Z
# institution                                           United states (Unknown)
# date_update                                              2020-01-13T07:57:45Z
# data_mode                                                                   R
# parameters                              DC_REFERENCE PRES DEPH DATA_MODE TEMP
# netcdf                                                       GL_PR_XB_NBTM.nc
# file_type                                                                  PR
# data_type                                                                  XB
# platform_code                                                            NBTM
# wmo_platform_code                                                        NBTM
# institution_edmo_code
# last_latitude_observation                                            -64.0100
# last_longitude_observation                                           160.7600
# last_date_observation                                    1997-12-22T15:49:00Z
# timeOverlap                                                             False
# spatialOverlap                                                           True
#
#                                                                         34276  \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                     -77.48
# geospatial_lat_max                                                      76.03
# geospatial_lon_min                                                    -179.60
# geospatial_lon_max                                                     179.50
# time_coverage_start                                      1996-01-21T12:15:00Z
# time_coverage_end                                        2002-08-23T10:54:00Z
# institution                                           United states (Unknown)
# date_update                                              2019-09-29T01:18:28Z
# data_mode                                                                   R
# parameters                              DC_REFERENCE PRES DEPH DATA_MODE TEMP
# netcdf                                                       GL_PR_XX_NBTM.nc
# file_type                                                                  PR
# data_type                                                                  XX
# platform_code                                                            NBTM
# wmo_platform_code                                                        NBTM
# institution_edmo_code
# last_latitude_observation                                              -64.01
# last_longitude_observation                                             160.76
# last_date_observation                                    1997-12-22T15:49:00Z
# timeOverlap                                                             False
# spatialOverlap                                                           True
#
#                                                                         34286  \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                       4.30
# geospatial_lat_max                                                      80.53
# geospatial_lon_min                                                    -116.01
# geospatial_lon_max                                                      -3.42
# time_coverage_start                                      1986-06-14T05:48:00Z
# time_coverage_end                                        1993-07-29T19:43:00Z
# institution                                           United states (Unknown)
# date_update                                              2019-05-08T19:13:06Z
# data_mode                                                                   R
# parameters                              DC_REFERENCE PRES DEPH DATA_MODE TEMP
# netcdf                                                       GL_PR_XB_WTEG.nc
# file_type                                                                  PR
# data_type                                                                  XB
# platform_code                                                            WTEG
# wmo_platform_code                                                        WTEG
# institution_edmo_code
# last_latitude_observation                                               80.53
# last_longitude_observation                                             -13.50
# last_date_observation                                    1993-07-29T19:43:00Z
# timeOverlap                                                             False
# spatialOverlap                                                           True
#
#                                                                         34288  \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                      38.10
# geospatial_lat_max                                                      71.62
# geospatial_lon_min                                                     -54.36
# geospatial_lon_max                                                      26.34
# time_coverage_start                                      1998-11-05T05:40:00Z
# time_coverage_end                                        2003-03-07T07:43:00Z
# institution                                University of Washington (Seattle)
# date_update                                              2019-09-28T09:41:23Z
# data_mode                                                                   R
# parameters                                   DC_REFERENCE PRES DATA_MODE TEMP
# netcdf                                                      GL_PR_XX_41537.nc
# file_type                                                                  PR
# data_type                                                                  XX
# platform_code                                                           41537
# wmo_platform_code                                                       41537
# institution_edmo_code                                                    3839
# last_latitude_observation                                               71.45
# last_longitude_observation                                              26.34
# last_date_observation                                    2003-03-07T07:43:00Z
# timeOverlap                                                             False
# spatialOverlap                                                           True
#
#                                                                         34300  \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                     49.550
# geospatial_lat_max                                                     72.198
# geospatial_lon_min                                                    -21.960
# geospatial_lon_max                                                     -0.088
# time_coverage_start                                      1998-03-21T12:29:00Z
# time_coverage_end                                        2002-11-15T04:12:00Z
# institution                                           United states (Unknown)
# date_update                                              2019-09-28T15:38:57Z
# data_mode                                                                   R
# parameters                                   DC_REFERENCE PRES DATA_MODE TEMP
# netcdf                                                      GL_PR_XX_62729.nc
# file_type                                                                  PR
# data_type                                                                  XX
# platform_code                                                           62729
# wmo_platform_code                                                       62729
# institution_edmo_code
# last_latitude_observation                                              71.124
# last_longitude_observation                                             -3.064
# last_date_observation                                    2002-11-15T04:12:00Z
# timeOverlap                                                             False
# spatialOverlap                                                           True
#
#                                                                         34307  \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                     61.680
# geospatial_lat_max                                                     79.800
# geospatial_lon_min                                                    -14.930
# geospatial_lon_max                                                     -0.080
# time_coverage_start                                      1998-04-07T23:01:00Z
# time_coverage_end                                        2001-03-18T06:54:00Z
# institution                                           United states (Unknown)
# date_update                                              2019-09-28T15:39:37Z
# data_mode                                                                   R
# parameters                                   DC_REFERENCE PRES DATA_MODE TEMP
# netcdf                                                      GL_PR_XX_62740.nc
# file_type                                                                  PR
# data_type                                                                  XX
# platform_code                                                           62740
# wmo_platform_code                                                       62740
# institution_edmo_code
# last_latitude_observation                                              76.984
# last_longitude_observation                                             -0.147
# last_date_observation                                    2001-03-18T06:54:00Z
# timeOverlap                                                             False
# spatialOverlap                                                           True
#
#                                                                         34353
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                    -38.130
# geospatial_lat_max                                                     90.000
# geospatial_lon_min                                                   -174.100
# geospatial_lon_max                                                    153.950
# time_coverage_start                                      1985-05-04T23:00:00Z
# time_coverage_end                                        2007-12-06T11:45:00Z
# institution                                               Australia (Unknown)
# date_update                                              2019-10-06T08:04:24Z
# data_mode                                                                   R
# parameters                              DC_REFERENCE PRES DEPH DATA_MODE TEMP
# netcdf                                                       GL_PR_XX_VKLA.nc
# file_type                                                                  PR
# data_type                                                                  XX
# platform_code                                                            VKLA
# wmo_platform_code                                                        VKLA
# institution_edmo_code
# last_latitude_observation                                             -33.350
# last_longitude_observation                                            114.883
# last_date_observation                                    2007-12-06T11:45:00Z
# timeOverlap                                                             False
# spatialOverlap                                                           True
#
# [23 rows x 1335 columns]

# %% [markdown]
# Let's check now if the bbox of the above files truely overlaps with the targeted area!: `run the next cells`

# %%
numberOfFiles = 50 #we will check just a sample of files not all as there might be too many

# %%
m = folium.Map(location=[39.0, 0], zoom_start=6)
m.add_child(folium.vector_layers.Polygon(locations=edges_))
for platform, files in subset[:numberOfFiles].groupby(['platform_code', 'data_type']):
    color = "%06x" % random.randint(0, 0xFFFFFF)
    for i in range(0, len(files)):
        netcdf = files.iloc[i]['file_name'].split('/')[-1]
        upper_left = [
            files.iloc[i]['geospatial_lat_max'],
            files.iloc[i]['geospatial_lon_min']
        ]
        upper_right = [
            files.iloc[i]['geospatial_lat_max'],
            files.iloc[i]['geospatial_lon_max']
        ]
        lower_right = [
            files.iloc[i]['geospatial_lat_min'],
            files.iloc[i]['geospatial_lon_max']
        ]
        lower_left = [
            files.iloc[i]['geospatial_lat_min'],
            files.iloc[i]['geospatial_lon_min']
        ]
        edges = [upper_left, upper_right, lower_right, lower_left]
        popup_info = '<b>netcdf</b>: ' + files.iloc[i]['netcdf']
        m.add_child(folium.vector_layers.Polygon(locations=edges,color='#' + color,popup=(folium.Popup(popup_info))))
        m.fit_bounds(edges, max_zoom=6)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_38cca1ff6aaa4201bd9c2f346610d070%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_38cca1ff6aaa4201bd9c2f346610d070%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_38cca1ff6aaa4201bd9c2f346610d070%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_38cca1ff6aaa4201bd9c2f346610d070%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B39.0%2C%200.0%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20crs ...

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>WARNING</b>
#
# ***
# If you do not see any map when running the next cell please change your navigator (try chrome!).

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>TIP</b>
#
# ***
# To check if everything went well, just check if the files box is indeed at some point within the one you were interested in (targeted bbox)

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>IMPORTANT</b>
#
# ***
# If you are not satisfied with the resulting output (i.e you want to get only the files whose bbox is completely within the targeted area) please revisit the [definition of the SpatialOverlap](#SpatialOverlap) function and replace the rule applied (`intersects`) by any of the available ones [here](https://shapely.readthedocs.io/en/stable/manual.html#binary-predicates)

# %% [markdown]
# #### 4.1.4. By last position

# %% [markdown]
# Let's look for files produced by a platform whose last position is within a specific area.<br>`Please set your own area limits` next `and run the cell`:

# %% [markdown]
# Let's see the area you have set before: `run the next cell`

# %%
targeted_geospatial_lat_min = 62.0  # enter min latitude of your bounding box
targeted_geospatial_lat_max = 66.5  # enter max latitude of your bounding box
targeted_geospatial_lon_min = -65.5  # enter min longitude of your bounding box
targeted_geospatial_lon_max = -50.0  # enter max longitude of your bounding box
targeted_bbox = [targeted_geospatial_lon_min, targeted_geospatial_lat_min, targeted_geospatial_lon_max, targeted_geospatial_lat_max]  # (minx, miny, maxx, maxy)

# %%
m = folium.Map(location=[39.0, 0], zoom_start=4)
upper_left = [targeted_geospatial_lat_max, targeted_geospatial_lon_min]
upper_right = [targeted_geospatial_lat_max, targeted_geospatial_lon_max]
lower_right = [targeted_geospatial_lat_min, targeted_geospatial_lon_max]
lower_left = [targeted_geospatial_lat_min, targeted_geospatial_lon_min]
edges_ = [upper_left, upper_right, lower_right, lower_left]
m.add_child(folium.vector_layers.Polygon(locations=edges_))
#Zooming closer
m.fit_bounds(edges_, max_zoom=5)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_e02aa2cd71f9403f908ce0002b82fe7e%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_e02aa2cd71f9403f908ce0002b82fe7e%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_e02aa2cd71f9403f908ce0002b82fe7e%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_e02aa2cd71f9403f908ce0002b82fe7e%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B39.0%2C%200.0%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20crs ...

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>WARNING</b>
#
# ***
# If you do not see any map when running the next cell please change your navigator (try chrome!).

# %% [markdown]
# `Run the next cell` to obtain the subset of files with data in such area:

# %%
info['lastLocationInRange'] = info.apply(lastLocationInRange,targeted_bbox=targeted_bbox,axis=1)
condition = info['lastLocationInRange'] == True
subset = info[condition]
subset.transpose()
# Out:
#                                                                         3040   \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                   62.16192
# geospatial_lat_max                                                   62.24062
# geospatial_lon_min                                                  -56.27084
# geospatial_lon_max                                                  -56.06039
# time_coverage_start                                      2021-01-13T00:01:00Z
# time_coverage_end                                        2021-01-13T23:00:00Z
# institution                 National Data Buoy Center (NDBC)  National Oce...
# date_update                                              2021-01-14T01:31:22Z
# data_mode                                                                   R
# parameters                                             DC_REFERENCE DEPH TEMP
# netcdf                                           GL_TS_DB_4402534_20210113.nc
# file_type                                                                  TS
# data_type                                                                  DB
# platform_code                                                         4402534
# wmo_platform_code                                                     4402534
# institution_edmo_code                                                    1463
# last_latitude_observation                                            62.16192
# last_longitude_observation                                          -56.06039
# last_date_observation                                    2021-01-13T23:00:00Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                      True
#
#                                                                         3041   \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                   62.14686
# geospatial_lat_max                                                   62.16160
# geospatial_lon_min                                                  -56.04750
# geospatial_lon_max                                                  -55.77020
# time_coverage_start                                      2021-01-14T00:02:00Z
# time_coverage_end                                        2021-01-14T23:00:00Z
# institution                 National Data Buoy Center (NDBC)  National Oce...
# date_update                                              2021-01-15T01:33:45Z
# data_mode                                                                   R
# parameters                                             DC_REFERENCE DEPH TEMP
# netcdf                                           GL_TS_DB_4402534_20210114.nc
# file_type                                                                  TS
# data_type                                                                  DB
# platform_code                                                         4402534
# wmo_platform_code                                                     4402534
# institution_edmo_code                                                    1463
# last_latitude_observation                                            62.16192
# last_longitude_observation                                          -56.06039
# last_date_observation                                    2021-01-13T23:00:00Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                      True
#
#                                                                         3042   \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                   62.16313
# geospatial_lat_max                                                   62.21375
# geospatial_lon_min                                                  -55.76954
# geospatial_lon_max                                                  -55.67218
# time_coverage_start                                      2021-01-15T00:00:00Z
# time_coverage_end                                        2021-01-15T23:00:00Z
# institution                 National Data Buoy Center (NDBC)  National Oce...
# date_update                                              2021-01-16T01:35:02Z
# data_mode                                                                   R
# parameters                                             DC_REFERENCE DEPH TEMP
# netcdf                                           GL_TS_DB_4402534_20210115.nc
# file_type                                                                  TS
# data_type                                                                  DB
# platform_code                                                         4402534
# wmo_platform_code                                                     4402534
# institution_edmo_code                                                    1463
# last_latitude_observation                                            62.16192
# last_longitude_observation                                          -56.06039
# last_date_observation                                    2021-01-13T23:00:00Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                      True
#
#                                                                         3043   \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                   62.21175
# geospatial_lat_max                                                   62.31928
# geospatial_lon_min                                                  -55.68790
# geospatial_lon_max                                                  -55.60779
# time_coverage_start                                      2021-01-16T00:01:00Z
# time_coverage_end                                        2021-01-16T23:00:00Z
# institution                 National Data Buoy Center (NDBC)  National Oce...
# date_update                                              2021-01-17T01:30:03Z
# data_mode                                                                   R
# parameters                                             DC_REFERENCE DEPH TEMP
# netcdf                                           GL_TS_DB_4402534_20210116.nc
# file_type                                                                  TS
# data_type                                                                  DB
# platform_code                                                         4402534
# wmo_platform_code                                                     4402534
# institution_edmo_code                                                    1463
# last_latitude_observation                                            62.16192
# last_longitude_observation                                          -56.06039
# last_date_observation                                    2021-01-13T23:00:00Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                      True
#
#                                                                         3044   \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                   62.31160
# geospatial_lat_max                                                   62.41868
# geospatial_lon_min                                                  -55.76512
# geospatial_lon_max                                                  -55.63796
# time_coverage_start                                      2021-01-17T00:00:00Z
# time_coverage_end                                        2021-01-17T23:00:00Z
# institution                 National Data Buoy Center (NDBC)  National Oce...
# date_update                                              2021-01-18T01:31:20Z
# data_mode                                                                   R
# parameters                                             DC_REFERENCE DEPH TEMP
# netcdf                                           GL_TS_DB_4402534_20210117.nc
# file_type                                                                  TS
# data_type                                                                  DB
# platform_code                                                         4402534
# wmo_platform_code                                                     4402534
# institution_edmo_code                                                    1463
# last_latitude_observation                                            62.16192
# last_longitude_observation                                          -56.06039
# last_date_observation                                    2021-01-13T23:00:00Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                      True
#
#                                                                         3045   \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                   62.43013
# geospatial_lat_max                                                   62.46912
# geospatial_lon_min                                                  -55.85101
# geospatial_lon_max                                                  -55.75055
# time_coverage_start                                      2021-01-18T00:00:00Z
# time_coverage_end                                        2021-01-18T23:00:00Z
# institution                 National Data Buoy Center (NDBC)  National Oce...
# date_update                                              2021-01-19T01:32:00Z
# data_mode                                                                   R
# parameters                                             DC_REFERENCE DEPH TEMP
# netcdf                                           GL_TS_DB_4402534_20210118.nc
# file_type                                                                  TS
# data_type                                                                  DB
# platform_code                                                         4402534
# wmo_platform_code                                                     4402534
# institution_edmo_code                                                    1463
# last_latitude_observation                                            62.16192
# last_longitude_observation                                          -56.06039
# last_date_observation                                    2021-01-13T23:00:00Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                      True
#
#                                                                         3046   \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                   62.44384
# geospatial_lat_max                                                   62.46471
# geospatial_lon_min                                                  -55.79998
# geospatial_lon_max                                                  -55.66914
# time_coverage_start                                      2021-01-19T00:00:00Z
# time_coverage_end                                        2021-01-19T23:00:00Z
# institution                 National Data Buoy Center (NDBC)  National Oce...
# date_update                                              2021-01-20T01:34:00Z
# data_mode                                                                   R
# parameters                                             DC_REFERENCE DEPH TEMP
# netcdf                                           GL_TS_DB_4402534_20210119.nc
# file_type                                                                  TS
# data_type                                                                  DB
# platform_code                                                         4402534
# wmo_platform_code                                                     4402534
# institution_edmo_code                                                    1463
# last_latitude_observation                                            62.16192
# last_longitude_observation                                          -56.06039
# last_date_observation                                    2021-01-13T23:00:00Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                      True
#
#                                                                         3047   \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                   62.46098
# geospatial_lat_max                                                   62.53334
# geospatial_lon_min                                                  -55.65058
# geospatial_lon_max                                                  -55.50704
# time_coverage_start                                      2021-01-20T00:00:00Z
# time_coverage_end                                        2021-01-20T23:00:00Z
# institution                 National Data Buoy Center (NDBC)  National Oce...
# date_update                                              2021-01-21T01:35:15Z
# data_mode                                                                   R
# parameters                                             DC_REFERENCE DEPH TEMP
# netcdf                                           GL_TS_DB_4402534_20210120.nc
# file_type                                                                  TS
# data_type                                                                  DB
# platform_code                                                         4402534
# wmo_platform_code                                                     4402534
# institution_edmo_code                                                    1463
# last_latitude_observation                                            62.16192
# last_longitude_observation                                          -56.06039
# last_date_observation                                    2021-01-13T23:00:00Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                      True
#
#                                                                         3048   \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                   62.49770
# geospatial_lat_max                                                   62.52604
# geospatial_lon_min                                                  -55.53377
# geospatial_lon_max                                                  -55.37912
# time_coverage_start                                      2021-01-21T00:00:00Z
# time_coverage_end                                        2021-01-21T23:00:00Z
# institution                 National Data Buoy Center (NDBC)  National Oce...
# date_update                                              2021-01-22T01:44:48Z
# data_mode                                                                   R
# parameters                                             DC_REFERENCE DEPH TEMP
# netcdf                                           GL_TS_DB_4402534_20210121.nc
# file_type                                                                  TS
# data_type                                                                  DB
# platform_code                                                         4402534
# wmo_platform_code                                                     4402534
# institution_edmo_code                                                    1463
# last_latitude_observation                                            62.16192
# last_longitude_observation                                          -56.06039
# last_date_observation                                    2021-01-13T23:00:00Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                      True
#
#                                                                         3049   \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                   62.52895
# geospatial_lat_max                                                   62.59060
# geospatial_lon_min                                                  -55.37928
# geospatial_lon_max                                                  -55.29599
# time_coverage_start                                      2021-01-22T00:00:00Z
# time_coverage_end                                        2021-01-22T23:00:00Z
# institution                 National Data Buoy Center (NDBC)  National Oce...
# date_update                                              2021-01-23T01:34:23Z
# data_mode                                                                   R
# parameters                                             DC_REFERENCE DEPH TEMP
# netcdf                                           GL_TS_DB_4402534_20210122.nc
# file_type                                                                  TS
# data_type                                                                  DB
# platform_code                                                         4402534
# wmo_platform_code                                                     4402534
# institution_edmo_code                                                    1463
# last_latitude_observation                                            62.16192
# last_longitude_observation                                          -56.06039
# last_date_observation                                    2021-01-13T23:00:00Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                      True
#
#                             ...  \
# # product_id                ...
# file_name                   ...
# geospatial_lat_min          ...
# geospatial_lat_max          ...
# geospatial_lon_min          ...
# geospatial_lon_max          ...
# time_coverage_start         ...
# time_coverage_end           ...
# institution                 ...
# date_update                 ...
# data_mode                   ...
# parameters                  ...
# netcdf                      ...
# file_type                   ...
# data_type                   ...
# platform_code               ...
# wmo_platform_code           ...
# institution_edmo_code       ...
# last_latitude_observation   ...
# last_longitude_observation  ...
# last_date_observation       ...
# timeOverlap                 ...
# spatialOverlap              ...
# lastLocationInRange         ...
#
#                                                                         34196  \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                    45.1493
# geospatial_lat_max                                                    64.2284
# geospatial_lon_min                                                   -60.5354
# geospatial_lon_max                                                   -51.0801
# time_coverage_start                                      2004-05-18T18:00:00Z
# time_coverage_end                                        2004-07-15T23:11:00Z
# institution                                       Fisheries and Oceans Canada
# date_update                                              2019-05-07T14:56:26Z
# data_mode                                                                   D
# parameters                  PRES_ADJUSTED DC_REFERENCE PRES TEMP_ADJUSTED ...
# netcdf                                                   GL_PR_SM_EXSM0171.nc
# file_type                                                                  PR
# data_type                                                                  SM
# platform_code                                                        EXSM0171
# wmo_platform_code
# institution_edmo_code                                                    1979
# last_latitude_observation                                             64.1803
# last_longitude_observation                                           -60.5354
# last_date_observation                                    2004-07-15T23:11:00Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                      True
#
#                                                                         34203  \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                    63.3958
# geospatial_lat_max                                                    74.7722
# geospatial_lon_min                                                   -96.1295
# geospatial_lon_max                                                   -58.1205
# time_coverage_start                                      2013-08-30T03:08:59Z
# time_coverage_end                                        2013-11-28T01:24:59Z
# institution                                       Fisheries and Oceans Canada
# date_update                                              2019-05-07T14:57:27Z
# data_mode                                                                   D
# parameters                  PRES_ADJUSTED DC_REFERENCE PRES TEMP_ADJUSTED ...
# netcdf                                                   GL_PR_SM_EXSM0193.nc
# file_type                                                                  PR
# data_type                                                                  SM
# platform_code                                                        EXSM0193
# wmo_platform_code
# institution_edmo_code                                                    1979
# last_latitude_observation                                             63.4855
# last_longitude_observation                                           -64.2635
# last_date_observation                                    2013-11-28T01:24:59Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                      True
#
#                                                                         34204  \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                    63.7486
# geospatial_lat_max                                                    75.9449
# geospatial_lon_min                                                   -96.5097
# geospatial_lon_max                                                   -54.3704
# time_coverage_start                                      2013-08-28T23:14:00Z
# time_coverage_end                                        2013-11-01T13:10:59Z
# institution                                       Fisheries and Oceans Canada
# date_update                                              2019-05-07T14:57:27Z
# data_mode                                                                   D
# parameters                  PRES_ADJUSTED DC_REFERENCE PRES TEMP_ADJUSTED ...
# netcdf                                                   GL_PR_SM_EXSM0194.nc
# file_type                                                                  PR
# data_type                                                                  SM
# platform_code                                                        EXSM0194
# wmo_platform_code
# institution_edmo_code                                                    1979
# last_latitude_observation                                             63.7486
# last_longitude_observation                                           -57.2939
# last_date_observation                                    2013-11-01T13:10:59Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                      True
#
#                                                                         34213  \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                    65.5931
# geospatial_lat_max                                                    74.9861
# geospatial_lon_min                                                   -99.0914
# geospatial_lon_max                                                   -59.6115
# time_coverage_start                                      2012-08-01T02:31:00Z
# time_coverage_end                                        2013-03-17T11:29:00Z
# institution                                       Fisheries and Oceans Canada
# date_update                                              2019-05-07T14:59:25Z
# data_mode                                                                   D
# parameters                  PRES_ADJUSTED DC_REFERENCE PRES TEMP_ADJUSTED ...
# netcdf                                                   GL_PR_SM_EXSM0226.nc
# file_type                                                                  PR
# data_type                                                                  SM
# platform_code                                                        EXSM0226
# wmo_platform_code
# institution_edmo_code                                                    1979
# last_latitude_observation                                             65.7260
# last_longitude_observation                                           -62.4358
# last_date_observation                                    2013-03-17T11:29:00Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                      True
#
#                                                                         34302  \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                      59.10
# geospatial_lat_max                                                      65.70
# geospatial_lon_min                                                     -56.70
# geospatial_lon_max                                                     -27.05
# time_coverage_start                                      1998-04-05T09:15:00Z
# time_coverage_end                                        2000-01-19T14:59:00Z
# institution                                           United states (Unknown)
# date_update                                              2019-09-28T15:39:34Z
# data_mode                                                                   R
# parameters                                   DC_REFERENCE PRES DATA_MODE TEMP
# netcdf                                                      GL_PR_XX_62735.nc
# file_type                                                                  PR
# data_type                                                                  XX
# platform_code                                                           62735
# wmo_platform_code                                                       62735
# institution_edmo_code
# last_latitude_observation                                               65.70
# last_longitude_observation                                             -56.70
# last_date_observation                                    2000-01-19T14:59:00Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                      True
#
#                                                                         34310  \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                      58.90
# geospatial_lat_max                                                      65.53
# geospatial_lon_min                                                     -57.48
# geospatial_lon_max                                                     -21.46
# time_coverage_start                                      1998-03-24T14:13:00Z
# time_coverage_end                                        2000-02-06T05:15:00Z
# institution                                           United states (Unknown)
# date_update                                              2019-09-28T15:39:36Z
# data_mode                                                                   R
# parameters                                   DC_REFERENCE PRES DATA_MODE TEMP
# netcdf                                                      GL_PR_XX_62744.nc
# file_type                                                                  PR
# data_type                                                                  XX
# platform_code                                                           62744
# wmo_platform_code                                                       62744
# institution_edmo_code
# last_latitude_observation                                               63.55
# last_longitude_observation                                             -57.48
# last_date_observation                                    2000-02-06T05:15:00Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                      True
#
#                                                                         34311  \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                     52.550
# geospatial_lat_max                                                     64.353
# geospatial_lon_min                                                    -55.914
# geospatial_lon_max                                                    -28.450
# time_coverage_start                                      1998-11-05T12:14:00Z
# time_coverage_end                                        2002-09-25T15:45:00Z
# institution                                           United states (Unknown)
# date_update                                              2019-09-28T15:39:34Z
# data_mode                                                                   R
# parameters                                   DC_REFERENCE PRES DATA_MODE TEMP
# netcdf                                                      GL_PR_XX_62746.nc
# file_type                                                                  PR
# data_type                                                                  XX
# platform_code                                                           62746
# wmo_platform_code                                                       62746
# institution_edmo_code
# last_latitude_observation                                              64.353
# last_longitude_observation                                            -52.489
# last_date_observation                                    2002-09-25T15:45:00Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                      True
#
#                                                                         34316  \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                      60.48
# geospatial_lat_max                                                      65.13
# geospatial_lon_min                                                     -54.92
# geospatial_lon_max                                                     -29.78
# time_coverage_start                                      1998-02-26T09:49:00Z
# time_coverage_end                                        1998-10-04T08:14:00Z
# institution                                           United states (Unknown)
# date_update                                              2019-09-28T15:41:12Z
# data_mode                                                                   R
# parameters                                   DC_REFERENCE PRES DATA_MODE TEMP
# netcdf                                                      GL_PR_XX_64099.nc
# file_type                                                                  PR
# data_type                                                                  XX
# platform_code                                                           64099
# wmo_platform_code                                                       64099
# institution_edmo_code
# last_latitude_observation                                               62.79
# last_longitude_observation                                             -54.92
# last_date_observation                                    1998-10-04T08:14:00Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                      True
#
#                                                                         34327  \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                      62.01
# geospatial_lat_max                                                      62.70
# geospatial_lon_min                                                     -59.51
# geospatial_lon_max                                                     -58.80
# time_coverage_start                                      1998-04-04T18:44:00Z
# time_coverage_end                                        1998-04-24T10:49:00Z
# institution                                 Naval Oceanographic Office (NAVO)
# date_update                                              2019-09-28T15:42:00Z
# data_mode                                                                   R
# parameters                                   DC_REFERENCE PRES DATA_MODE TEMP
# netcdf                                                      GL_PR_XX_64680.nc
# file_type                                                                  PR
# data_type                                                                  XX
# platform_code                                                           64680
# wmo_platform_code                                                       64680
# institution_edmo_code                                                    3577
# last_latitude_observation                                               62.49
# last_longitude_observation                                             -59.51
# last_date_observation                                    1998-04-24T10:49:00Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                      True
#
#                                                                         34355
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                     49.003
# geospatial_lat_max                                                     66.232
# geospatial_lon_min                                                    -69.967
# geospatial_lon_max                                                    -49.985
# time_coverage_start                                      2012-07-20T12:01:00Z
# time_coverage_end                                        2014-09-24T07:19:00Z
# institution                                               Unknown institution
# date_update                                              2019-10-06T08:07:25Z
# data_mode                                                                   R
# parameters                              PSAL DC_REFERENCE DEPH DATA_MODE TEMP
# netcdf                                                       GL_PR_XX_VOLZ.nc
# file_type                                                                  PR
# data_type                                                                  XX
# platform_code                                                            VOLZ
# wmo_platform_code                                                        VOLZ
# institution_edmo_code
# last_latitude_observation                                              62.558
# last_longitude_observation                                            -63.009
# last_date_observation                                    2014-09-24T07:19:00Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                      True
#
# [24 rows x 946 columns]

# %% [markdown]
# Let's check now if the last position reported by the platform that produced those files truely overlaps with the targeted area!: `run the next cells`

# %%
numberOfFiles = 300 #we will check just a sample of files not all

# %%
m = folium.Map(location=[39.3, 0], zoom_start=4)
m.add_child(folium.vector_layers.Polygon(locations=edges_))
for platform, files in subset[:numberOfFiles].groupby(['platform_code', 'data_type']):
    #Last reported position to map as marker
    i = len(files)-1
    m.add_child(folium.Marker([files.iloc[i]['last_latitude_observation'], files.iloc[i]['last_longitude_observation']], popup=files.iloc[i]['platform_code']+' last position' ))
#Zooming closer
m.fit_bounds(edges, max_zoom=3)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_d7ac0a8dd2d14c4b83b518c00d0ae753%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_d7ac0a8dd2d14c4b83b518c00d0ae753%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_d7ac0a8dd2d14c4b83b518c00d0ae753%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_d7ac0a8dd2d14c4b83b518c00d0ae753%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B39.3%2C%200.0%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20crs ...

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>WARNING</b>
#
# ***
# If you do not see any map when running the next cell please change your navigator (try chrome!).

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>TIP</b>
#
# ***
# To check if everything went well, just check if the markers (last platform position) is indeed within the one you were interested in (targeted bbox)

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>IMPORTANT</b>
#
# ***
# If you are not satisfied with the resulting output please revisit the [definition of the lastLocationInRange](#LocationInRange) function and replace the rule applied (`contains`) by any of the available ones [here](https://shapely.readthedocs.io/en/stable/manual.html#binary-predicates)

# %% [markdown]
# #### 4.1.5. By data type

# %% [markdown]
# Let's look for files produced by a certain data type.<br>`Please set a data type` next `and run the cell`:

# %%
targeted_data_type = 'PF' # try others: TG for Tide Gauges, PF for profilers etc =>Product User Manual: https://archimer.ifremer.fr/doc/00324/43494/

# %% [markdown]
# `Run the next cell` to obtain just the files reported by such data type:

# %%
condition = info['data_type'] == targeted_data_type
subset = info[condition]
subset.transpose()
# Out:
#                                                                         1389   \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                   69.10792
# geospatial_lat_max                                                   69.10792
# geospatial_lon_min                                                    6.21510
# geospatial_lon_max                                                    6.21510
# time_coverage_start                                      2021-01-13T11:58:00Z
# time_coverage_end                                        2021-01-13T11:58:00Z
# institution                                                         Euro-Argo
# date_update                                              2021-01-13T15:01:25Z
# data_mode                                                                   R
# parameters                  PRES VERTICAL_SAMPLING_SCHEME PSAL DC_REFERENC...
# netcdf                                           GL_PR_PF_3901873_20210113.nc
# file_type                                                                  PR
# data_type                                                                  PF
# platform_code                                                         3901873
# wmo_platform_code                                                     3901873
# institution_edmo_code                                                    4614
# last_latitude_observation                                            69.10792
# last_longitude_observation                                            6.21510
# last_date_observation                                    2021-01-13T11:58:00Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
#                                                                         1390   \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                   69.27847
# geospatial_lat_max                                                   69.27847
# geospatial_lon_min                                                    7.43758
# geospatial_lon_max                                                    7.43758
# time_coverage_start                                      2021-01-23T11:54:00Z
# time_coverage_end                                        2021-01-23T11:54:00Z
# institution                                                         Euro-Argo
# date_update                                              2021-01-23T14:01:46Z
# data_mode                                                                   R
# parameters                  PRES VERTICAL_SAMPLING_SCHEME PSAL DC_REFERENC...
# netcdf                                           GL_PR_PF_3901873_20210123.nc
# file_type                                                                  PR
# data_type                                                                  PF
# platform_code                                                         3901873
# wmo_platform_code                                                     3901873
# institution_edmo_code                                                    4614
# last_latitude_observation                                            69.10792
# last_longitude_observation                                            6.21510
# last_date_observation                                    2021-01-13T11:58:00Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
#                                                                         1391   \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                   69.61020
# geospatial_lat_max                                                   69.61020
# geospatial_lon_min                                                    7.42179
# geospatial_lon_max                                                    7.42179
# time_coverage_start                                      2021-02-02T11:42:00Z
# time_coverage_end                                        2021-02-02T11:42:00Z
# institution                                                         Euro-Argo
# date_update                                              2021-02-02T14:02:06Z
# data_mode                                                                   R
# parameters                  PRES VERTICAL_SAMPLING_SCHEME PSAL DC_REFERENC...
# netcdf                                           GL_PR_PF_3901873_20210202.nc
# file_type                                                                  PR
# data_type                                                                  PF
# platform_code                                                         3901873
# wmo_platform_code                                                     3901873
# institution_edmo_code                                                    4614
# last_latitude_observation                                            69.10792
# last_longitude_observation                                            6.21510
# last_date_observation                                    2021-01-13T11:58:00Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
#                                                                         1392   \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                   67.27830
# geospatial_lat_max                                                   67.99055
# geospatial_lon_min                                                   -5.21096
# geospatial_lon_max                                                   -4.96815
# time_coverage_start                                      2016-09-04T06:31:00Z
# time_coverage_end                                        2016-09-26T11:48:00Z
# institution                                                         Euro-Argo
# date_update                                              2020-09-10T12:11:50Z
# data_mode                                                                   D
# parameters                  PSAL_ADJUSTED_ERROR TEMP_ADJUSTED PRES_ADJUSTE...
# netcdf                                             GL_PR_PF_3901873_201609.nc
# file_type                                                                  PR
# data_type                                                                  PF
# platform_code                                                         3901873
# wmo_platform_code                                                     3901873
# institution_edmo_code                                                    4614
# last_latitude_observation                                            69.10792
# last_longitude_observation                                            6.21510
# last_date_observation                                    2021-01-13T11:58:00Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
#                                                                         1393   \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                   66.49991
# geospatial_lat_max                                                   66.93770
# geospatial_lon_min                                                   -4.26624
# geospatial_lon_max                                                   -3.48365
# time_coverage_start                                      2016-10-06T11:57:00Z
# time_coverage_end                                        2016-10-26T11:54:00Z
# institution                                                         Euro-Argo
# date_update                                              2020-09-10T12:12:00Z
# data_mode                                                                   D
# parameters                  PSAL_ADJUSTED_ERROR TEMP_ADJUSTED PRES_ADJUSTE...
# netcdf                                             GL_PR_PF_3901873_201610.nc
# file_type                                                                  PR
# data_type                                                                  PF
# platform_code                                                         3901873
# wmo_platform_code                                                     3901873
# institution_edmo_code                                                    4614
# last_latitude_observation                                            69.10792
# last_longitude_observation                                            6.21510
# last_date_observation                                    2021-01-13T11:58:00Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
#                                                                         1394   \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                   66.47352
# geospatial_lat_max                                                   66.78110
# geospatial_lon_min                                                   -3.32691
# geospatial_lon_max                                                   -2.84020
# time_coverage_start                                      2016-11-05T11:54:00Z
# time_coverage_end                                        2016-11-25T11:57:00Z
# institution                                                         Euro-Argo
# date_update                                              2020-09-10T12:12:00Z
# data_mode                                                                   D
# parameters                  PSAL_ADJUSTED_ERROR TEMP_ADJUSTED PRES_ADJUSTE...
# netcdf                                             GL_PR_PF_3901873_201611.nc
# file_type                                                                  PR
# data_type                                                                  PF
# platform_code                                                         3901873
# wmo_platform_code                                                     3901873
# institution_edmo_code                                                    4614
# last_latitude_observation                                            69.10792
# last_longitude_observation                                            6.21510
# last_date_observation                                    2021-01-13T11:58:00Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
#                                                                         1395   \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                   66.93157
# geospatial_lat_max                                                   67.26809
# geospatial_lon_min                                                   -2.82345
# geospatial_lon_max                                                   -1.99415
# time_coverage_start                                      2016-12-05T11:57:00Z
# time_coverage_end                                        2016-12-25T11:54:00Z
# institution                                                         Euro-Argo
# date_update                                              2020-09-10T12:12:53Z
# data_mode                                                                   D
# parameters                  PSAL_ADJUSTED_ERROR TEMP_ADJUSTED PRES_ADJUSTE...
# netcdf                                             GL_PR_PF_3901873_201612.nc
# file_type                                                                  PR
# data_type                                                                  PF
# platform_code                                                         3901873
# wmo_platform_code                                                     3901873
# institution_edmo_code                                                    4614
# last_latitude_observation                                            69.10792
# last_longitude_observation                                            6.21510
# last_date_observation                                    2021-01-13T11:58:00Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
#                                                                         1396   \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                   67.61547
# geospatial_lat_max                                                   67.91934
# geospatial_lon_min                                                   -1.61250
# geospatial_lon_max                                                   -1.03738
# time_coverage_start                                      2017-01-04T11:59:00Z
# time_coverage_end                                        2017-01-24T11:53:00Z
# institution                                                         Euro-Argo
# date_update                                              2020-09-10T12:12:37Z
# data_mode                                                                   D
# parameters                  PSAL_ADJUSTED_ERROR TEMP_ADJUSTED PRES_ADJUSTE...
# netcdf                                             GL_PR_PF_3901873_201701.nc
# file_type                                                                  PR
# data_type                                                                  PF
# platform_code                                                         3901873
# wmo_platform_code                                                     3901873
# institution_edmo_code                                                    4614
# last_latitude_observation                                            69.10792
# last_longitude_observation                                            6.21510
# last_date_observation                                    2021-01-13T11:58:00Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
#                                                                         1397   \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                   67.88699
# geospatial_lat_max                                                   68.11547
# geospatial_lon_min                                                   -1.60741
# geospatial_lon_max                                                   -1.43255
# time_coverage_start                                      2017-02-03T11:48:00Z
# time_coverage_end                                        2017-02-23T11:57:00Z
# institution                                                         Euro-Argo
# date_update                                              2020-09-10T12:12:37Z
# data_mode                                                                   D
# parameters                  PSAL_ADJUSTED_ERROR TEMP_ADJUSTED PRES_ADJUSTE...
# netcdf                                             GL_PR_PF_3901873_201702.nc
# file_type                                                                  PR
# data_type                                                                  PF
# platform_code                                                         3901873
# wmo_platform_code                                                     3901873
# institution_edmo_code                                                    4614
# last_latitude_observation                                            69.10792
# last_longitude_observation                                            6.21510
# last_date_observation                                    2021-01-13T11:58:00Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
#                                                                         1398   \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                   67.82950
# geospatial_lat_max                                                   68.03568
# geospatial_lon_min                                                   -1.16950
# geospatial_lon_max                                                   -1.10666
# time_coverage_start                                      2017-03-05T11:57:00Z
# time_coverage_end                                        2017-03-25T11:49:00Z
# institution                                                         Euro-Argo
# date_update                                              2020-09-10T12:12:37Z
# data_mode                                                                   D
# parameters                  PSAL_ADJUSTED_ERROR TEMP_ADJUSTED PRES_ADJUSTE...
# netcdf                                             GL_PR_PF_3901873_201703.nc
# file_type                                                                  PR
# data_type                                                                  PF
# platform_code                                                         3901873
# wmo_platform_code                                                     3901873
# institution_edmo_code                                                    4614
# last_latitude_observation                                            69.10792
# last_longitude_observation                                            6.21510
# last_date_observation                                    2021-01-13T11:58:00Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
#                             ...  \
# # product_id                ...
# file_name                   ...
# geospatial_lat_min          ...
# geospatial_lat_max          ...
# geospatial_lon_min          ...
# geospatial_lon_max          ...
# time_coverage_start         ...
# time_coverage_end           ...
# institution                 ...
# date_update                 ...
# data_mode                   ...
# parameters                  ...
# netcdf                      ...
# file_type                   ...
# data_type                   ...
# platform_code               ...
# wmo_platform_code           ...
# institution_edmo_code       ...
# last_latitude_observation   ...
# last_longitude_observation  ...
# last_date_observation       ...
# timeOverlap                 ...
# spatialOverlap              ...
# lastLocationInRange         ...
#
#                                                                         34048  \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                     73.166
# geospatial_lat_max                                                     78.188
# geospatial_lon_min                                                     -5.291
# geospatial_lon_max                                                      7.613
# time_coverage_start                                      2007-08-07T05:53:35Z
# time_coverage_end                                        2009-12-24T07:15:47Z
# institution                  University of Hamburg  Institute of Oceanography
# date_update                                              2019-06-29T13:15:52Z
# data_mode                                                                   D
# parameters                  PSAL PRES_ADJUSTED VERTICAL_SAMPLING_SCHEME PS...
# netcdf                                                    GL_PR_PF_7900169.nc
# file_type                                                                  PR
# data_type                                                                  PF
# platform_code                                                         7900169
# wmo_platform_code                                                     7900169
# institution_edmo_code                                                    1156
# last_latitude_observation                                              78.188
# last_longitude_observation                                              5.068
# last_date_observation                                    2009-12-24T07:15:47Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
#                                                                         34049  \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                     68.870
# geospatial_lat_max                                                     77.241
# geospatial_lon_min                                                    -18.648
# geospatial_lon_max                                                      5.694
# time_coverage_start                                      2007-08-06T20:24:16Z
# time_coverage_end                                        2010-01-22T20:23:20Z
# institution                  University of Hamburg  Institute of Oceanography
# date_update                                              2020-01-13T06:50:24Z
# data_mode                                                                   M
# parameters                  PSAL PRES_ADJUSTED VERTICAL_SAMPLING_SCHEME PS...
# netcdf                                                    GL_PR_PF_7900170.nc
# file_type                                                                  PR
# data_type                                                                  PF
# platform_code                                                         7900170
# wmo_platform_code                                                     7900170
# institution_edmo_code                                                    1156
# last_latitude_observation                                              68.907
# last_longitude_observation                                            -17.424
# last_date_observation                                    2010-01-22T20:23:20Z
# timeOverlap                                                             False
# spatialOverlap                                                           True
# lastLocationInRange                                                     False
#
#                                                                         34050  \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                     74.261
# geospatial_lat_max                                                     75.613
# geospatial_lon_min                                                     -9.149
# geospatial_lon_max                                                      1.589
# time_coverage_start                                      2007-08-06T17:59:45Z
# time_coverage_end                                        2008-06-01T15:21:55Z
# institution                  University of Hamburg  Institute of Oceanography
# date_update                                              2019-12-15T18:21:33Z
# data_mode                                                                   M
# parameters                  PSAL PRES_ADJUSTED VERTICAL_SAMPLING_SCHEME PS...
# netcdf                                                    GL_PR_PF_7900171.nc
# file_type                                                                  PR
# data_type                                                                  PF
# platform_code                                                         7900171
# wmo_platform_code                                                     7900171
# institution_edmo_code                                                    1156
# last_latitude_observation                                              74.907
# last_longitude_observation                                             -9.149
# last_date_observation                                    2008-06-01T15:21:55Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
#                                                                         34051  \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                     73.589
# geospatial_lat_max                                                     76.099
# geospatial_lon_min                                                     -5.003
# geospatial_lon_max                                                      2.636
# time_coverage_start                                      2007-08-09T03:13:01Z
# time_coverage_end                                        2009-03-01T03:32:08Z
# institution                  University of Hamburg  Institute of Oceanography
# date_update                                              2019-06-29T13:15:52Z
# data_mode                                                                   D
# parameters                  PSAL PRES_ADJUSTED VERTICAL_SAMPLING_SCHEME PS...
# netcdf                                                    GL_PR_PF_7900172.nc
# file_type                                                                  PR
# data_type                                                                  PF
# platform_code                                                         7900172
# wmo_platform_code                                                     7900172
# institution_edmo_code                                                    1156
# last_latitude_observation                                              75.051
# last_longitude_observation                                              0.165
# last_date_observation                                    2009-03-01T03:32:08Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
#                                                                         34052  \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                     63.058
# geospatial_lat_max                                                     71.555
# geospatial_lon_min                                                     -7.456
# geospatial_lon_max                                                      3.259
# time_coverage_start                                      2007-08-23T12:00:52Z
# time_coverage_end                                        2010-06-18T15:18:25Z
# institution                  University of Hamburg  Institute of Oceanography
# date_update                                              2019-09-14T17:29:21Z
# data_mode                                                                   D
# parameters                  PSAL PRES_ADJUSTED VERTICAL_SAMPLING_SCHEME PS...
# netcdf                                                    GL_PR_PF_7900173.nc
# file_type                                                                  PR
# data_type                                                                  PF
# platform_code                                                         7900173
# wmo_platform_code                                                     7900173
# institution_edmo_code                                                    1156
# last_latitude_observation                                              65.188
# last_longitude_observation                                              0.066
# last_date_observation                                    2010-06-18T15:18:25Z
# timeOverlap                                                             False
# spatialOverlap                                                           True
# lastLocationInRange                                                     False
#
#                                                                         34053  \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                     66.449
# geospatial_lat_max                                                     72.005
# geospatial_lon_min                                                     -6.427
# geospatial_lon_max                                                      8.135
# time_coverage_start                                      2007-08-23T19:03:12Z
# time_coverage_end                                        2009-04-04T18:57:50Z
# institution                  University of Hamburg  Institute of Oceanography
# date_update                                              2019-09-14T17:29:21Z
# data_mode                                                                   D
# parameters                  PSAL PRES_ADJUSTED VERTICAL_SAMPLING_SCHEME PS...
# netcdf                                                    GL_PR_PF_7900174.nc
# file_type                                                                  PR
# data_type                                                                  PF
# platform_code                                                         7900174
# wmo_platform_code                                                     7900174
# institution_edmo_code                                                    1156
# last_latitude_observation                                              66.750
# last_longitude_observation                                             -4.969
# last_date_observation                                    2009-04-04T18:57:50Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
#                                                                         34054  \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                     65.264
# geospatial_lat_max                                                     70.860
# geospatial_lon_min                                                     -1.783
# geospatial_lon_max                                                     13.692
# time_coverage_start                                      2007-08-24T18:44:39Z
# time_coverage_end                                        2010-08-08T21:35:28Z
# institution                  University of Hamburg  Institute of Oceanography
# date_update                                              2020-01-13T06:50:24Z
# data_mode                                                                   D
# parameters                  PSAL PRES_ADJUSTED VERTICAL_SAMPLING_SCHEME PS...
# netcdf                                                    GL_PR_PF_7900175.nc
# file_type                                                                  PR
# data_type                                                                  PF
# platform_code                                                         7900175
# wmo_platform_code                                                     7900175
# institution_edmo_code                                                    1156
# last_latitude_observation                                              69.816
# last_longitude_observation                                              2.217
# last_date_observation                                    2010-08-08T21:35:28Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
#                                                                         34055  \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                     60.220
# geospatial_lat_max                                                     69.727
# geospatial_lon_min                                                    -13.961
# geospatial_lon_max                                                      1.162
# time_coverage_start                                      2007-08-31T10:19:11Z
# time_coverage_end                                        2011-12-08T13:28:27Z
# institution                  University of Hamburg  Institute of Oceanography
# date_update                                              2019-09-14T17:29:24Z
# data_mode                                                                   D
# parameters                  PSAL PRES_ADJUSTED VERTICAL_SAMPLING_SCHEME PS...
# netcdf                                                    GL_PR_PF_7900176.nc
# file_type                                                                  PR
# data_type                                                                  PF
# platform_code                                                         7900176
# wmo_platform_code                                                     7900176
# institution_edmo_code                                                    1156
# last_latitude_observation                                              62.087
# last_longitude_observation                                            -10.614
# last_date_observation                                    2011-12-08T13:28:27Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
#                                                                         34056  \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                     62.929
# geospatial_lat_max                                                     72.145
# geospatial_lon_min                                                    -15.509
# geospatial_lon_max                                                     14.768
# time_coverage_start                                      2007-08-31T13:47:49Z
# time_coverage_end                                        2014-12-22T18:01:58Z
# institution                  University of Hamburg  Institute of Oceanography
# date_update                                              2020-07-06T04:29:03Z
# data_mode                                                                   D
# parameters                  PSAL PRES_ADJUSTED VERTICAL_SAMPLING_SCHEME PS...
# netcdf                                                    GL_PR_PF_7900177.nc
# file_type                                                                  PR
# data_type                                                                  PF
# platform_code                                                         7900177
# wmo_platform_code                                                     7900177
# institution_edmo_code                                                    1156
# last_latitude_observation                                              70.274
# last_longitude_observation                                              8.545
# last_date_observation                                    2014-12-22T18:01:58Z
# timeOverlap                                                             False
# spatialOverlap                                                           True
# lastLocationInRange                                                     False
#
#                                                                         34057
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                     73.269
# geospatial_lat_max                                                     78.198
# geospatial_lon_min                                                     -5.772
# geospatial_lon_max                                                      5.471
# time_coverage_start                                      2007-08-05T21:14:09Z
# time_coverage_end                                        2010-08-19T23:49:57Z
# institution                  University of Hamburg  Institute of Oceanography
# date_update                                              2020-01-13T06:50:24Z
# data_mode                                                                   M
# parameters                  PSAL PRES_ADJUSTED VERTICAL_SAMPLING_SCHEME PS...
# netcdf                                                    GL_PR_PF_7900178.nc
# file_type                                                                  PR
# data_type                                                                  PF
# platform_code                                                         7900178
# wmo_platform_code                                                     7900178
# institution_edmo_code                                                    1156
# last_latitude_observation                                              76.278
# last_longitude_observation                                              3.705
# last_date_observation                                    2010-08-19T23:49:57Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
# [24 rows x 7171 columns]

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>TIP</b>
#
# ***
# To check if the subset only contains the aimed data type (targeted_data_type) just check the `data_type` row of the above output.

# %% [markdown]
# #### 4.1.6. By file type

# %% [markdown]
# Let's look for certain types of files.<br>`Please set a file type` next `and run the cell`:

# %%
targeted_file_type = 'TS' # try others: RV for HF Radar radial velocities...=>Product User Manual: https://archimer.ifremer.fr/doc/00324/43494/

# %% [markdown]
# `Run the next cell` to obtain just the above type of files:

# %%
condition = info['file_type'] == targeted_file_type
subset = info[condition]
subset.transpose()
# Out:
#                                                                         312    \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                     65.698
# geospatial_lat_max                                                     65.698
# geospatial_lon_min                                                    -24.778
# geospatial_lon_max                                                    -24.778
# time_coverage_start                                      2021-01-13T00:00:00Z
# time_coverage_end                                        2021-01-13T23:00:00Z
# institution                 Icelandic Road and Coastal Administration (Ice...
# date_update                                              2021-01-14T03:15:14Z
# data_mode                                                                   M
# parameters                                                     VTZA VAVH DEPH
# netcdf                                         AR_TS_MO_Blakksnes_20210113.nc
# file_type                                                                  TS
# data_type                                                                  MO
# platform_code                                                       Blakksnes
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                    3899
# last_latitude_observation                                              65.698
# last_longitude_observation                                            -24.778
# last_date_observation                                    2021-01-13T23:00:00Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
#                                                                         313    \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                     65.698
# geospatial_lat_max                                                     65.698
# geospatial_lon_min                                                    -24.778
# geospatial_lon_max                                                    -24.778
# time_coverage_start                                      2021-01-14T00:00:00Z
# time_coverage_end                                        2021-01-14T23:00:00Z
# institution                 Icelandic Road and Coastal Administration (Ice...
# date_update                                              2021-01-15T05:15:15Z
# data_mode                                                                   M
# parameters                                                     VTZA VAVH DEPH
# netcdf                                         AR_TS_MO_Blakksnes_20210114.nc
# file_type                                                                  TS
# data_type                                                                  MO
# platform_code                                                       Blakksnes
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                    3899
# last_latitude_observation                                              65.698
# last_longitude_observation                                            -24.778
# last_date_observation                                    2021-01-13T23:00:00Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
#                                                                         314    \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                     65.698
# geospatial_lat_max                                                     65.698
# geospatial_lon_min                                                    -24.778
# geospatial_lon_max                                                    -24.778
# time_coverage_start                                      2021-01-15T00:00:00Z
# time_coverage_end                                        2021-01-15T23:00:00Z
# institution                 Icelandic Road and Coastal Administration (Ice...
# date_update                                              2021-01-16T03:15:15Z
# data_mode                                                                   M
# parameters                                                     VTZA VAVH DEPH
# netcdf                                         AR_TS_MO_Blakksnes_20210115.nc
# file_type                                                                  TS
# data_type                                                                  MO
# platform_code                                                       Blakksnes
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                    3899
# last_latitude_observation                                              65.698
# last_longitude_observation                                            -24.778
# last_date_observation                                    2021-01-13T23:00:00Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
#                                                                         315    \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                     65.698
# geospatial_lat_max                                                     65.698
# geospatial_lon_min                                                    -24.778
# geospatial_lon_max                                                    -24.778
# time_coverage_start                                      2021-01-16T00:00:00Z
# time_coverage_end                                        2021-01-16T23:00:00Z
# institution                 Icelandic Road and Coastal Administration (Ice...
# date_update                                              2021-01-17T03:15:15Z
# data_mode                                                                   M
# parameters                                                     VTZA VAVH DEPH
# netcdf                                         AR_TS_MO_Blakksnes_20210116.nc
# file_type                                                                  TS
# data_type                                                                  MO
# platform_code                                                       Blakksnes
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                    3899
# last_latitude_observation                                              65.698
# last_longitude_observation                                            -24.778
# last_date_observation                                    2021-01-13T23:00:00Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
#                                                                         316    \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                     65.698
# geospatial_lat_max                                                     65.698
# geospatial_lon_min                                                    -24.778
# geospatial_lon_max                                                    -24.778
# time_coverage_start                                      2021-01-17T00:00:00Z
# time_coverage_end                                        2021-01-17T23:00:00Z
# institution                 Icelandic Road and Coastal Administration (Ice...
# date_update                                              2021-01-18T03:15:16Z
# data_mode                                                                   M
# parameters                                                     VTZA VAVH DEPH
# netcdf                                         AR_TS_MO_Blakksnes_20210117.nc
# file_type                                                                  TS
# data_type                                                                  MO
# platform_code                                                       Blakksnes
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                    3899
# last_latitude_observation                                              65.698
# last_longitude_observation                                            -24.778
# last_date_observation                                    2021-01-13T23:00:00Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
#                                                                         317    \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                     65.698
# geospatial_lat_max                                                     65.698
# geospatial_lon_min                                                    -24.778
# geospatial_lon_max                                                    -24.778
# time_coverage_start                                      2021-01-18T00:00:00Z
# time_coverage_end                                        2021-01-18T23:00:00Z
# institution                 Icelandic Road and Coastal Administration (Ice...
# date_update                                              2021-01-19T03:15:16Z
# data_mode                                                                   M
# parameters                                                     VTZA VAVH DEPH
# netcdf                                         AR_TS_MO_Blakksnes_20210118.nc
# file_type                                                                  TS
# data_type                                                                  MO
# platform_code                                                       Blakksnes
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                    3899
# last_latitude_observation                                              65.698
# last_longitude_observation                                            -24.778
# last_date_observation                                    2021-01-13T23:00:00Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
#                                                                         318    \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                     65.698
# geospatial_lat_max                                                     65.698
# geospatial_lon_min                                                    -24.778
# geospatial_lon_max                                                    -24.778
# time_coverage_start                                      2021-01-19T00:00:00Z
# time_coverage_end                                        2021-01-19T23:00:00Z
# institution                 Icelandic Road and Coastal Administration (Ice...
# date_update                                              2021-01-20T03:15:29Z
# data_mode                                                                   M
# parameters                                                     VTZA VAVH DEPH
# netcdf                                         AR_TS_MO_Blakksnes_20210119.nc
# file_type                                                                  TS
# data_type                                                                  MO
# platform_code                                                       Blakksnes
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                    3899
# last_latitude_observation                                              65.698
# last_longitude_observation                                            -24.778
# last_date_observation                                    2021-01-13T23:00:00Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
#                                                                         319    \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                     65.698
# geospatial_lat_max                                                     65.698
# geospatial_lon_min                                                    -24.778
# geospatial_lon_max                                                    -24.778
# time_coverage_start                                      2021-01-20T00:00:00Z
# time_coverage_end                                        2021-01-20T23:00:00Z
# institution                 Icelandic Road and Coastal Administration (Ice...
# date_update                                              2021-01-21T03:15:28Z
# data_mode                                                                   M
# parameters                                                     VTZA VAVH DEPH
# netcdf                                         AR_TS_MO_Blakksnes_20210120.nc
# file_type                                                                  TS
# data_type                                                                  MO
# platform_code                                                       Blakksnes
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                    3899
# last_latitude_observation                                              65.698
# last_longitude_observation                                            -24.778
# last_date_observation                                    2021-01-13T23:00:00Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
#                                                                         320    \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                     65.698
# geospatial_lat_max                                                     65.698
# geospatial_lon_min                                                    -24.778
# geospatial_lon_max                                                    -24.778
# time_coverage_start                                      2021-01-21T00:00:00Z
# time_coverage_end                                        2021-01-21T23:00:00Z
# institution                 Icelandic Road and Coastal Administration (Ice...
# date_update                                              2021-01-22T03:15:28Z
# data_mode                                                                   M
# parameters                                                     VTZA VAVH DEPH
# netcdf                                         AR_TS_MO_Blakksnes_20210121.nc
# file_type                                                                  TS
# data_type                                                                  MO
# platform_code                                                       Blakksnes
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                    3899
# last_latitude_observation                                              65.698
# last_longitude_observation                                            -24.778
# last_date_observation                                    2021-01-13T23:00:00Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
#                                                                         321    \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                     65.698
# geospatial_lat_max                                                     65.698
# geospatial_lon_min                                                    -24.778
# geospatial_lon_max                                                    -24.778
# time_coverage_start                                      2021-01-22T00:00:00Z
# time_coverage_end                                        2021-01-22T23:00:00Z
# institution                 Icelandic Road and Coastal Administration (Ice...
# date_update                                              2021-01-23T03:15:32Z
# data_mode                                                                   M
# parameters                                                     VTZA VAVH DEPH
# netcdf                                         AR_TS_MO_Blakksnes_20210122.nc
# file_type                                                                  TS
# data_type                                                                  MO
# platform_code                                                       Blakksnes
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                    3899
# last_latitude_observation                                              65.698
# last_longitude_observation                                            -24.778
# last_date_observation                                    2021-01-13T23:00:00Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
#                             ...  \
# # product_id                ...
# file_name                   ...
# geospatial_lat_min          ...
# geospatial_lat_max          ...
# geospatial_lon_min          ...
# geospatial_lon_max          ...
# time_coverage_start         ...
# time_coverage_end           ...
# institution                 ...
# date_update                 ...
# data_mode                   ...
# parameters                  ...
# netcdf                      ...
# file_type                   ...
# data_type                   ...
# platform_code               ...
# wmo_platform_code           ...
# institution_edmo_code       ...
# last_latitude_observation   ...
# last_longitude_observation  ...
# last_date_observation       ...
# timeOverlap                 ...
# spatialOverlap              ...
# lastLocationInRange         ...
#
#                                                                         34236  \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                   52.01670
# geospatial_lat_max                                                   63.20000
# geospatial_lon_min                                                    1.01670
# geospatial_lon_max                                                   24.96670
# time_coverage_start                                      2005-12-04T00:00:00Z
# time_coverage_end                                        2009-06-06T10:00:00Z
# institution                                                 Germany (Unknown)
# date_update                                              2019-05-09T03:04:25Z
# data_mode                                                                   R
# parameters                          DC_REFERENCE POSITIONING_SYSTEM DEPH TEMP
# netcdf                                                       GL_TS_TS_DJOK.nc
# file_type                                                                  TS
# data_type                                                                  TS
# platform_code                                                            DJOK
# wmo_platform_code                                                        DJOK
# institution_edmo_code
# last_latitude_observation                                            54.30000
# last_longitude_observation                                            8.26667
# last_date_observation                                    2009-06-06T10:00:00Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
#                                                                         34237  \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                     -34.55
# geospatial_lat_max                                                      67.54
# geospatial_lon_min                                                     -97.05
# geospatial_lon_max                                                      34.00
# time_coverage_start                                      1990-01-01T02:00:00Z
# time_coverage_end                                        1996-09-19T18:00:00Z
# institution                 IRD  Institut de recherche pour le developpeme...
# date_update                                              2019-05-09T18:14:33Z
# data_mode                                                                   R
# parameters                     PSAL DC_REFERENCE POSITIONING_SYSTEM DEPH TEMP
# netcdf                                                   GL_TS_TS_IF000088.nc
# file_type                                                                  TS
# data_type                                                                  TS
# platform_code                                                        IF000088
# wmo_platform_code
# institution_edmo_code                                                     440
# last_latitude_observation                                               66.66
# last_longitude_observation                                             -31.12
# last_date_observation                                    1996-09-19T18:00:00Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
#                                                                         34238  \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                     -47.52
# geospatial_lat_max                                                      65.85
# geospatial_lon_min                                                    -179.96
# geospatial_lon_max                                                     180.00
# time_coverage_start                                      1990-01-01T00:00:00Z
# time_coverage_end                                        1996-06-24T18:00:00Z
# institution                 IRD  Institut de recherche pour le developpeme...
# date_update                                              2019-05-09T18:14:37Z
# data_mode                                                                   R
# parameters                     PSAL DC_REFERENCE POSITIONING_SYSTEM DEPH TEMP
# netcdf                                                   GL_TS_TS_IF000096.nc
# file_type                                                                  TS
# data_type                                                                  TS
# platform_code                                                        IF000096
# wmo_platform_code
# institution_edmo_code                                                     440
# last_latitude_observation                                               47.06
# last_longitude_observation                                            -128.00
# last_date_observation                                    1996-06-24T18:00:00Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
#                                                                         34239  \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                   -32.8500
# geospatial_lat_max                                                    60.1500
# geospatial_lon_min                                                  -169.9667
# geospatial_lon_max                                                   179.9167
# time_coverage_start                                      2008-09-25T15:00:00Z
# time_coverage_end                                        2012-11-09T14:00:00Z
# institution                                               Unknown institution
# date_update                                              2020-01-19T22:55:37Z
# data_mode                                                                   R
# parameters                     PSAL DC_REFERENCE POSITIONING_SYSTEM DEPH TEMP
# netcdf                                                      GL_TS_TS_KS077.nc
# file_type                                                                  TS
# data_type                                                                  TS
# platform_code                                                           KS077
# wmo_platform_code                                                       KS077
# institution_edmo_code
# last_latitude_observation                                             26.7333
# last_longitude_observation                                           -80.0500
# last_date_observation                                    2012-11-09T14:00:00Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
#                                                                         34240  \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                    47.3500
# geospatial_lat_max                                                    76.3667
# geospatial_lon_min                                                  -168.2667
# geospatial_lon_max                                                  -122.4000
# time_coverage_start                                      2008-10-16T12:00:00Z
# time_coverage_end                                        2008-12-09T23:00:00Z
# institution                                               Unknown institution
# date_update                                              2019-05-09T18:18:33Z
# data_mode                                                                   R
# parameters                     PSAL DC_REFERENCE POSITIONING_SYSTEM DEPH TEMP
# netcdf                                                      GL_TS_TS_KS081.nc
# file_type                                                                  TS
# data_type                                                                  TS
# platform_code                                                           KS081
# wmo_platform_code                                                       KS081
# institution_edmo_code
# last_latitude_observation                                             47.5500
# last_longitude_observation                                          -122.5333
# last_date_observation                                    2008-12-05T12:00:00Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
#                                                                         34241  \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                   -36.8000
# geospatial_lat_max                                                    72.9833
# geospatial_lon_min                                                  -179.6167
# geospatial_lon_max                                                   179.7667
# time_coverage_start                                      2009-02-13T03:00:00Z
# time_coverage_end                                        2011-05-20T15:00:00Z
# institution                                               Unknown institution
# date_update                                              2020-01-19T22:55:38Z
# data_mode                                                                   R
# parameters                     PSAL DC_REFERENCE POSITIONING_SYSTEM DEPH TEMP
# netcdf                                                      GL_TS_TS_KS085.nc
# file_type                                                                  TS
# data_type                                                                  TS
# platform_code                                                           KS085
# wmo_platform_code                                                       KS085
# institution_edmo_code
# last_latitude_observation                                             43.5500
# last_longitude_observation                                            -9.0333
# last_date_observation                                    2011-05-20T15:00:00Z
# timeOverlap                                                             False
# spatialOverlap                                                           True
# lastLocationInRange                                                     False
#
#                                                                         34242  \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                   -55.9500
# geospatial_lat_max                                                    69.4500
# geospatial_lon_min                                                   -91.5333
# geospatial_lon_max                                                    29.4000
# time_coverage_start                                      2009-05-19T18:00:00Z
# time_coverage_end                                        2012-12-11T15:00:00Z
# institution                                               Unknown institution
# date_update                                              2019-05-09T18:18:33Z
# data_mode                                                                   R
# parameters                     PSAL DC_REFERENCE POSITIONING_SYSTEM DEPH TEMP
# netcdf                                                      GL_TS_TS_KS089.nc
# file_type                                                                  TS
# data_type                                                                  TS
# platform_code                                                           KS089
# wmo_platform_code                                                       KS089
# institution_edmo_code
# last_latitude_observation                                             18.0000
# last_longitude_observation                                           -64.8000
# last_date_observation                                    2012-12-11T15:00:00Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
#                                                                         34243  \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                   -65.2167
# geospatial_lat_max                                                    60.4500
# geospatial_lon_min                                                  -151.7500
# geospatial_lon_max                                                    30.1167
# time_coverage_start                                      2010-11-01T18:00:00Z
# time_coverage_end                                        2012-03-21T02:00:00Z
# institution                                               Unknown institution
# date_update                                              2020-01-19T22:57:38Z
# data_mode                                                                   R
# parameters                     PSAL DC_REFERENCE POSITIONING_SYSTEM DEPH TEMP
# netcdf                                                      GL_TS_TS_KS094.nc
# file_type                                                                  TS
# data_type                                                                  TS
# platform_code                                                           KS094
# wmo_platform_code                                                       KS094
# institution_edmo_code
# last_latitude_observation                                            -16.5000
# last_longitude_observation                                          -151.7500
# last_date_observation                                    2012-03-21T02:00:00Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
#                                                                         34244  \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                      36.92
# geospatial_lat_max                                                      66.13
# geospatial_lon_min                                                     -76.33
# geospatial_lon_max                                                       2.87
# time_coverage_start                                      1996-04-05T19:00:00Z
# time_coverage_end                                        1997-12-31T23:00:00Z
# institution                                                 Antigua (Unknown)
# date_update                                              2019-05-09T23:22:13Z
# data_mode                                                                   R
# parameters                     PSAL DC_REFERENCE POSITIONING_SYSTEM DEPH TEMP
# netcdf                                                       GL_TS_TS_V2EZ.nc
# file_type                                                                  TS
# data_type                                                                  TS
# platform_code                                                            V2EZ
# wmo_platform_code                                                        V2EZ
# institution_edmo_code
# last_latitude_observation                                               38.55
# last_longitude_observation                                             -72.33
# last_date_observation                                    1997-12-31T23:00:00Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
#                                                                         34247
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                  -53.75410
# geospatial_lat_max                                                   62.99798
# geospatial_lon_min                                                 -178.17888
# geospatial_lon_max                                                  -36.62067
# time_coverage_start                                      2007-06-09T00:02:10Z
# time_coverage_end                                        2009-10-19T15:52:36Z
# institution                                           United states (Unknown)
# date_update                                              2020-10-22T12:20:30Z
# data_mode                                                                   R
# parameters                  PSAL TEMP DC_REFERENCE POSITIONING_SYSTEM CNDC...
# netcdf                                                       GL_TS_TS_WTDM.nc
# file_type                                                                  TS
# data_type                                                                  TS
# platform_code                                                            WTDM
# wmo_platform_code                                                        WTDM
# institution_edmo_code
# last_latitude_observation                                            47.55710
# last_longitude_observation                                         -122.34160
# last_date_observation                                    2009-10-19T15:52:36Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
# [24 rows x 22610 columns]

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>TIP</b>
#
# ***
# To check if the subset matches the aimed file type (targeted_file_type) just check the `file_type` row of the above output.

# %% [markdown]
# #### 4.1.7. By parameter

# %% [markdown]
# Let's look for files containing a certain parameter.<br>`Please set a parameter code` next `and run the cell`:

# %%
targeted_parameter = 'PSAL' #try others: TEMP, SLEV etc => In Situ parameter list: https://archimer.ifremer.fr/doc/00422/53381/

# %% [markdown]
# Run the next cell to obtain just the files reporting such parameter:

# %%
condition = info['parameters'].str.contains(targeted_parameter)
subset = info[condition]
subset.transpose()
# Out:
#                                                                         0      \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                     57.001
# geospatial_lat_max                                                     57.001
# geospatial_lon_min                                                      4.696
# geospatial_lon_max                                                      4.696
# time_coverage_start                                      2021-01-13T02:13:09Z
# time_coverage_end                                        2021-01-13T02:13:09Z
# institution                             Institute of Marine Research (Norway)
# date_update                                              2021-01-13T23:15:07Z
# data_mode                                                                   R
# parameters                                        SIGMA_T PRES CNDC PSAL TEMP
# netcdf                                              AR_PR_CT_58JH_20210113.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                            58JH
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                    1351
# last_latitude_observation                                              57.001
# last_longitude_observation                                              4.696
# last_date_observation                                    2021-01-13T02:13:09Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
#                                                                         1      \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                     57.000
# geospatial_lat_max                                                     57.000
# geospatial_lon_min                                                      7.949
# geospatial_lon_max                                                      7.949
# time_coverage_start                                      2021-01-14T18:55:20Z
# time_coverage_end                                        2021-01-14T18:55:20Z
# institution                             Institute of Marine Research (Norway)
# date_update                                              2021-01-15T20:15:08Z
# data_mode                                                                   R
# parameters                                        SIGMA_T PRES CNDC PSAL TEMP
# netcdf                                              AR_PR_CT_58JH_20210114.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                            58JH
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                    1351
# last_latitude_observation                                              57.001
# last_longitude_observation                                              4.696
# last_date_observation                                    2021-01-13T02:13:09Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
#                                                                         2      \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                     63.308
# geospatial_lat_max                                                     63.308
# geospatial_lon_min                                                      3.130
# geospatial_lon_max                                                      3.130
# time_coverage_start                                      2021-01-18T22:00:29Z
# time_coverage_end                                        2021-01-18T22:00:29Z
# institution                             Institute of Marine Research (Norway)
# date_update                                              2021-01-19T23:15:16Z
# data_mode                                                                   R
# parameters                                        SIGMA_T PRES CNDC PSAL TEMP
# netcdf                                              AR_PR_CT_58JH_20210118.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                            58JH
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                    1351
# last_latitude_observation                                              57.001
# last_longitude_observation                                              4.696
# last_date_observation                                    2021-01-13T02:13:09Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
#                                                                         3      \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                     63.427
# geospatial_lat_max                                                     64.667
# geospatial_lon_min                                                      0.002
# geospatial_lon_max                                                      2.866
# time_coverage_start                                      2021-01-19T00:11:14Z
# time_coverage_end                                        2021-01-19T20:59:19Z
# institution                             Institute of Marine Research (Norway)
# date_update                                              2021-01-20T23:15:15Z
# data_mode                                                                   R
# parameters                                        SIGMA_T PRES CNDC PSAL TEMP
# netcdf                                              AR_PR_CT_58JH_20210119.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                            58JH
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                    1351
# last_latitude_observation                                              57.001
# last_longitude_observation                                              4.696
# last_date_observation                                    2021-01-13T02:13:09Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
#                                                                         4      \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                     66.005
# geospatial_lat_max                                                     66.005
# geospatial_lon_min                                                      1.998
# geospatial_lon_max                                                      1.998
# time_coverage_start                                      2021-01-20T12:02:10Z
# time_coverage_end                                        2021-01-20T12:02:10Z
# institution                             Institute of Marine Research (Norway)
# date_update                                              2021-01-21T23:15:14Z
# data_mode                                                                   R
# parameters                                        SIGMA_T PRES CNDC PSAL TEMP
# netcdf                                              AR_PR_CT_58JH_20210120.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                            58JH
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                    1351
# last_latitude_observation                                              57.001
# last_longitude_observation                                              4.696
# last_date_observation                                    2021-01-13T02:13:09Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
#                                                                         5      \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                     68.912
# geospatial_lat_max                                                     68.912
# geospatial_lon_min                                                     14.405
# geospatial_lon_max                                                     14.405
# time_coverage_start                                      2021-01-22T15:38:07Z
# time_coverage_end                                        2021-01-22T15:38:07Z
# institution                             Institute of Marine Research (Norway)
# date_update                                              2021-01-23T23:15:15Z
# data_mode                                                                   R
# parameters                                        SIGMA_T PRES CNDC PSAL TEMP
# netcdf                                              AR_PR_CT_58JH_20210122.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                            58JH
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                    1351
# last_latitude_observation                                              57.001
# last_longitude_observation                                              4.696
# last_date_observation                                    2021-01-13T02:13:09Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
#                                                                         6      \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                     70.666
# geospatial_lat_max                                                     71.501
# geospatial_lon_min                                                     19.791
# geospatial_lon_max                                                     19.962
# time_coverage_start                                      2021-01-24T02:27:03Z
# time_coverage_end                                        2021-01-24T14:54:57Z
# institution                             Institute of Marine Research (Norway)
# date_update                                              2021-01-25T23:15:16Z
# data_mode                                                                   R
# parameters                                        SIGMA_T PRES CNDC PSAL TEMP
# netcdf                                              AR_PR_CT_58JH_20210124.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                            58JH
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                    1351
# last_latitude_observation                                              57.001
# last_longitude_observation                                              4.696
# last_date_observation                                    2021-01-13T02:13:09Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
#                                                                         7      \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                     71.529
# geospatial_lat_max                                                     71.529
# geospatial_lon_min                                                     21.804
# geospatial_lon_max                                                     21.804
# time_coverage_start                                      2021-01-28T08:05:31Z
# time_coverage_end                                        2021-01-28T08:05:31Z
# institution                             Institute of Marine Research (Norway)
# date_update                                              2021-01-29T23:15:15Z
# data_mode                                                                   R
# parameters                                        SIGMA_T PRES CNDC PSAL TEMP
# netcdf                                              AR_PR_CT_58JH_20210128.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                            58JH
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                    1351
# last_latitude_observation                                              57.001
# last_longitude_observation                                              4.696
# last_date_observation                                    2021-01-13T02:13:09Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
#                                                                         8      \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                     71.222
# geospatial_lat_max                                                     71.222
# geospatial_lon_min                                                     25.250
# geospatial_lon_max                                                     25.250
# time_coverage_start                                      2021-01-31T23:48:59Z
# time_coverage_end                                        2021-01-31T23:48:59Z
# institution                             Institute of Marine Research (Norway)
# date_update                                              2021-02-01T20:15:09Z
# data_mode                                                                   R
# parameters                                        SIGMA_T PRES CNDC PSAL TEMP
# netcdf                                              AR_PR_CT_58JH_20210131.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                            58JH
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                    1351
# last_latitude_observation                                              57.001
# last_longitude_observation                                              4.696
# last_date_observation                                    2021-01-13T02:13:09Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
#                                                                         9      \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                     71.124
# geospatial_lat_max                                                     71.124
# geospatial_lon_min                                                     23.697
# geospatial_lon_max                                                     23.697
# time_coverage_start                                      2021-02-01T20:35:48Z
# time_coverage_end                                        2021-02-01T20:35:48Z
# institution                             Institute of Marine Research (Norway)
# date_update                                              2021-02-03T01:15:15Z
# data_mode                                                                   R
# parameters                                        SIGMA_T PRES CNDC PSAL TEMP
# netcdf                                              AR_PR_CT_58JH_20210201.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                            58JH
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                    1351
# last_latitude_observation                                              57.001
# last_longitude_observation                                              4.696
# last_date_observation                                    2021-01-13T02:13:09Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
#                             ...  \
# # product_id                ...
# file_name                   ...
# geospatial_lat_min          ...
# geospatial_lat_max          ...
# geospatial_lon_min          ...
# geospatial_lon_max          ...
# time_coverage_start         ...
# time_coverage_end           ...
# institution                 ...
# date_update                 ...
# data_mode                   ...
# parameters                  ...
# netcdf                      ...
# file_type                   ...
# data_type                   ...
# platform_code               ...
# wmo_platform_code           ...
# institution_edmo_code       ...
# last_latitude_observation   ...
# last_longitude_observation  ...
# last_date_observation       ...
# timeOverlap                 ...
# spatialOverlap              ...
# lastLocationInRange         ...
#
#                                                                         34242  \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                   -55.9500
# geospatial_lat_max                                                    69.4500
# geospatial_lon_min                                                   -91.5333
# geospatial_lon_max                                                    29.4000
# time_coverage_start                                      2009-05-19T18:00:00Z
# time_coverage_end                                        2012-12-11T15:00:00Z
# institution                                               Unknown institution
# date_update                                              2019-05-09T18:18:33Z
# data_mode                                                                   R
# parameters                     PSAL DC_REFERENCE POSITIONING_SYSTEM DEPH TEMP
# netcdf                                                      GL_TS_TS_KS089.nc
# file_type                                                                  TS
# data_type                                                                  TS
# platform_code                                                           KS089
# wmo_platform_code                                                       KS089
# institution_edmo_code
# last_latitude_observation                                             18.0000
# last_longitude_observation                                           -64.8000
# last_date_observation                                    2012-12-11T15:00:00Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
#                                                                         34243  \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                   -65.2167
# geospatial_lat_max                                                    60.4500
# geospatial_lon_min                                                  -151.7500
# geospatial_lon_max                                                    30.1167
# time_coverage_start                                      2010-11-01T18:00:00Z
# time_coverage_end                                        2012-03-21T02:00:00Z
# institution                                               Unknown institution
# date_update                                              2020-01-19T22:57:38Z
# data_mode                                                                   R
# parameters                     PSAL DC_REFERENCE POSITIONING_SYSTEM DEPH TEMP
# netcdf                                                      GL_TS_TS_KS094.nc
# file_type                                                                  TS
# data_type                                                                  TS
# platform_code                                                           KS094
# wmo_platform_code                                                       KS094
# institution_edmo_code
# last_latitude_observation                                            -16.5000
# last_longitude_observation                                          -151.7500
# last_date_observation                                    2012-03-21T02:00:00Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
#                                                                         34244  \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                      36.92
# geospatial_lat_max                                                      66.13
# geospatial_lon_min                                                     -76.33
# geospatial_lon_max                                                       2.87
# time_coverage_start                                      1996-04-05T19:00:00Z
# time_coverage_end                                        1997-12-31T23:00:00Z
# institution                                                 Antigua (Unknown)
# date_update                                              2019-05-09T23:22:13Z
# data_mode                                                                   R
# parameters                     PSAL DC_REFERENCE POSITIONING_SYSTEM DEPH TEMP
# netcdf                                                       GL_TS_TS_V2EZ.nc
# file_type                                                                  TS
# data_type                                                                  TS
# platform_code                                                            V2EZ
# wmo_platform_code                                                        V2EZ
# institution_edmo_code
# last_latitude_observation                                               38.55
# last_longitude_observation                                             -72.33
# last_date_observation                                    1997-12-31T23:00:00Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
#                                                                         34247  \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                  -53.75410
# geospatial_lat_max                                                   62.99798
# geospatial_lon_min                                                 -178.17888
# geospatial_lon_max                                                  -36.62067
# time_coverage_start                                      2007-06-09T00:02:10Z
# time_coverage_end                                        2009-10-19T15:52:36Z
# institution                                           United states (Unknown)
# date_update                                              2020-10-22T12:20:30Z
# data_mode                                                                   R
# parameters                  PSAL TEMP DC_REFERENCE POSITIONING_SYSTEM CNDC...
# netcdf                                                       GL_TS_TS_WTDM.nc
# file_type                                                                  TS
# data_type                                                                  TS
# platform_code                                                            WTDM
# wmo_platform_code                                                        WTDM
# institution_edmo_code
# last_latitude_observation                                            47.55710
# last_longitude_observation                                         -122.34160
# last_date_observation                                    2009-10-19T15:52:36Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
#                                                                         34332  \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                      55.10
# geospatial_lat_max                                                      60.40
# geospatial_lon_min                                                     -54.11
# geospatial_lon_max                                                     -48.42
# time_coverage_start                                      1999-07-02T04:52:00Z
# time_coverage_end                                        1999-07-09T22:06:00Z
# institution                                               Unknown institution
# date_update                                              2019-09-28T18:30:48Z
# data_mode                                                                   R
# parameters                              PSAL DC_REFERENCE PRES DATA_MODE TEMP
# netcdf                                                       GL_PR_XX_CDGD.nc
# file_type                                                                  PR
# data_type                                                                  XX
# platform_code                                                            CDGD
# wmo_platform_code                                                        CDGD
# institution_edmo_code
# last_latitude_observation                                               57.38
# last_longitude_observation                                             -51.80
# last_date_observation                                    1999-07-09T22:06:00Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
#                                                                         34333  \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                    36.8187
# geospatial_lat_max                                                    60.5942
# geospatial_lon_min                                                   -70.1888
# geospatial_lon_max                                                   -44.7783
# time_coverage_start                                      2000-06-11T02:44:00Z
# time_coverage_end                                        2016-03-14T09:19:00Z
# institution                                                  Canada (Unknown)
# date_update                                              2020-01-28T04:26:21Z
# data_mode                                                                   R
# parameters                         PSAL DC_REFERENCE PRES DEPH DATA_MODE TEMP
# netcdf                                                       GL_PR_XX_CGCC.nc
# file_type                                                                  PR
# data_type                                                                  XX
# platform_code                                                            CGCC
# wmo_platform_code                                                        CGCC
# institution_edmo_code
# last_latitude_observation                                             48.8437
# last_longitude_observation                                           -63.4725
# last_date_observation                                    2016-03-14T09:19:00Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
#                                                                         34336  \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                     -42.92
# geospatial_lat_max                                                      61.42
# geospatial_lon_min                                                    -179.25
# geospatial_lon_max                                                     176.43
# time_coverage_start                                      1997-04-07T12:09:00Z
# time_coverage_end                                        2000-10-04T15:46:00Z
# institution                                           United states (Unknown)
# date_update                                              2019-09-28T23:37:30Z
# data_mode                                                                   R
# parameters                         PSAL DC_REFERENCE PRES DEPH DATA_MODE TEMP
# netcdf                                                       GL_PR_XX_KWAL.nc
# file_type                                                                  PR
# data_type                                                                  XX
# platform_code                                                            KWAL
# wmo_platform_code                                                        KWAL
# institution_edmo_code
# last_latitude_observation                                               36.00
# last_longitude_observation                                             -76.00
# last_date_observation                                    2000-10-04T15:46:00Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
#                                                                         34351  \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                     57.698
# geospatial_lat_max                                                     66.232
# geospatial_lon_min                                                    -69.927
# geospatial_lon_max                                                    -57.756
# time_coverage_start                                      2015-08-19T04:26:00Z
# time_coverage_end                                        2015-09-21T07:20:00Z
# institution                                               Unknown institution
# date_update                                              2019-10-06T07:59:28Z
# data_mode                                                                   R
# parameters                              PSAL DC_REFERENCE DEPH DATA_MODE TEMP
# netcdf                                                       GL_PR_XX_VAAI.nc
# file_type                                                                  PR
# data_type                                                                  XX
# platform_code                                                            VAAI
# wmo_platform_code                                                        VAAI
# institution_edmo_code
# last_latitude_observation                                              61.763
# last_longitude_observation                                            -60.956
# last_date_observation                                    2015-09-21T07:20:00Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
#                                                                         34352  \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                     42.920
# geospatial_lat_max                                                     60.970
# geospatial_lon_min                                                    -64.030
# geospatial_lon_max                                                    -45.230
# time_coverage_start                                      1997-03-02T00:30:00Z
# time_coverage_end                                        2004-06-17T13:00:00Z
# institution                                                  Canada (Unknown)
# date_update                                              2019-10-06T07:59:28Z
# data_mode                                                                   R
# parameters                         PSAL DC_REFERENCE PRES DEPH DATA_MODE TEMP
# netcdf                                                     GL_PR_XX_VC4959.nc
# file_type                                                                  PR
# data_type                                                                  XX
# platform_code                                                          VC4959
# wmo_platform_code                                                      VC4959
# institution_edmo_code
# last_latitude_observation                                              46.250
# last_longitude_observation                                            -51.666
# last_date_observation                                    2004-06-17T13:00:00Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
#                                                                         34355
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                     49.003
# geospatial_lat_max                                                     66.232
# geospatial_lon_min                                                    -69.967
# geospatial_lon_max                                                    -49.985
# time_coverage_start                                      2012-07-20T12:01:00Z
# time_coverage_end                                        2014-09-24T07:19:00Z
# institution                                               Unknown institution
# date_update                                              2019-10-06T08:07:25Z
# data_mode                                                                   R
# parameters                              PSAL DC_REFERENCE DEPH DATA_MODE TEMP
# netcdf                                                       GL_PR_XX_VOLZ.nc
# file_type                                                                  PR
# data_type                                                                  XX
# platform_code                                                            VOLZ
# wmo_platform_code                                                        VOLZ
# institution_edmo_code
# last_latitude_observation                                              62.558
# last_longitude_observation                                            -63.009
# last_date_observation                                    2014-09-24T07:19:00Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                      True
#
# [24 rows x 11698 columns]

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>TIP</b>
#
# ***
# To check if the subset only contains the aimed parameter (targeted_parameter) just check the `parameters` row of the above output.

# %% [markdown]
# #### 4.1.8. By platform code

# %% [markdown]
# Let's look for files produced by a certain platform.<br>`Please set a platform code` next `and run the cell`:

# %%
targeted_platform_code = '58GS'

# %% [markdown]
# Run the next cell to obtain just the files reported by such platform:

# %%
condition = info['platform_code']==targeted_platform_code
subset = info[condition]
subset.transpose()
# Out:
#                                                                         13451  \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                     57.610
# geospatial_lat_max                                                     57.610
# geospatial_lon_min                                                      6.568
# geospatial_lon_max                                                      6.568
# time_coverage_start                                      2021-01-18T20:39:41Z
# time_coverage_end                                        2021-01-18T20:39:41Z
# institution                             Institute of Marine Research (Norway)
# date_update                                              2021-01-19T23:15:16Z
# data_mode                                                                   R
# parameters                                        SIGMA_T PRES CNDC PSAL TEMP
# netcdf                                              AR_PR_CT_58GS_20210118.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                            58GS
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                    1351
# last_latitude_observation                                              57.610
# last_longitude_observation                                              6.568
# last_date_observation                                    2021-01-18T20:39:41Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
#                                                                         13452  \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                     57.664
# geospatial_lat_max                                                     58.138
# geospatial_lon_min                                                      8.527
# geospatial_lon_max                                                     10.247
# time_coverage_start                                      2021-01-19T04:22:35Z
# time_coverage_end                                        2021-01-19T23:20:52Z
# institution                             Institute of Marine Research (Norway)
# date_update                                              2021-01-20T23:15:14Z
# data_mode                                                                   R
# parameters                                        SIGMA_T PRES CNDC PSAL TEMP
# netcdf                                              AR_PR_CT_58GS_20210119.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                            58GS
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                    1351
# last_latitude_observation                                              57.610
# last_longitude_observation                                              6.568
# last_date_observation                                    2021-01-18T20:39:41Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
#                                                                         13453  \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                     58.053
# geospatial_lat_max                                                     58.109
# geospatial_lon_min                                                      9.977
# geospatial_lon_max                                                     10.568
# time_coverage_start                                      2021-01-20T01:07:40Z
# time_coverage_end                                        2021-01-20T12:01:13Z
# institution                             Institute of Marine Research (Norway)
# date_update                                              2021-01-21T23:15:13Z
# data_mode                                                                   R
# parameters                                        SIGMA_T PRES CNDC PSAL TEMP
# netcdf                                              AR_PR_CT_58GS_20210120.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                            58GS
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                    1351
# last_latitude_observation                                              57.610
# last_longitude_observation                                              6.568
# last_date_observation                                    2021-01-18T20:39:41Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
#                                                                         13454  \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                     58.410
# geospatial_lat_max                                                     58.410
# geospatial_lon_min                                                      2.777
# geospatial_lon_max                                                      2.777
# time_coverage_start                                      2021-01-21T22:04:25Z
# time_coverage_end                                        2021-01-21T22:04:25Z
# institution                             Institute of Marine Research (Norway)
# date_update                                              2021-01-22T23:15:14Z
# data_mode                                                                   R
# parameters                                        SIGMA_T PRES CNDC PSAL TEMP
# netcdf                                              AR_PR_CT_58GS_20210121.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                            58GS
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                    1351
# last_latitude_observation                                              57.610
# last_longitude_observation                                              6.568
# last_date_observation                                    2021-01-18T20:39:41Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
#                                                                         13455  \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                     57.877
# geospatial_lat_max                                                     58.200
# geospatial_lon_min                                                      2.424
# geospatial_lon_max                                                      2.661
# time_coverage_start                                      2021-01-22T00:42:35Z
# time_coverage_end                                        2021-01-22T22:17:37Z
# institution                             Institute of Marine Research (Norway)
# date_update                                              2021-01-23T23:15:14Z
# data_mode                                                                   R
# parameters                                        SIGMA_T PRES CNDC PSAL TEMP
# netcdf                                              AR_PR_CT_58GS_20210122.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                            58GS
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                    1351
# last_latitude_observation                                              57.610
# last_longitude_observation                                              6.568
# last_date_observation                                    2021-01-18T20:39:41Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
#                                                                         13456  \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                     57.204
# geospatial_lat_max                                                     57.588
# geospatial_lon_min                                                      2.637
# geospatial_lon_max                                                      4.205
# time_coverage_start                                      2021-01-23T04:23:03Z
# time_coverage_end                                        2021-01-23T23:49:27Z
# institution                             Institute of Marine Research (Norway)
# date_update                                              2021-01-24T23:15:17Z
# data_mode                                                                   R
# parameters                                        SIGMA_T PRES CNDC PSAL TEMP
# netcdf                                              AR_PR_CT_58GS_20210123.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                            58GS
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                    1351
# last_latitude_observation                                              57.610
# last_longitude_observation                                              6.568
# last_date_observation                                    2021-01-18T20:39:41Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
#                                                                         13457  \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                     57.388
# geospatial_lat_max                                                     57.637
# geospatial_lon_min                                                      4.555
# geospatial_lon_max                                                      6.172
# time_coverage_start                                      2021-01-24T01:58:26Z
# time_coverage_end                                        2021-01-24T23:59:11Z
# institution                             Institute of Marine Research (Norway)
# date_update                                              2021-01-25T23:15:15Z
# data_mode                                                                   R
# parameters                                        SIGMA_T PRES CNDC PSAL TEMP
# netcdf                                              AR_PR_CT_58GS_20210124.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                            58GS
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                    1351
# last_latitude_observation                                              57.610
# last_longitude_observation                                              6.568
# last_date_observation                                    2021-01-18T20:39:41Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
#                                                                         13458  \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                     57.193
# geospatial_lat_max                                                     58.585
# geospatial_lon_min                                                      3.732
# geospatial_lon_max                                                      6.298
# time_coverage_start                                      2021-01-25T01:56:06Z
# time_coverage_end                                        2021-01-25T23:11:17Z
# institution                             Institute of Marine Research (Norway)
# date_update                                              2021-01-26T23:15:17Z
# data_mode                                                                   R
# parameters                                        SIGMA_T PRES CNDC PSAL TEMP
# netcdf                                              AR_PR_CT_58GS_20210125.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                            58GS
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                    1351
# last_latitude_observation                                              57.610
# last_longitude_observation                                              6.568
# last_date_observation                                    2021-01-18T20:39:41Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
#                                                                         13459  \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                     58.374
# geospatial_lat_max                                                     59.147
# geospatial_lon_min                                                      2.730
# geospatial_lon_max                                                      3.750
# time_coverage_start                                      2021-01-26T04:15:54Z
# time_coverage_end                                        2021-01-26T22:21:59Z
# institution                             Institute of Marine Research (Norway)
# date_update                                              2021-01-27T23:15:16Z
# data_mode                                                                   R
# parameters                                        SIGMA_T PRES CNDC PSAL TEMP
# netcdf                                              AR_PR_CT_58GS_20210126.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                            58GS
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                    1351
# last_latitude_observation                                              57.610
# last_longitude_observation                                              6.568
# last_date_observation                                    2021-01-18T20:39:41Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
#                                                                         13460  \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                     59.301
# geospatial_lat_max                                                     59.817
# geospatial_lon_min                                                      1.813
# geospatial_lon_max                                                      2.778
# time_coverage_start                                      2021-01-27T03:48:32Z
# time_coverage_end                                        2021-01-27T22:23:25Z
# institution                             Institute of Marine Research (Norway)
# date_update                                              2021-01-28T23:15:17Z
# data_mode                                                                   R
# parameters                                        SIGMA_T PRES CNDC PSAL TEMP
# netcdf                                              AR_PR_CT_58GS_20210127.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                            58GS
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                    1351
# last_latitude_observation                                              57.610
# last_longitude_observation                                              6.568
# last_date_observation                                    2021-01-18T20:39:41Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
#                             ...  \
# # product_id                ...
# file_name                   ...
# geospatial_lat_min          ...
# geospatial_lat_max          ...
# geospatial_lon_min          ...
# geospatial_lon_max          ...
# time_coverage_start         ...
# time_coverage_end           ...
# institution                 ...
# date_update                 ...
# data_mode                   ...
# parameters                  ...
# netcdf                      ...
# file_type                   ...
# data_type                   ...
# platform_code               ...
# wmo_platform_code           ...
# institution_edmo_code       ...
# last_latitude_observation   ...
# last_longitude_observation  ...
# last_date_observation       ...
# timeOverlap                 ...
# spatialOverlap              ...
# lastLocationInRange         ...
#
#                                                                         13518  \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                     58.233
# geospatial_lat_max                                                     64.237
# geospatial_lon_min                                                      2.485
# geospatial_lon_max                                                      8.964
# time_coverage_start                                      2020-03-01T14:38:28Z
# time_coverage_end                                        2020-03-14T05:00:40Z
# institution                             Institute of Marine Research (Norway)
# date_update                                              2020-06-02T10:10:25Z
# data_mode                                                                   M
# parameters                                   SIGMA_T PRES PSAL TEMP CNDC DEPH
# netcdf                                                AR_PR_CT_58GS_202003.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                            58GS
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                    1351
# last_latitude_observation                                              57.610
# last_longitude_observation                                              6.568
# last_date_observation                                    2021-01-18T20:39:41Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
#                                                                         13519  \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                     63.885
# geospatial_lat_max                                                     64.975
# geospatial_lon_min                                                      7.355
# geospatial_lon_max                                                      8.973
# time_coverage_start                                      2020-04-14T00:28:24Z
# time_coverage_end                                        2020-04-26T04:50:15Z
# institution                             Institute of Marine Research (Norway)
# date_update                                              2020-06-02T10:11:01Z
# data_mode                                                                   M
# parameters                                   SIGMA_T PRES PSAL TEMP CNDC DEPH
# netcdf                                                AR_PR_CT_58GS_202004.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                            58GS
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                    1351
# last_latitude_observation                                              57.610
# last_longitude_observation                                              6.568
# last_date_observation                                    2021-01-18T20:39:41Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
#                                                                         13520  \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                     60.413
# geospatial_lat_max                                                     73.775
# geospatial_lon_min                                                     -2.337
# geospatial_lon_max                                                     24.785
# time_coverage_start                                      2020-05-01T10:32:27Z
# time_coverage_end                                        2020-05-31T21:58:49Z
# institution                             Institute of Marine Research (Norway)
# date_update                                              2020-09-01T06:15:17Z
# data_mode                                                                   M
# parameters                                   SIGMA_T PRES PSAL TEMP CNDC DEPH
# netcdf                                                AR_PR_CT_58GS_202005.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                            58GS
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                    1351
# last_latitude_observation                                              57.610
# last_longitude_observation                                              6.568
# last_date_observation                                    2021-01-18T20:39:41Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
#                                                                         13521  \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                     61.019
# geospatial_lat_max                                                     71.499
# geospatial_lon_min                                                      5.010
# geospatial_lon_max                                                     21.470
# time_coverage_start                                      2020-06-01T04:28:38Z
# time_coverage_end                                        2020-06-29T23:02:03Z
# institution                             Institute of Marine Research (Norway)
# date_update                                              2020-09-01T06:15:58Z
# data_mode                                                                   M
# parameters                                   SIGMA_T PRES PSAL TEMP CNDC DEPH
# netcdf                                                AR_PR_CT_58GS_202006.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                            58GS
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                    1351
# last_latitude_observation                                              57.610
# last_longitude_observation                                              6.568
# last_date_observation                                    2021-01-18T20:39:41Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
#                                                                         13522  \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                     65.479
# geospatial_lat_max                                                     73.457
# geospatial_lon_min                                                      3.828
# geospatial_lon_max                                                     10.618
# time_coverage_start                                      2020-07-02T03:25:16Z
# time_coverage_end                                        2020-07-31T22:21:56Z
# institution                             Institute of Marine Research (Norway)
# date_update                                              2020-09-01T06:16:29Z
# data_mode                                                                   M
# parameters                                   SIGMA_T PRES PSAL TEMP CNDC DEPH
# netcdf                                                AR_PR_CT_58GS_202007.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                            58GS
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                    1351
# last_latitude_observation                                              57.610
# last_longitude_observation                                              6.568
# last_date_observation                                    2021-01-18T20:39:41Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
#                                                                         13523  \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                     69.502
# geospatial_lat_max                                                     74.740
# geospatial_lon_min                                                     15.443
# geospatial_lon_max                                                     36.865
# time_coverage_start                                      2020-08-10T10:38:28Z
# time_coverage_end                                        2020-08-31T18:56:40Z
# institution                             Institute of Marine Research (Norway)
# date_update                                              2020-11-01T07:21:15Z
# data_mode                                                                   M
# parameters                                   SIGMA_T PRES PSAL TEMP CNDC DEPH
# netcdf                                                AR_PR_CT_58GS_202008.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                            58GS
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                    1351
# last_latitude_observation                                              57.610
# last_longitude_observation                                              6.568
# last_date_observation                                    2021-01-18T20:39:41Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
#                                                                         13524  \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                     60.727
# geospatial_lat_max                                                     76.481
# geospatial_lon_min                                                     -2.062
# geospatial_lon_max                                                     37.752
# time_coverage_start                                      2020-09-01T01:53:36Z
# time_coverage_end                                        2020-09-28T08:28:01Z
# institution                             Institute of Marine Research (Norway)
# date_update                                              2020-11-01T07:21:42Z
# data_mode                                                                   M
# parameters                                   SIGMA_T PRES PSAL TEMP CNDC DEPH
# netcdf                                                AR_PR_CT_58GS_202009.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                            58GS
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                    1351
# last_latitude_observation                                              57.610
# last_longitude_observation                                              6.568
# last_date_observation                                    2021-01-18T20:39:41Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
#                                                                         13525  \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                     73.118
# geospatial_lat_max                                                     78.850
# geospatial_lon_min                                                     13.524
# geospatial_lon_max                                                     35.037
# time_coverage_start                                      2020-10-06T22:10:08Z
# time_coverage_end                                        2020-10-25T18:07:26Z
# institution                             Institute of Marine Research (Norway)
# date_update                                              2021-01-01T07:17:53Z
# data_mode                                                                   R
# parameters                                        SIGMA_T PRES PSAL TEMP CNDC
# netcdf                                                AR_PR_CT_58GS_202010.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                            58GS
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                    1351
# last_latitude_observation                                              57.610
# last_longitude_observation                                              6.568
# last_date_observation                                    2021-01-18T20:39:41Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
#                                                                         13526  \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                     69.358
# geospatial_lat_max                                                     69.502
# geospatial_lon_min                                                     18.952
# geospatial_lon_max                                                     19.180
# time_coverage_start                                      2020-11-19T12:57:04Z
# time_coverage_end                                        2020-11-28T11:17:43Z
# institution                             Institute of Marine Research (Norway)
# date_update                                              2020-12-01T07:12:32Z
# data_mode                                                                   R
# parameters                                        SIGMA_T PRES PSAL TEMP CNDC
# netcdf                                                AR_PR_CT_58GS_202011.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                            58GS
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                    1351
# last_latitude_observation                                              57.610
# last_longitude_observation                                              6.568
# last_date_observation                                    2021-01-18T20:39:41Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
#                                                                         13527
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                    -67.094
# geospatial_lat_max                                                     80.654
# geospatial_lon_min                                                    -57.361
# geospatial_lon_max                                                     46.693
# time_coverage_start                                      2003-07-26T23:40:20Z
# time_coverage_end                                        2020-11-28T11:17:43Z
# institution                             Institute of Marine Research (Norway)
# date_update                                              2021-01-15T07:03:39Z
# data_mode                                                                   M
# parameters                                        PSAL PRES CNDC SIGMA_T TEMP
# netcdf                                                       AR_PR_CT_58GS.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                            58GS
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                    1351
# last_latitude_observation                                              57.610
# last_longitude_observation                                              6.568
# last_date_observation                                    2021-01-18T20:39:41Z
# timeOverlap                                                              True
# spatialOverlap                                                           True
# lastLocationInRange                                                     False
#
# [24 rows x 77 columns]

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>TIP</b>
#
# ***
# To check if the subset matches the aimed platform (targeted_platform_code) just check the `platform_code` row of the above output.

# %% [markdown]
# #### 4.1.9. By provider

# %% [markdown]
# Let's look for files produced by a certain provider (find others at: [SeaDataNet](https://edmo.seadatanet.org/search)).<br>`Please set a provider code` next `and run the cell`:

# %%
targeted_provider_code = '29'

# %% [markdown]
# Run the next cell to obtain just the files reported by such provider:

# %%
info['institution_edmo_code'] = ' '+info['institution_edmo_code']+' '

# %%
condition = info['institution_edmo_code'].str.contains(targeted_provider_code, na=False)
subset = info[condition]
subset.transpose()
# Out:
#                                                                         12780  \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                    61.2243
# geospatial_lat_max                                                    61.2243
# geospatial_lon_min                                                   -21.1156
# geospatial_lon_max                                                   -21.1156
# time_coverage_start                                      2021-01-15T16:50:42Z
# time_coverage_end                                        2021-01-15T16:50:42Z
# institution                               Met Office (Ocean Weather Services)
# date_update                                              2021-01-15T21:08:04Z
# data_mode                                                                   R
# parameters                  PRES VERTICAL_SAMPLING_SCHEME PSAL DC_REFERENC...
# netcdf                                           GL_PR_PF_6901166_20210115.nc
# file_type                                                                  PR
# data_type                                                                  PF
# platform_code                                                         6901166
# wmo_platform_code                                                     6901166
# institution_edmo_code                                                     29
# last_latitude_observation                                             61.2243
# last_longitude_observation                                           -21.1156
# last_date_observation                                    2021-01-15T16:50:42Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
#                                                                         12781  \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                    60.9081
# geospatial_lat_max                                                    60.9081
# geospatial_lon_min                                                   -20.5883
# geospatial_lon_max                                                   -20.5883
# time_coverage_start                                      2021-01-25T15:05:54Z
# time_coverage_end                                        2021-01-25T15:05:54Z
# institution                               Met Office (Ocean Weather Services)
# date_update                                              2021-01-25T21:03:41Z
# data_mode                                                                   M
# parameters                  PRES VERTICAL_SAMPLING_SCHEME PSAL TEMP_ADJUST...
# netcdf                                           GL_PR_PF_6901166_20210125.nc
# file_type                                                                  PR
# data_type                                                                  PF
# platform_code                                                         6901166
# wmo_platform_code                                                     6901166
# institution_edmo_code                                                     29
# last_latitude_observation                                             61.2243
# last_longitude_observation                                           -21.1156
# last_date_observation                                    2021-01-15T16:50:42Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
#                                                                         12782  \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                    60.9942
# geospatial_lat_max                                                    60.9942
# geospatial_lon_min                                                   -20.7744
# geospatial_lon_max                                                   -20.7744
# time_coverage_start                                      2021-02-04T16:46:06Z
# time_coverage_end                                        2021-02-04T16:46:06Z
# institution                               Met Office (Ocean Weather Services)
# date_update                                              2021-02-04T21:03:15Z
# data_mode                                                                   M
# parameters                  PRES VERTICAL_SAMPLING_SCHEME PSAL TEMP_ADJUST...
# netcdf                                           GL_PR_PF_6901166_20210204.nc
# file_type                                                                  PR
# data_type                                                                  PF
# platform_code                                                         6901166
# wmo_platform_code                                                     6901166
# institution_edmo_code                                                     29
# last_latitude_observation                                             61.2243
# last_longitude_observation                                           -21.1156
# last_date_observation                                    2021-01-15T16:50:42Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
#                                                                         12783  \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                    59.5530
# geospatial_lat_max                                                    60.7020
# geospatial_lon_min                                                   -29.0230
# geospatial_lon_max                                                   -27.6280
# time_coverage_start                                      2016-01-02T14:46:39Z
# time_coverage_end                                        2016-01-22T15:33:46Z
# institution                               Met Office (Ocean Weather Services)
# date_update                                              2019-10-10T14:17:26Z
# data_mode                                                                   D
# parameters                  PSAL_ADJUSTED_ERROR TEMP_ADJUSTED PRES_ADJUSTE...
# netcdf                                             GL_PR_PF_6901166_201601.nc
# file_type                                                                  PR
# data_type                                                                  PF
# platform_code                                                         6901166
# wmo_platform_code                                                     6901166
# institution_edmo_code                                                     29
# last_latitude_observation                                             61.2243
# last_longitude_observation                                           -21.1156
# last_date_observation                                    2021-01-15T16:50:42Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
#                                                                         12784  \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                    59.3910
# geospatial_lat_max                                                    60.0420
# geospatial_lon_min                                                   -30.3510
# geospatial_lon_max                                                   -29.8030
# time_coverage_start                                      2016-02-01T13:29:58Z
# time_coverage_end                                        2016-02-21T14:49:17Z
# institution                               Met Office (Ocean Weather Services)
# date_update                                              2019-10-10T14:17:26Z
# data_mode                                                                   D
# parameters                  PSAL_ADJUSTED_ERROR TEMP_ADJUSTED PRES_ADJUSTE...
# netcdf                                             GL_PR_PF_6901166_201602.nc
# file_type                                                                  PR
# data_type                                                                  PF
# platform_code                                                         6901166
# wmo_platform_code                                                     6901166
# institution_edmo_code                                                     29
# last_latitude_observation                                             61.2243
# last_longitude_observation                                           -21.1156
# last_date_observation                                    2021-01-15T16:50:42Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
#                                                                         12785  \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                    60.6780
# geospatial_lat_max                                                    61.4790
# geospatial_lon_min                                                   -29.7350
# geospatial_lon_max                                                   -28.8370
# time_coverage_start                                      2016-03-02T15:18:05Z
# time_coverage_end                                        2016-03-22T15:34:24Z
# institution                               Met Office (Ocean Weather Services)
# date_update                                              2019-10-10T14:17:26Z
# data_mode                                                                   D
# parameters                  PSAL_ADJUSTED_ERROR TEMP_ADJUSTED PRES_ADJUSTE...
# netcdf                                             GL_PR_PF_6901166_201603.nc
# file_type                                                                  PR
# data_type                                                                  PF
# platform_code                                                         6901166
# wmo_platform_code                                                     6901166
# institution_edmo_code                                                     29
# last_latitude_observation                                             61.2243
# last_longitude_observation                                           -21.1156
# last_date_observation                                    2021-01-15T16:50:42Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
#                                                                         12786  \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                    61.5820
# geospatial_lat_max                                                    62.7460
# geospatial_lon_min                                                   -29.4980
# geospatial_lon_max                                                   -28.7020
# time_coverage_start                                      2016-04-01T13:36:54Z
# time_coverage_end                                        2016-04-21T16:33:30Z
# institution                               Met Office (Ocean Weather Services)
# date_update                                              2019-10-10T14:17:26Z
# data_mode                                                                   D
# parameters                  PSAL_ADJUSTED_ERROR TEMP_ADJUSTED PRES_ADJUSTE...
# netcdf                                             GL_PR_PF_6901166_201604.nc
# file_type                                                                  PR
# data_type                                                                  PF
# platform_code                                                         6901166
# wmo_platform_code                                                     6901166
# institution_edmo_code                                                     29
# last_latitude_observation                                             61.2243
# last_longitude_observation                                           -21.1156
# last_date_observation                                    2021-01-15T16:50:42Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
#                                                                         12787  \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                    62.8590
# geospatial_lat_max                                                    63.3770
# geospatial_lon_min                                                   -31.1220
# geospatial_lon_max                                                   -30.6470
# time_coverage_start                                      2016-05-01T14:01:01Z
# time_coverage_end                                        2016-05-31T14:17:21Z
# institution                               Met Office (Ocean Weather Services)
# date_update                                              2019-10-10T14:17:26Z
# data_mode                                                                   D
# parameters                  PSAL_ADJUSTED_ERROR TEMP_ADJUSTED PRES_ADJUSTE...
# netcdf                                             GL_PR_PF_6901166_201605.nc
# file_type                                                                  PR
# data_type                                                                  PF
# platform_code                                                         6901166
# wmo_platform_code                                                     6901166
# institution_edmo_code                                                     29
# last_latitude_observation                                             61.2243
# last_longitude_observation                                           -21.1156
# last_date_observation                                    2021-01-15T16:50:42Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
#                                                                         12788  \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                    63.3720
# geospatial_lat_max                                                    63.8760
# geospatial_lon_min                                                   -32.0940
# geospatial_lon_max                                                   -30.0570
# time_coverage_start                                      2016-06-10T14:22:25Z
# time_coverage_end                                        2016-06-30T14:33:07Z
# institution                               Met Office (Ocean Weather Services)
# date_update                                              2019-10-10T14:17:26Z
# data_mode                                                                   D
# parameters                  PSAL_ADJUSTED_ERROR TEMP_ADJUSTED PRES_ADJUSTE...
# netcdf                                             GL_PR_PF_6901166_201606.nc
# file_type                                                                  PR
# data_type                                                                  PF
# platform_code                                                         6901166
# wmo_platform_code                                                     6901166
# institution_edmo_code                                                     29
# last_latitude_observation                                             61.2243
# last_longitude_observation                                           -21.1156
# last_date_observation                                    2021-01-15T16:50:42Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
#                                                                         12789  \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                    63.3930
# geospatial_lat_max                                                    63.6540
# geospatial_lon_min                                                   -31.9834
# geospatial_lon_max                                                   -31.6470
# time_coverage_start                                      2016-07-10T14:38:49Z
# time_coverage_end                                        2016-07-30T15:03:12Z
# institution                               Met Office (Ocean Weather Services)
# date_update                                              2019-10-10T14:17:26Z
# data_mode                                                                   D
# parameters                  PSAL_ADJUSTED_ERROR TEMP_ADJUSTED PRES_ADJUSTE...
# netcdf                                             GL_PR_PF_6901166_201607.nc
# file_type                                                                  PR
# data_type                                                                  PF
# platform_code                                                         6901166
# wmo_platform_code                                                     6901166
# institution_edmo_code                                                     29
# last_latitude_observation                                             61.2243
# last_longitude_observation                                           -21.1156
# last_date_observation                                    2021-01-15T16:50:42Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
#                             ...  \
# # product_id                ...
# file_name                   ...
# geospatial_lat_min          ...
# geospatial_lat_max          ...
# geospatial_lon_min          ...
# geospatial_lon_max          ...
# time_coverage_start         ...
# time_coverage_end           ...
# institution                 ...
# date_update                 ...
# data_mode                   ...
# parameters                  ...
# netcdf                      ...
# file_type                   ...
# data_type                   ...
# platform_code               ...
# wmo_platform_code           ...
# institution_edmo_code       ...
# last_latitude_observation   ...
# last_longitude_observation  ...
# last_date_observation       ...
# timeOverlap                 ...
# spatialOverlap              ...
# lastLocationInRange         ...
#
#                                                                         34004  \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                     54.869
# geospatial_lat_max                                                     61.091
# geospatial_lon_min                                                    -34.558
# geospatial_lon_max                                                    -19.644
# time_coverage_start                                      2012-08-13T14:47:51Z
# time_coverage_end                                        2014-12-31T18:08:44Z
# institution                               Met Office (Ocean Weather Services)
# date_update                                              2019-09-07T20:13:42Z
# data_mode                                                                   D
# parameters                  PSAL PRES_ADJUSTED VERTICAL_SAMPLING_SCHEME PS...
# netcdf                                                    GL_PR_PF_6901134.nc
# file_type                                                                  PR
# data_type                                                                  PF
# platform_code                                                         6901134
# wmo_platform_code                                                     6901134
# institution_edmo_code                                                     29
# last_latitude_observation                                              55.596
# last_longitude_observation                                            -34.022
# last_date_observation                                    2014-12-31T18:08:44Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
#                                                                         34005  \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                     57.771
# geospatial_lat_max                                                     65.360
# geospatial_lon_min                                                    -34.163
# geospatial_lon_max                                                    -17.110
# time_coverage_start                                      2012-08-14T05:37:08Z
# time_coverage_end                                        2014-09-13T05:49:52Z
# institution                               Met Office (Ocean Weather Services)
# date_update                                              2019-09-07T20:13:42Z
# data_mode                                                                   D
# parameters                  PSAL PRES_ADJUSTED VERTICAL_SAMPLING_SCHEME PS...
# netcdf                                                    GL_PR_PF_6901135.nc
# file_type                                                                  PR
# data_type                                                                  PF
# platform_code                                                         6901135
# wmo_platform_code                                                     6901135
# institution_edmo_code                                                     29
# last_latitude_observation                                              64.872
# last_longitude_observation                                            -34.163
# last_date_observation                                    2014-09-13T05:49:52Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
#                                                                         34006  \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                     58.762
# geospatial_lat_max                                                     65.094
# geospatial_lon_min                                                    -52.268
# geospatial_lon_max                                                    -17.859
# time_coverage_start                                      2012-08-14T18:56:14Z
# time_coverage_end                                        2014-09-13T18:39:38Z
# institution                               Met Office (Ocean Weather Services)
# date_update                                              2019-09-07T20:13:42Z
# data_mode                                                                   D
# parameters                  PSAL PRES_ADJUSTED VERTICAL_SAMPLING_SCHEME PS...
# netcdf                                                    GL_PR_PF_6901136.nc
# file_type                                                                  PR
# data_type                                                                  PF
# platform_code                                                         6901136
# wmo_platform_code                                                     6901136
# institution_edmo_code                                                     29
# last_latitude_observation                                              62.467
# last_longitude_observation                                            -52.268
# last_date_observation                                    2014-09-13T18:39:38Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                      True
#
#                                                                         34007  \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                     64.013
# geospatial_lat_max                                                     72.926
# geospatial_lon_min                                                     -6.689
# geospatial_lon_max                                                     14.405
# time_coverage_start                                      2012-08-29T13:23:37Z
# time_coverage_end                                        2015-12-03T20:38:07Z
# institution                               Met Office (Ocean Weather Services)
# date_update                                              2019-05-07T19:45:09Z
# data_mode                                                                   R
# parameters                  PSAL DC_REFERENCE TEMP_ADJUSTED PRES PSAL_ADJU...
# netcdf                                                    GL_PR_PF_6901139.nc
# file_type                                                                  PR
# data_type                                                                  PF
# platform_code                                                         6901139
# wmo_platform_code                                                     6901139
# institution_edmo_code                                                     29
# last_latitude_observation                                              65.465
# last_longitude_observation                                             -2.570
# last_date_observation                                    2015-12-03T20:38:07Z
# timeOverlap                                                             False
# spatialOverlap                                                           True
# lastLocationInRange                                                     False
#
#                                                                         34008  \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                    52.9502
# geospatial_lat_max                                                    64.9030
# geospatial_lon_min                                                   -60.4160
# geospatial_lon_max                                                   -16.8380
# time_coverage_start                                      2013-05-14T04:45:19Z
# time_coverage_end                                        2020-12-03T10:46:16Z
# institution                               Met Office (Ocean Weather Services)
# date_update                                              2021-01-11T17:25:35Z
# data_mode                                                                   M
# parameters                  PSAL PRES_ADJUSTED VERTICAL_SAMPLING_SCHEME PS...
# netcdf                                                    GL_PR_PF_6901147.nc
# file_type                                                                  PR
# data_type                                                                  PF
# platform_code                                                         6901147
# wmo_platform_code                                                     6901147
# institution_edmo_code                                                     29
# last_latitude_observation                                             57.5758
# last_longitude_observation                                           -36.8099
# last_date_observation                                    2020-12-03T10:46:16Z
# timeOverlap                                                              True
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
#                                                                         34009  \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                    50.3410
# geospatial_lat_max                                                    64.9680
# geospatial_lon_min                                                   -53.0720
# geospatial_lon_max                                                   -13.5440
# time_coverage_start                                      2013-05-17T14:55:09Z
# time_coverage_end                                        2020-01-31T18:38:04Z
# institution                               Met Office (Ocean Weather Services)
# date_update                                              2020-02-03T03:05:16Z
# data_mode                                                                   M
# parameters                  PSAL PRES_ADJUSTED VERTICAL_SAMPLING_SCHEME PS...
# netcdf                                                    GL_PR_PF_6901149.nc
# file_type                                                                  PR
# data_type                                                                  PF
# platform_code                                                         6901149
# wmo_platform_code                                                     6901149
# institution_edmo_code                                                     29
# last_latitude_observation                                             50.8686
# last_longitude_observation                                           -39.9429
# last_date_observation                                    2020-01-31T18:38:04Z
# timeOverlap                                                              True
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
#                                                                         34010  \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                    64.6322
# geospatial_lat_max                                                    69.7938
# geospatial_lon_min                                                    -6.8955
# geospatial_lon_max                                                     0.9852
# time_coverage_start                                      2013-11-16T15:05:37Z
# time_coverage_end                                        2015-06-24T06:12:29Z
# institution                               Met Office (Ocean Weather Services)
# date_update                                              2020-07-06T02:43:03Z
# data_mode                                                                   R
# parameters                  PSAL PRES_ADJUSTED VERTICAL_SAMPLING_SCHEME DC...
# netcdf                                                    GL_PR_PF_6901157.nc
# file_type                                                                  PR
# data_type                                                                  PF
# platform_code                                                         6901157
# wmo_platform_code                                                     6901157
# institution_edmo_code                                                     29
# last_latitude_observation                                             66.6649
# last_longitude_observation                                            -6.8955
# last_date_observation                                    2015-06-24T06:12:29Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
#                                                                         34011  \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                    66.1792
# geospatial_lat_max                                                    70.0759
# geospatial_lon_min                                                    -8.5531
# geospatial_lon_max                                                     1.9396
# time_coverage_start                                      2013-11-18T01:47:34Z
# time_coverage_end                                        2014-12-13T08:25:27Z
# institution                               Met Office (Ocean Weather Services)
# date_update                                              2020-07-06T02:43:02Z
# data_mode                                                                   R
# parameters                  PSAL PRES_ADJUSTED VERTICAL_SAMPLING_SCHEME DC...
# netcdf                                                    GL_PR_PF_6901158.nc
# file_type                                                                  PR
# data_type                                                                  PF
# platform_code                                                         6901158
# wmo_platform_code                                                     6901158
# institution_edmo_code                                                     29
# last_latitude_observation                                             67.8320
# last_longitude_observation                                            -4.2677
# last_date_observation                                    2014-12-13T08:25:27Z
# timeOverlap                                                             False
# spatialOverlap                                                           True
# lastLocationInRange                                                     False
#
#                                                                         34012  \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                    69.2871
# geospatial_lat_max                                                    71.7057
# geospatial_lon_min                                                     5.4389
# geospatial_lon_max                                                    10.5631
# time_coverage_start                                      2014-01-23T05:02:32Z
# time_coverage_end                                        2014-07-02T09:24:06Z
# institution                               Met Office (Ocean Weather Services)
# date_update                                              2020-02-03T03:05:15Z
# data_mode                                                                   R
# parameters                  PSAL PRES_ADJUSTED VERTICAL_SAMPLING_SCHEME DC...
# netcdf                                                    GL_PR_PF_6901159.nc
# file_type                                                                  PR
# data_type                                                                  PF
# platform_code                                                         6901159
# wmo_platform_code                                                     6901159
# institution_edmo_code                                                     29
# last_latitude_observation                                             70.0605
# last_longitude_observation                                             9.7690
# last_date_observation                                    2014-07-02T09:24:06Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
#                                                                         34047
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                     58.981
# geospatial_lat_max                                                     62.980
# geospatial_lon_min                                                    -25.488
# geospatial_lon_max                                                    -13.797
# time_coverage_start                                      2001-05-20T12:05:05Z
# time_coverage_end                                        2003-09-18T04:09:06Z
# institution                               Met Office (Ocean Weather Services)
# date_update                                              2020-12-27T16:09:37Z
# data_mode                                                                   M
# parameters                  PSAL PRES_ADJUSTED VERTICAL_SAMPLING_SCHEME PS...
# netcdf                                                      GL_PR_PF_69081.nc
# file_type                                                                  PR
# data_type                                                                  PF
# platform_code                                                           69081
# wmo_platform_code                                                       69081
# institution_edmo_code                                                     29
# last_latitude_observation                                              60.510
# last_longitude_observation                                            -18.318
# last_date_observation                                    2003-09-18T04:09:06Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
# [24 rows x 805 columns]

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>TIP</b>
#
# ***
# To check if the subset matches the aimed provider (targeted_provider_code) just check the `insitution_edmo_code` row of the above output.

# %% [markdown]
# #### 4.1.10. By several criterias at once

# %% [markdown]
# Set the collection of interest, range of time and bbox to find only the files that match:

# %%
targeted_collection = 'history'
targeted_range = '2001-01-01T00:00:00Z/2019-12-01T23:59:59Z'
targeted_data_type = 'MO'
targeted_parameter = 'TEMP'
targeted_geospatial_lat_min = 62.0  # enter min latitude of your bounding box
targeted_geospatial_lat_max = 67.5  # enter max latitude of your bounding box
targeted_geospatial_lon_min = -25.5  # enter min longitude of your bounding box
targeted_geospatial_lon_max = -10.0  # enter max longitude of your bounding box
targeted_bbox = [targeted_geospatial_lon_min, targeted_geospatial_lat_min, targeted_geospatial_lon_max, targeted_geospatial_lat_max]  # (minx, miny, maxx, maxy)

# %% [markdown]
# Run the next cell to apply the above filters:

# %%
info['timeOverlap'] = info.apply(timeOverlap,targeted_range=targeted_range,axis=1)
condition1 = info['timeOverlap'] == True
info['spatialOverlap'] = info.apply(spatialOverlap,targeted_bbox=targeted_bbox,axis=1)
condition2 = info['spatialOverlap'] == True

condition3 = info['data_type'] == targeted_data_type
condition4 = info['file_name'].str.contains(targeted_collection)
condition5 = info['parameters'].str.contains(targeted_parameter)

subset = info[condition1 & condition2 & condition3 & condition4 & condition5]
subset.transpose()
# Out:
#                                                                          757   \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                     66.539
# geospatial_lat_max                                                     66.539
# geospatial_lon_min                                                    -18.017
# geospatial_lon_max                                                    -18.017
# time_coverage_start                                      2016-01-01T00:00:00Z
# time_coverage_end                                        2020-12-31T01:00:00Z
# institution                               Marine Research Institute (Iceland)
# date_update                                              2021-01-15T07:43:03Z
# data_mode                                                                   M
# parameters                                                          DEPH TEMP
# netcdf                                                    AR_TS_MO_Grimsey.nc
# file_type                                                                  TS
# data_type                                                                  MO
# platform_code                                                         Grimsey
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                   4766
# last_latitude_observation                                              66.539
# last_longitude_observation                                            -18.017
# last_date_observation                                    2021-01-13T23:50:00Z
# timeOverlap                                                              True
# spatialOverlap                                                           True
# lastLocationInRange                                                     False
#
#                                                                          1208
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                     64.152
# geospatial_lat_max                                                     64.152
# geospatial_lon_min                                                    -21.932
# geospatial_lon_max                                                    -21.932
# time_coverage_start                                      2016-01-01T00:00:00Z
# time_coverage_end                                        2020-12-30T20:00:00Z
# institution                               Marine Research Institute (Iceland)
# date_update                                              2021-01-15T07:42:22Z
# data_mode                                                                   M
# parameters                                                          DEPH TEMP
# netcdf                                                  AR_TS_MO_Reykjavik.nc
# file_type                                                                  TS
# data_type                                                                  MO
# platform_code                                                       Reykjavik
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                   4766
# last_latitude_observation                                              64.152
# last_longitude_observation                                            -21.932
# last_date_observation                                    2021-01-13T23:50:00Z
# timeOverlap                                                              True
# spatialOverlap                                                           True
# lastLocationInRange                                                     False

# %% [markdown]
# ### 4.2. Exporting

# %% [markdown]
# If you just want to export the above table containing ftp link to download each file in subset and some more metadata as csv for sharing it (a lot more compact than sharing the actual files), just run the next cell:

# %%
subset.to_csv('subsetOffiles.csv')

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>TIP</b>
#
# ***
# Find [here](https://github.com/CopernicusMarineInsitu/downloadFilesFromCSV) and example about how to read and download the content of the files listed in the 'subsetOffiles.csv'.<br>**Remember**!: change the column_name to 'file_name'

# %% [markdown]
# ### 4.3. Downloading

# %% [markdown]
# After you have created your own subset (see above examples about how-to), we will loop over the files in such subset and download each of them from the FTP server thanks to the `file_name` column, field that contains the ftp link to the file.<br> Run the next cells:

# %%
output_directory = os.getcwd()# Defaults to the current working directory; change it as you please

# %%
treshold = 10 #Please set a file number maxima to download. 
#This is just an example and we do not wanna trigger the download of too many files!

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>TIP</b>
#
# ***
# If wanna download the whole subset and not just a sample, set `treshold = float('inf')`

# %%
with ftputil.FTPHost(dataset['host'], usr, pas) as ftp_host:  # connect to CMEMS FTP
    for i in range(0, len(subset)):
        if i<treshold:
            filepath = subset.iloc[i]['file_name'].split(dataset['host'])[1]
            ncdf_file_name = filepath.split('/')[-1]
            if ftp_host.path.isfile(filepath):
                print('.....Downloading ' + ncdf_file_name)
                cwd = os.getcwd()
                os.chdir(output_directory)
                try:
                    ftp_host.download(filepath, ncdf_file_name)  # remote, local
                    print('Done!')
                except Exception as e:
                    print('error!: FTP download failed ...')
                os.chdir(cwd)
# Out:
# .....Downloading AR_TS_MO_Grimsey.nc
# Done!
# .....Downloading AR_TS_MO_Reykjavik.nc
# Done!

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>TIP</b>
#
# ***
# To check if the files have been donwloaded just check if you find them in the directory specified as <i>output directory</i>.

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>WARNING</b>
#
# ***
# FTP download might be forbidden in the remote server for security reasons. <br>If you experience an error please run this jupyter notebook locally for being able to actually download the files. Steps:
# 1. [Install anaconda](https://www.anaconda.com/distribution/): according to your OS (Windows,Linux,Mac...)
# 2. Navigate to the folder containing the notebooks (.ipynb files)
# 3. Run the following command at the Terminal (Mac/Linux) or Command Prompt (Windows): jupyter notebook

# %% [markdown]
# ---
#
# # 5. Wrap-up
# [Go back to the "Table of Contents"](#Table-of-Contents)
#
# So far you should already know how to subset the product/dataset by several subsetting criterias as well as exporting and downloading the resulting subset of files.<br> `If you don't please ask us! it is the moment!`
# <br>In the next tutorial we will see how to open and visualize some of the files donloaded. Ready? Let's go!

# %% [markdown]
# ---
#
# # 6. Next Tutorial
#
# [Go back to the "Table of Contents"](#Table-of-Contents)
#
# _Click on one of the hyperlinks below to continue the training_
# <br>
# [**13-03-NearRealTime-product-managing-files-moorings.ipynb**](13-03-NearRealTime-product-managing-files-moorings.ipynb)<br>
# [**13-04-NearRealTime-product-managing-files-profilers.ipynb**](13-04-NearRealTime-product-managing-files-profilers.ipynb)<br>
# [**13-05-NearRealTime-product-managing-files-hfradars.ipynb**](13-05-NearRealTime-product-managing-files-hfradars.ipynb)<br>
