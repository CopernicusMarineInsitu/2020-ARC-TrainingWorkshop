# %% [markdown]
# ![header](https://i.imgur.com/I4ake6d.jpg)

# %% [markdown]
# # COPERNICUS MARINE IN SITU ARCTIC OCEAN TRAINING (1/5)

# %% [markdown]
# <div style="text-align: right"><i> 13-01-Part-one-out-of-five </i></div>

# %% [markdown]
# ***
# # An overview of  the ARC `NRT` product/dataset

# %% [markdown]
# ***
# **General Note 1**: Execute each cell through the <button class="btn btn-default btn-xs"><i class="icon-play fa fa-play"></i></button> button from the top MENU (or keyboard shortcut `Shift` + `Enter`).<br>
# <br><br>
# **General Note 2**: If, for any reason, the kernel is not working anymore, in the top MENU, click on the <button class="btn btn-default btn-xs"><i class="fa fa-repeat icon-repeat"></i></button> button. Then, in the top MENU, click on "Cell" and select "Run All Above Selected Cell".<br>
# ***

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc">
#     <ul class="toc-item">
#         <li><span><a href="#1.-Introduction" data-toc-modified-id="1.-Introduction">1. Introduction</a></span></li>
#         <li>
#             <span><a href="#2.-Setup" data-toc-modified-id="2.-Setup">2. Setup</a></span>
#             <ul>
#                 <li><span><a href="#2.1.-Python-packages" data-toc-modified-id="2.1.-Python-packages">2.1. Python packages</a></span></li>
#                 <li><span><a href="#2.2.-Copernicus-Database" data-toc-modified-id="2.2.-Copernicus-Database">2.2. Copernicus database</a></span></li>
#                 <li><span><a href="#2.3.-Auxiliary-functions" data-toc-modified-id="2.3-Setup">2.3. Auxiliary functions</a></span></li>
#             </ul>
#         </li>
#         <li>
#             <span><a href="#3.-COLLECTION-OVERVIEW" data-toc-modified-id="3.-COLLECTION-OVERVIEW">3. Collection overview</a></span>
#             <ul>
#                 <li><span><a href="#3.1.-Getting-started" data-toc-modified-id="3.1.-Getting-started-packages">3.1. Getting started</a></span></li>
#                 <li><span><a href="#3.2.-Choosing-collection" data-toc-modified-id="3.2.-Chosing-collection">3.2. Choosing collection</a></span></li>
#                 <li>
#                     <span><a href="#3.3.-Overview" data-toc-modified-id="3.3.-Overview">3.3. Overview</a></span>
#                     <ul>
#                 <li><span><a href="#3.3.1.-Platforms" data-toc-modified-id="3.3.1.-Platforms">3.3.1. Platforms</a></span></li>
#                 <li><span><a href="#3.3.2.-Source-types-(data-types)" data-toc-modified-id="3.3.2.-Source-types-(data-types)">3.3.2. Source types (data types)</a></span></li>
#                 <li><span><a href="#3.3.3.-Feature-types-(file-types)" data-toc-modified-id="3.3.3.-Feature-types-(file-types)">3.3.3. Feature types (file types)</a></span></li>
#                 <li><span><a href="#3.3.4.-Parameters" data-toc-modified-id="3.3.4.-Parameters">3.3.4. Parameters</a></span></li>
#                 <li><span><a href="#3.3.5.-Providers" data-toc-modified-id="3.3.5.-Providers">3.3.5. Providers</a></span></li>
#             </ul>
#                 </li>
#             </ul>
#         </li>
#         <li><span><a href="#4.-Wrap-up" data-toc-modified-id="4.-Wrap-up">4. Wrap-up</a></span></li>
#         <li><span><a href="#5.-Next-tutorial" data-toc-modified-id="5.-Next-tutorial">5. Next tutorial</a></span></li>
#     </ul>
# </div>

# %% [markdown]
# ***

# %% [markdown]
# ## 1. Introduction
# [Go back to the "Table of contents"](#Table-of-Contents)
#
# This notebook focuses on getting an overview of the files available in the different collections (`latest`, `monthly` and `history`) available within the In Situ Near Real Time product/dataset covering the Arctic Regional Seas: `INSITU_ARC_NRT_OBSERVATIONS_013_031`. Click [here](https://resources.marine.copernicus.eu/?option=com_csw&task=results?option=com_csw&view=details&product_id=INSITU_ARC_NRT_OBSERVATIONS_013_031) to  view the dedicated section of this product within the [CMEMS Catalog](http://marine.copernicus.eu/services-portfolio/access-to-products/).

# %% [markdown]
# Any In Situ NRT product/dataset is just a bunch of netcdf files produced by the platforms (*drifters, profilers, gliders, moorings, HF-radars, vessels etc*) deployed in certain seas (in this case, the Arctic Regional Seas); so many files that navigation/subsetting can be challenging.

# %% [markdown]
# | ![ARCLatest.png](img/ARCLatest.png)|
# |:--:|
# | *Last location (point or trajectory) of the platforms providing near real time data in the ARC area (last 30 days)* |

# %% [markdown]
# To smooth the process of data discovery to users, the In Situ TAC provides a set of `index files` that describes the aforementioned file collections. In addition to these index files, it is also possible to find further info regarding each platform contributing with files on the `index_platform.txt`.

# %% [markdown]
# | Index |  Description |
# | ------- | ----------- |
# | `index_latest.txt`  |  List of available files within the latest collection + metadata |
# | `index_monthly.txt`   | List of available files within the monthly collection + metadata |
# | `index_history.txt`   |  List of available files within the history collection + metadata |
# | `index_platform.txt`   | Full list of platforms + metadata |

# %% [markdown]
# Check more about these files in the <a href="https://archimer.ifremer.fr/doc/00324/43494/" target="_blank">Product User Manual</a>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>OBJECTIVE</b>
#
# ***
# To discover which platforms, file types, data types, parameters and providers are to be expected in a specific collection of the ARC NRT product/dataset by using the aforementioned index files.

# %% [markdown]
# ## 2. Setup
# [Go back to the "Table of Contents"](#Table-of-Contents)

# %% [markdown]
# ### 2.1. Python packages

# %% [markdown]
# For the notebook to properly run we need to first load the following packages available from the Jupyter Notebook Ecosystem. Please run the `next cell`:

# %%
import os
import warnings
warnings.filterwarnings("ignore")
import IPython
from shapely.geometry import box 
import ftputil
import pandas as pd
import folium
from folium import plugins
import json2html
from json2html import *
# %matplotlib inline

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>WARNING</b>
#
# ***
# If any of them raises any error it means you need to install the module first. For doing so please:
# 1. Open a new cell in the notebook
# 2. Run <i>`!conda install packageName --yes`</i> or <i>`!conda install -c conda-forge packageName --yes`</i> or <i>`!pip install packageName`</i>
# 3. Import again!
# <br><br>
# Example: <i>how-to-solve import error for json2html module </i>
#
# ![errorImporting.gif](img/errorImporting.gif)

# %% [markdown]
# ### 2.2. Copernicus Database

# %% [markdown]
# Please `set next your CMEMS User credentials` in the next cell and `run the cell` afterwards:

# %%
usr = 'inputHereYourCMEMSUser'
pas = 'inputHereYourCMEMSPassword'

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>WARNING</b>
#
# ***
# **Don't you have credentials yet?**
# <br>Please go [here](https://resources.marine.copernicus.eu/?option=com_sla) to get the above credentials to be able to access CMEMS secured FTP servers hosting CMEMS data products.

# %% [markdown]
# As stated before, we will focus on the Near Real Time product/dataset covering the Arctic regional seas so, please `run the next` to load the info defining such product/dataset:

# %%
dataset = {
    'host': 'nrt.cmems-du.eu',#ftp host => nrt.cmems-du.eu for Near Real Time products
    'product': 'INSITU_ARC_NRT_OBSERVATIONS_013_031',#name of the In Situ Near Real Time product in the ARC area
    'name': 'arc_multiparameter_nrt',#name of the dataset available in the above In Situ Near Real Time product
    'index_files': ['index_latest.txt', 'index_monthly.txt', 'index_history.txt'],#files describing the content of the lastest, monthly and history netCDF file collections available withint he above dataset
    'index_platform': 'index_platform.txt',#files describing the netwotk of platforms contributting with files in the abve collections
}

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>TIP</b>
#
# ***
# In case you want to explore any other In Situ NRT product/dataset just set the above definitions accordingly and you will be able to reproduce the analysis we will perform next.

# %% [markdown]
# ### 2.3. Auxiliary functions

# %% [markdown]
# For exploring the product/dataset we will use a set of files called `index files` located in the CMEMS FTP server.

# %% [markdown]
# 1. **Download the index files**.
# In order to download the most updated version of these files we will use the next function. <br>Please `run the next cell` to load it (the function) in memory for later use:

# %%
def getIndexFiles(usr,pas,dataset,path2indexes):
    #Provides the index files available at the ftp server
    indexes = dataset['index_files'] + [dataset['index_platform']]
    with ftputil.FTPHost(dataset['host'], usr, pas) as ftp_host:  # connect to CMEMS FTP
        for index in indexes:
            remotefile= "/".join(['Core',dataset['product'],dataset['name'],index])
            print('.....Downloading ' + index)
            localfile = os.path.join(path2indexes,index)
            ftp_host.download(remotefile,localfile)  # remote, local
    print('Ready!')

# %% [markdown]
# 2. **Index files reader**.
# In order to load the information contained in *each* of the files we will use the next function. <br>Please `run the next cell` to load it in memory for later use:

# %%
def readIndexFileFromCWD(path2file):
    #Load as pandas dataframe the file in the provided path
    with open(path2file, 'rb') as f:
        filename = os.path.basename(path2file)
        print('...Loading info from: '+filename)
        raw_index_info = pd.read_csv(path2file, skiprows=5)
    return raw_index_info

# %% [markdown]
# 3. **Index files merger**.
# In order to load the information contained in *all* the indexes in a one single entity we will use the next function. <br>Please `run the next cell` to load it in memory for later use:

# %%
def getIndexFilesInfo(usr, pas, dataset,path2indexes):
    # Load and merge in a single entity all the information contained on each file descriptor of a given dataset
    # 1) Loading the index platform info as dataframe
    path2file = os.path.join(path2indexes, dataset['index_platform'])
    indexPlatform = readIndexFileFromCWD(path2file)
    indexPlatform.rename(columns={indexPlatform.columns[0]: "platform_code" }, inplace = True)
    indexPlatform = indexPlatform.drop_duplicates(subset='platform_code', keep="first")
    # 2) Loading the index files info as dataframes
    netcdf_collections = []
    for filename in dataset['index_files']:
        path2file = os.path.join(path2indexes,filename)
        indexFile = readIndexFileFromCWD(path2file)
        netcdf_collections.append(indexFile)
    netcdf_collections = pd.concat(netcdf_collections)
    # 3) creating new columns: derived info
    netcdf_collections['netcdf'] = netcdf_collections['file_name'].str.split('/').str[-1]
    netcdf_collections['file_type'] = netcdf_collections['netcdf'].str.split('.').str[0].str.split('_').str[1]
    netcdf_collections['data_type'] = netcdf_collections['netcdf'].str.split('.').str[0].str.split('_').str[2]
    netcdf_collections['platform_code'] = netcdf_collections['netcdf'].str.split('.').str[0].str.split('_').str[3]
    # 4) Merging the information of all files
    headers = ['platform_code','wmo_platform_code', 'institution_edmo_code', 'last_latitude_observation', 'last_longitude_observation','last_date_observation']
    result = pd.merge(netcdf_collections,indexPlatform[headers],on='platform_code')
    print('Ready!')
    return result

# %% [markdown]
# ## 3. COLLECTION OVERVIEW
# [Go back to the "Table of Contents"](#Table-of-Contents)

# %% [markdown]
# ### 3.1. Getting started

# %% [markdown]
# For the analysis to be carried out we need the most recent version of the index files. By default we will save them into the `index_files` folder available in the `data` folder. Nevertheless if you rather use a different one set it next:

# %%
path2indexes= os.path.join(os.getcwd(),'data','index_files')#default path to save the files

# %% [markdown]
# Although in such folder we have provided already a copy of the files, **if you are running this notebook later than October 2020** please `Run the next` cell and download again the index files:

# %%
getIndexFiles(usr,pas,dataset,path2indexes)
# Out:
# .....Downloading index_latest.txt
# .....Downloading index_monthly.txt
# .....Downloading index_history.txt
# .....Downloading index_platform.txt
# Ready!

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>WARNING</b>
#
# ***
# **Are you getting a `permission denied` error?**
# <br>Please be aware that no `writes` are authorized in the 'shared_notebook' folder. Make sure you run this on you own space after copying the notebooks form shared_notebooks. If you are still facing a problem contact us trough [Mattermost](https://chat-cmems.mercator-ocean.fr/).

# %% [markdown]
# Let's load now into a dataframe the info contained in such files: `run the next cell!`

# %%
info = getIndexFilesInfo(usr, pas, dataset, path2indexes)
# Out:
# ...Loading info from: index_platform.txt
# ...Loading info from: index_latest.txt
# ...Loading info from: index_monthly.txt
# ...Loading info from: index_history.txt
# Ready!

# %% [markdown]
# `Run now the next cell` to see the information just loaded above:

# %%
info.transpose()
# Out:
#                                                                         0      \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                     57.001
# geospatial_lat_max                                                     57.001
# geospatial_lon_min                                                      4.696
# geospatial_lon_max                                                      4.696
# time_coverage_start                                      2021-01-13T02:13:09Z
# time_coverage_end                                        2021-01-13T02:13:09Z
# institution                             Institute of Marine Research (Norway)
# date_update                                              2021-01-13T23:15:07Z
# data_mode                                                                   R
# parameters                                        SIGMA_T PRES CNDC PSAL TEMP
# netcdf                                              AR_PR_CT_58JH_20210113.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                            58JH
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                    1351
# last_latitude_observation                                              57.001
# last_longitude_observation                                              4.696
# last_date_observation                                    2021-01-13T02:13:09Z
#
#                                                                         1      \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                     57.000
# geospatial_lat_max                                                     57.000
# geospatial_lon_min                                                      7.949
# geospatial_lon_max                                                      7.949
# time_coverage_start                                      2021-01-14T18:55:20Z
# time_coverage_end                                        2021-01-14T18:55:20Z
# institution                             Institute of Marine Research (Norway)
# date_update                                              2021-01-15T20:15:08Z
# data_mode                                                                   R
# parameters                                        SIGMA_T PRES CNDC PSAL TEMP
# netcdf                                              AR_PR_CT_58JH_20210114.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                            58JH
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                    1351
# last_latitude_observation                                              57.001
# last_longitude_observation                                              4.696
# last_date_observation                                    2021-01-13T02:13:09Z
#
#                                                                         2      \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                     63.308
# geospatial_lat_max                                                     63.308
# geospatial_lon_min                                                      3.130
# geospatial_lon_max                                                      3.130
# time_coverage_start                                      2021-01-18T22:00:29Z
# time_coverage_end                                        2021-01-18T22:00:29Z
# institution                             Institute of Marine Research (Norway)
# date_update                                              2021-01-19T23:15:16Z
# data_mode                                                                   R
# parameters                                        SIGMA_T PRES CNDC PSAL TEMP
# netcdf                                              AR_PR_CT_58JH_20210118.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                            58JH
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                    1351
# last_latitude_observation                                              57.001
# last_longitude_observation                                              4.696
# last_date_observation                                    2021-01-13T02:13:09Z
#
#                                                                         3      \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                     63.427
# geospatial_lat_max                                                     64.667
# geospatial_lon_min                                                      0.002
# geospatial_lon_max                                                      2.866
# time_coverage_start                                      2021-01-19T00:11:14Z
# time_coverage_end                                        2021-01-19T20:59:19Z
# institution                             Institute of Marine Research (Norway)
# date_update                                              2021-01-20T23:15:15Z
# data_mode                                                                   R
# parameters                                        SIGMA_T PRES CNDC PSAL TEMP
# netcdf                                              AR_PR_CT_58JH_20210119.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                            58JH
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                    1351
# last_latitude_observation                                              57.001
# last_longitude_observation                                              4.696
# last_date_observation                                    2021-01-13T02:13:09Z
#
#                                                                         4      \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                     66.005
# geospatial_lat_max                                                     66.005
# geospatial_lon_min                                                      1.998
# geospatial_lon_max                                                      1.998
# time_coverage_start                                      2021-01-20T12:02:10Z
# time_coverage_end                                        2021-01-20T12:02:10Z
# institution                             Institute of Marine Research (Norway)
# date_update                                              2021-01-21T23:15:14Z
# data_mode                                                                   R
# parameters                                        SIGMA_T PRES CNDC PSAL TEMP
# netcdf                                              AR_PR_CT_58JH_20210120.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                            58JH
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                    1351
# last_latitude_observation                                              57.001
# last_longitude_observation                                              4.696
# last_date_observation                                    2021-01-13T02:13:09Z
#
#                                                                         5      \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                     68.912
# geospatial_lat_max                                                     68.912
# geospatial_lon_min                                                     14.405
# geospatial_lon_max                                                     14.405
# time_coverage_start                                      2021-01-22T15:38:07Z
# time_coverage_end                                        2021-01-22T15:38:07Z
# institution                             Institute of Marine Research (Norway)
# date_update                                              2021-01-23T23:15:15Z
# data_mode                                                                   R
# parameters                                        SIGMA_T PRES CNDC PSAL TEMP
# netcdf                                              AR_PR_CT_58JH_20210122.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                            58JH
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                    1351
# last_latitude_observation                                              57.001
# last_longitude_observation                                              4.696
# last_date_observation                                    2021-01-13T02:13:09Z
#
#                                                                         6      \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                     70.666
# geospatial_lat_max                                                     71.501
# geospatial_lon_min                                                     19.791
# geospatial_lon_max                                                     19.962
# time_coverage_start                                      2021-01-24T02:27:03Z
# time_coverage_end                                        2021-01-24T14:54:57Z
# institution                             Institute of Marine Research (Norway)
# date_update                                              2021-01-25T23:15:16Z
# data_mode                                                                   R
# parameters                                        SIGMA_T PRES CNDC PSAL TEMP
# netcdf                                              AR_PR_CT_58JH_20210124.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                            58JH
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                    1351
# last_latitude_observation                                              57.001
# last_longitude_observation                                              4.696
# last_date_observation                                    2021-01-13T02:13:09Z
#
#                                                                         7      \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                     71.529
# geospatial_lat_max                                                     71.529
# geospatial_lon_min                                                     21.804
# geospatial_lon_max                                                     21.804
# time_coverage_start                                      2021-01-28T08:05:31Z
# time_coverage_end                                        2021-01-28T08:05:31Z
# institution                             Institute of Marine Research (Norway)
# date_update                                              2021-01-29T23:15:15Z
# data_mode                                                                   R
# parameters                                        SIGMA_T PRES CNDC PSAL TEMP
# netcdf                                              AR_PR_CT_58JH_20210128.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                            58JH
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                    1351
# last_latitude_observation                                              57.001
# last_longitude_observation                                              4.696
# last_date_observation                                    2021-01-13T02:13:09Z
#
#                                                                         8      \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                     71.222
# geospatial_lat_max                                                     71.222
# geospatial_lon_min                                                     25.250
# geospatial_lon_max                                                     25.250
# time_coverage_start                                      2021-01-31T23:48:59Z
# time_coverage_end                                        2021-01-31T23:48:59Z
# institution                             Institute of Marine Research (Norway)
# date_update                                              2021-02-01T20:15:09Z
# data_mode                                                                   R
# parameters                                        SIGMA_T PRES CNDC PSAL TEMP
# netcdf                                              AR_PR_CT_58JH_20210131.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                            58JH
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                    1351
# last_latitude_observation                                              57.001
# last_longitude_observation                                              4.696
# last_date_observation                                    2021-01-13T02:13:09Z
#
#                                                                         9      \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                     71.124
# geospatial_lat_max                                                     71.124
# geospatial_lon_min                                                     23.697
# geospatial_lon_max                                                     23.697
# time_coverage_start                                      2021-02-01T20:35:48Z
# time_coverage_end                                        2021-02-01T20:35:48Z
# institution                             Institute of Marine Research (Norway)
# date_update                                              2021-02-03T01:15:15Z
# data_mode                                                                   R
# parameters                                        SIGMA_T PRES CNDC PSAL TEMP
# netcdf                                              AR_PR_CT_58JH_20210201.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                            58JH
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                    1351
# last_latitude_observation                                              57.001
# last_longitude_observation                                              4.696
# last_date_observation                                    2021-01-13T02:13:09Z
#
#                             ...  \
# # product_id                ...
# file_name                   ...
# geospatial_lat_min          ...
# geospatial_lat_max          ...
# geospatial_lon_min          ...
# geospatial_lon_max          ...
# time_coverage_start         ...
# time_coverage_end           ...
# institution                 ...
# date_update                 ...
# data_mode                   ...
# parameters                  ...
# netcdf                      ...
# file_type                   ...
# data_type                   ...
# platform_code               ...
# wmo_platform_code           ...
# institution_edmo_code       ...
# last_latitude_observation   ...
# last_longitude_observation  ...
# last_date_observation       ...
#
#                                                                         34348  \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                      62.13
# geospatial_lat_max                                                      62.13
# geospatial_lon_min                                                      17.86
# geospatial_lon_max                                                      17.86
# time_coverage_start                                      1996-10-25T10:00:00Z
# time_coverage_end                                        1997-09-27T15:45:00Z
# institution                                                  Sweden (Unknown)
# date_update                                              2019-10-06T06:52:45Z
# data_mode                                                                   R
# parameters                                   DC_REFERENCE PRES DATA_MODE TEMP
# netcdf                                                       GL_PR_XX_SKVP.nc
# file_type                                                                  PR
# data_type                                                                  XX
# platform_code                                                            SKVP
# wmo_platform_code                                                        SKVP
# institution_edmo_code
# last_latitude_observation                                               62.13
# last_longitude_observation                                              17.86
# last_date_observation                                    1997-09-27T15:45:00Z
#
#                                                                         34349  \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                      55.00
# geospatial_lat_max                                                      62.13
# geospatial_lon_min                                                      11.66
# geospatial_lon_max                                                      17.86
# time_coverage_start                                      1996-06-02T18:20:00Z
# time_coverage_end                                        1999-09-07T12:45:00Z
# institution                                                  Sweden (Unknown)
# date_update                                              2019-10-06T06:52:44Z
# data_mode                                                                   R
# parameters                                   DC_REFERENCE PRES DATA_MODE TEMP
# netcdf                                                       GL_PR_XX_SMZT.nc
# file_type                                                                  PR
# data_type                                                                  XX
# platform_code                                                            SMZT
# wmo_platform_code                                                        SMZT
# institution_edmo_code
# last_latitude_observation                                               57.18
# last_longitude_observation                                              11.66
# last_date_observation                                    1999-09-07T12:45:00Z
#
#                                                                         34350  \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                      61.33
# geospatial_lat_max                                                      63.23
# geospatial_lon_min                                                     -19.28
# geospatial_lon_max                                                     -11.70
# time_coverage_start                                      1996-01-06T16:22:00Z
# time_coverage_end                                        1996-05-05T16:01:00Z
# institution                                                 Iceland (Unknown)
# date_update                                              2019-10-06T07:14:05Z
# data_mode                                                                   R
# parameters                                   DC_REFERENCE PRES DATA_MODE TEMP
# netcdf                                                       GL_PR_XX_TFVD.nc
# file_type                                                                  PR
# data_type                                                                  XX
# platform_code                                                            TFVD
# wmo_platform_code                                                        TFVD
# institution_edmo_code
# last_latitude_observation                                               62.25
# last_longitude_observation                                             -15.46
# last_date_observation                                    1996-05-05T16:01:00Z
#
#                                                                         34351  \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                     57.698
# geospatial_lat_max                                                     66.232
# geospatial_lon_min                                                    -69.927
# geospatial_lon_max                                                    -57.756
# time_coverage_start                                      2015-08-19T04:26:00Z
# time_coverage_end                                        2015-09-21T07:20:00Z
# institution                                               Unknown institution
# date_update                                              2019-10-06T07:59:28Z
# data_mode                                                                   R
# parameters                              PSAL DC_REFERENCE DEPH DATA_MODE TEMP
# netcdf                                                       GL_PR_XX_VAAI.nc
# file_type                                                                  PR
# data_type                                                                  XX
# platform_code                                                            VAAI
# wmo_platform_code                                                        VAAI
# institution_edmo_code
# last_latitude_observation                                              61.763
# last_longitude_observation                                            -60.956
# last_date_observation                                    2015-09-21T07:20:00Z
#
#                                                                         34352  \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                     42.920
# geospatial_lat_max                                                     60.970
# geospatial_lon_min                                                    -64.030
# geospatial_lon_max                                                    -45.230
# time_coverage_start                                      1997-03-02T00:30:00Z
# time_coverage_end                                        2004-06-17T13:00:00Z
# institution                                                  Canada (Unknown)
# date_update                                              2019-10-06T07:59:28Z
# data_mode                                                                   R
# parameters                         PSAL DC_REFERENCE PRES DEPH DATA_MODE TEMP
# netcdf                                                     GL_PR_XX_VC4959.nc
# file_type                                                                  PR
# data_type                                                                  XX
# platform_code                                                          VC4959
# wmo_platform_code                                                      VC4959
# institution_edmo_code
# last_latitude_observation                                              46.250
# last_longitude_observation                                            -51.666
# last_date_observation                                    2004-06-17T13:00:00Z
#
#                                                                         34353  \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                    -38.130
# geospatial_lat_max                                                     90.000
# geospatial_lon_min                                                   -174.100
# geospatial_lon_max                                                    153.950
# time_coverage_start                                      1985-05-04T23:00:00Z
# time_coverage_end                                        2007-12-06T11:45:00Z
# institution                                               Australia (Unknown)
# date_update                                              2019-10-06T08:04:24Z
# data_mode                                                                   R
# parameters                              DC_REFERENCE PRES DEPH DATA_MODE TEMP
# netcdf                                                       GL_PR_XX_VKLA.nc
# file_type                                                                  PR
# data_type                                                                  XX
# platform_code                                                            VKLA
# wmo_platform_code                                                        VKLA
# institution_edmo_code
# last_latitude_observation                                             -33.350
# last_longitude_observation                                            114.883
# last_date_observation                                    2007-12-06T11:45:00Z
#
#                                                                         34354  \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                    -45.233
# geospatial_lat_max                                                     62.041
# geospatial_lon_min                                                   -178.988
# geospatial_lon_max                                                    180.000
# time_coverage_start                                      2001-06-21T12:30:00Z
# time_coverage_end                                        2016-07-25T22:00:00Z
# institution                                               Australia (Unknown)
# date_update                                              2019-10-06T08:05:25Z
# data_mode                                                                   R
# parameters                                   DC_REFERENCE DEPH DATA_MODE TEMP
# netcdf                                                       GL_PR_XX_VKLD.nc
# file_type                                                                  PR
# data_type                                                                  XX
# platform_code                                                            VKLD
# wmo_platform_code                                                        VKLD
# institution_edmo_code
# last_latitude_observation                                              19.667
# last_longitude_observation                                           -157.667
# last_date_observation                                    2016-07-25T22:00:00Z
#
#                                                                         34355  \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                     49.003
# geospatial_lat_max                                                     66.232
# geospatial_lon_min                                                    -69.967
# geospatial_lon_max                                                    -49.985
# time_coverage_start                                      2012-07-20T12:01:00Z
# time_coverage_end                                        2014-09-24T07:19:00Z
# institution                                               Unknown institution
# date_update                                              2019-10-06T08:07:25Z
# data_mode                                                                   R
# parameters                              PSAL DC_REFERENCE DEPH DATA_MODE TEMP
# netcdf                                                       GL_PR_XX_VOLZ.nc
# file_type                                                                  PR
# data_type                                                                  XX
# platform_code                                                            VOLZ
# wmo_platform_code                                                        VOLZ
# institution_edmo_code
# last_latitude_observation                                              62.558
# last_longitude_observation                                            -63.009
# last_date_observation                                    2014-09-24T07:19:00Z
#
#                                                                         34356  \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                     57.717
# geospatial_lat_max                                                     65.025
# geospatial_lon_min                                                    -12.979
# geospatial_lon_max                                                      8.983
# time_coverage_start                                      2013-09-21T15:14:00Z
# time_coverage_end                                        2013-10-25T05:34:00Z
# institution                                               Unknown institution
# date_update                                              2019-10-06T08:07:25Z
# data_mode                                                                   R
# parameters                                   DC_REFERENCE DEPH DATA_MODE TEMP
# netcdf                                                    GL_PR_XX_VOZ2040.nc
# file_type                                                                  PR
# data_type                                                                  XX
# platform_code                                                         VOZ2040
# wmo_platform_code                                                     VOZ2040
# institution_edmo_code
# last_latitude_observation                                              60.987
# last_longitude_observation                                             -1.430
# last_date_observation                                    2013-10-25T05:34:00Z
#
#                                                                         34357
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                      45.40
# geospatial_lat_max                                                      62.63
# geospatial_lon_min                                                     -46.17
# geospatial_lon_max                                                     -25.33
# time_coverage_start                                      1997-03-17T13:23:00Z
# time_coverage_end                                        1997-03-23T13:17:00Z
# institution                                           United states (Unknown)
# date_update                                              2019-10-06T08:13:16Z
# data_mode                                                                   R
# parameters                                   DC_REFERENCE PRES DATA_MODE TEMP
# netcdf                                                    GL_PR_XX_WBD9290.nc
# file_type                                                                  PR
# data_type                                                                  XX
# platform_code                                                         WBD9290
# wmo_platform_code                                                     WBD9290
# institution_edmo_code
# last_latitude_observation                                               62.63
# last_longitude_observation                                             -25.33
# last_date_observation                                    1997-03-23T13:17:00Z
#
# [21 rows x 34358 columns]

# %% [markdown]
# Above you can see, on the left hand side, a number of metadata fields that describes the files available in each collection (latest, monthly and history) of the product, such as: ftplink to download it (file_name), geospatial bounding box (geospatial_lat/lon_min/max), temporal coverage (time_coverage_start/end) etc.
#
# You can also see a dedicated column for each file with its corresponding values for the aforementioned descriptive metadata fields.

# %% [markdown]
# We will use all this information next to have a glimpse to the content of one of the product/dataset netCDF files collections.

# %% [markdown]
# ### 3.2. Choosing collection

# %% [markdown]
# `Set in the next cell the collection` you wanna get an overview of and `run it` afterwards. <br> We have selected the 'latest' by default but please feel free to change it:

# %%
targeted_collection = 'latest'
targeted_collection_info = info[info['file_name'].str.contains(targeted_collection)]
targeted_collection_info.transpose()
# Out:
#                                                                         0      \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                     57.001
# geospatial_lat_max                                                     57.001
# geospatial_lon_min                                                      4.696
# geospatial_lon_max                                                      4.696
# time_coverage_start                                      2021-01-13T02:13:09Z
# time_coverage_end                                        2021-01-13T02:13:09Z
# institution                             Institute of Marine Research (Norway)
# date_update                                              2021-01-13T23:15:07Z
# data_mode                                                                   R
# parameters                                        SIGMA_T PRES CNDC PSAL TEMP
# netcdf                                              AR_PR_CT_58JH_20210113.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                            58JH
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                    1351
# last_latitude_observation                                              57.001
# last_longitude_observation                                              4.696
# last_date_observation                                    2021-01-13T02:13:09Z
#
#                                                                         1      \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                     57.000
# geospatial_lat_max                                                     57.000
# geospatial_lon_min                                                      7.949
# geospatial_lon_max                                                      7.949
# time_coverage_start                                      2021-01-14T18:55:20Z
# time_coverage_end                                        2021-01-14T18:55:20Z
# institution                             Institute of Marine Research (Norway)
# date_update                                              2021-01-15T20:15:08Z
# data_mode                                                                   R
# parameters                                        SIGMA_T PRES CNDC PSAL TEMP
# netcdf                                              AR_PR_CT_58JH_20210114.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                            58JH
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                    1351
# last_latitude_observation                                              57.001
# last_longitude_observation                                              4.696
# last_date_observation                                    2021-01-13T02:13:09Z
#
#                                                                         2      \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                     63.308
# geospatial_lat_max                                                     63.308
# geospatial_lon_min                                                      3.130
# geospatial_lon_max                                                      3.130
# time_coverage_start                                      2021-01-18T22:00:29Z
# time_coverage_end                                        2021-01-18T22:00:29Z
# institution                             Institute of Marine Research (Norway)
# date_update                                              2021-01-19T23:15:16Z
# data_mode                                                                   R
# parameters                                        SIGMA_T PRES CNDC PSAL TEMP
# netcdf                                              AR_PR_CT_58JH_20210118.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                            58JH
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                    1351
# last_latitude_observation                                              57.001
# last_longitude_observation                                              4.696
# last_date_observation                                    2021-01-13T02:13:09Z
#
#                                                                         3      \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                     63.427
# geospatial_lat_max                                                     64.667
# geospatial_lon_min                                                      0.002
# geospatial_lon_max                                                      2.866
# time_coverage_start                                      2021-01-19T00:11:14Z
# time_coverage_end                                        2021-01-19T20:59:19Z
# institution                             Institute of Marine Research (Norway)
# date_update                                              2021-01-20T23:15:15Z
# data_mode                                                                   R
# parameters                                        SIGMA_T PRES CNDC PSAL TEMP
# netcdf                                              AR_PR_CT_58JH_20210119.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                            58JH
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                    1351
# last_latitude_observation                                              57.001
# last_longitude_observation                                              4.696
# last_date_observation                                    2021-01-13T02:13:09Z
#
#                                                                         4      \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                     66.005
# geospatial_lat_max                                                     66.005
# geospatial_lon_min                                                      1.998
# geospatial_lon_max                                                      1.998
# time_coverage_start                                      2021-01-20T12:02:10Z
# time_coverage_end                                        2021-01-20T12:02:10Z
# institution                             Institute of Marine Research (Norway)
# date_update                                              2021-01-21T23:15:14Z
# data_mode                                                                   R
# parameters                                        SIGMA_T PRES CNDC PSAL TEMP
# netcdf                                              AR_PR_CT_58JH_20210120.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                            58JH
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                    1351
# last_latitude_observation                                              57.001
# last_longitude_observation                                              4.696
# last_date_observation                                    2021-01-13T02:13:09Z
#
#                                                                         5      \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                     68.912
# geospatial_lat_max                                                     68.912
# geospatial_lon_min                                                     14.405
# geospatial_lon_max                                                     14.405
# time_coverage_start                                      2021-01-22T15:38:07Z
# time_coverage_end                                        2021-01-22T15:38:07Z
# institution                             Institute of Marine Research (Norway)
# date_update                                              2021-01-23T23:15:15Z
# data_mode                                                                   R
# parameters                                        SIGMA_T PRES CNDC PSAL TEMP
# netcdf                                              AR_PR_CT_58JH_20210122.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                            58JH
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                    1351
# last_latitude_observation                                              57.001
# last_longitude_observation                                              4.696
# last_date_observation                                    2021-01-13T02:13:09Z
#
#                                                                         6      \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                     70.666
# geospatial_lat_max                                                     71.501
# geospatial_lon_min                                                     19.791
# geospatial_lon_max                                                     19.962
# time_coverage_start                                      2021-01-24T02:27:03Z
# time_coverage_end                                        2021-01-24T14:54:57Z
# institution                             Institute of Marine Research (Norway)
# date_update                                              2021-01-25T23:15:16Z
# data_mode                                                                   R
# parameters                                        SIGMA_T PRES CNDC PSAL TEMP
# netcdf                                              AR_PR_CT_58JH_20210124.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                            58JH
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                    1351
# last_latitude_observation                                              57.001
# last_longitude_observation                                              4.696
# last_date_observation                                    2021-01-13T02:13:09Z
#
#                                                                         7      \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                     71.529
# geospatial_lat_max                                                     71.529
# geospatial_lon_min                                                     21.804
# geospatial_lon_max                                                     21.804
# time_coverage_start                                      2021-01-28T08:05:31Z
# time_coverage_end                                        2021-01-28T08:05:31Z
# institution                             Institute of Marine Research (Norway)
# date_update                                              2021-01-29T23:15:15Z
# data_mode                                                                   R
# parameters                                        SIGMA_T PRES CNDC PSAL TEMP
# netcdf                                              AR_PR_CT_58JH_20210128.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                            58JH
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                    1351
# last_latitude_observation                                              57.001
# last_longitude_observation                                              4.696
# last_date_observation                                    2021-01-13T02:13:09Z
#
#                                                                         8      \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                     71.222
# geospatial_lat_max                                                     71.222
# geospatial_lon_min                                                     25.250
# geospatial_lon_max                                                     25.250
# time_coverage_start                                      2021-01-31T23:48:59Z
# time_coverage_end                                        2021-01-31T23:48:59Z
# institution                             Institute of Marine Research (Norway)
# date_update                                              2021-02-01T20:15:09Z
# data_mode                                                                   R
# parameters                                        SIGMA_T PRES CNDC PSAL TEMP
# netcdf                                              AR_PR_CT_58JH_20210131.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                            58JH
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                    1351
# last_latitude_observation                                              57.001
# last_longitude_observation                                              4.696
# last_date_observation                                    2021-01-13T02:13:09Z
#
#                                                                         9      \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                     71.124
# geospatial_lat_max                                                     71.124
# geospatial_lon_min                                                     23.697
# geospatial_lon_max                                                     23.697
# time_coverage_start                                      2021-02-01T20:35:48Z
# time_coverage_end                                        2021-02-01T20:35:48Z
# institution                             Institute of Marine Research (Norway)
# date_update                                              2021-02-03T01:15:15Z
# data_mode                                                                   R
# parameters                                        SIGMA_T PRES CNDC PSAL TEMP
# netcdf                                              AR_PR_CT_58JH_20210201.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                            58JH
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                    1351
# last_latitude_observation                                              57.001
# last_longitude_observation                                              4.696
# last_date_observation                                    2021-01-13T02:13:09Z
#
#                             ...  \
# # product_id                ...
# file_name                   ...
# geospatial_lat_min          ...
# geospatial_lat_max          ...
# geospatial_lon_min          ...
# geospatial_lon_max          ...
# time_coverage_start         ...
# time_coverage_end           ...
# institution                 ...
# date_update                 ...
# data_mode                   ...
# parameters                  ...
# netcdf                      ...
# file_type                   ...
# data_type                   ...
# platform_code               ...
# wmo_platform_code           ...
# institution_edmo_code       ...
# last_latitude_observation   ...
# last_longitude_observation  ...
# last_date_observation       ...
#
#                                                                         14877  \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                    60.3104
# geospatial_lat_max                                                    60.3104
# geospatial_lon_min                                                   -21.8810
# geospatial_lon_max                                                   -21.8810
# time_coverage_start                                      2021-02-05T23:55:56Z
# time_coverage_end                                        2021-02-05T23:55:56Z
# institution                               Met Office (Ocean Weather Services)
# date_update                                              2021-02-06T03:01:19Z
# data_mode                                                                   M
# parameters                  PRES VERTICAL_SAMPLING_SCHEME PSAL TEMP_ADJUST...
# netcdf                                           GL_PR_PF_6901176_20210205.nc
# file_type                                                                  PR
# data_type                                                                  PF
# platform_code                                                         6901176
# wmo_platform_code                                                     6901176
# institution_edmo_code                                                      29
# last_latitude_observation                                             60.3104
# last_longitude_observation                                           -21.8810
# last_date_observation                                    2021-02-05T23:55:56Z
#
#                                                                         14904  \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                    60.0168
# geospatial_lat_max                                                    60.0168
# geospatial_lon_min                                                   -26.4192
# geospatial_lon_max                                                   -26.4192
# time_coverage_start                                      2021-02-05T15:29:46Z
# time_coverage_end                                        2021-02-05T15:29:46Z
# institution                               Met Office (Ocean Weather Services)
# date_update                                              2021-02-05T21:04:40Z
# data_mode                                                                   M
# parameters                  PRES VERTICAL_SAMPLING_SCHEME PSAL TEMP_ADJUST...
# netcdf                                           GL_PR_PF_6901199_20210205.nc
# file_type                                                                  PR
# data_type                                                                  PF
# platform_code                                                         6901199
# wmo_platform_code                                                     6901199
# institution_edmo_code                                                      29
# last_latitude_observation                                             60.0168
# last_longitude_observation                                           -26.4192
# last_date_observation                                    2021-02-05T15:29:46Z
#
#                                                                         14926  \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                   63.54071
# geospatial_lat_max                                                   63.54071
# geospatial_lon_min                                                  -17.90497
# geospatial_lon_max                                                  -17.90497
# time_coverage_start                                      2021-02-05T00:00:00Z
# time_coverage_end                                        2021-02-05T23:00:00Z
# institution                 National Data Buoy Center (NDBC)  National Oce...
# date_update                                              2021-02-06T02:31:44Z
# data_mode                                                                   R
# parameters                                             ATMS DC_REFERENCE DEPH
# netcdf                                           GL_TS_DB_6402542_20210205.nc
# file_type                                                                  TS
# data_type                                                                  DB
# platform_code                                                         6402542
# wmo_platform_code                                                     6402542
# institution_edmo_code                                                    1463
# last_latitude_observation                                            63.54071
# last_longitude_observation                                          -17.90497
# last_date_observation                                    2021-02-05T00:00:00Z
#
#                                                                         14936  \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                    62.1133
# geospatial_lat_max                                                    62.1133
# geospatial_lon_min                                                   -52.4075
# geospatial_lon_max                                                   -52.4075
# time_coverage_start                                      2021-02-06T16:32:24Z
# time_coverage_end                                        2021-02-06T16:32:24Z
# institution                   National Oceanography Centre  Southampton (NOC)
# date_update                                              2021-02-06T21:02:39Z
# data_mode                                                                   M
# parameters                  PRES VERTICAL_SAMPLING_SCHEME PSAL TEMP_ADJUST...
# netcdf                                           GL_PR_PF_6901200_20210206.nc
# file_type                                                                  PR
# data_type                                                                  PF
# platform_code                                                         6901200
# wmo_platform_code                                                     6901200
# institution_edmo_code                                                      17
# last_latitude_observation                                             62.1133
# last_longitude_observation                                           -52.4075
# last_date_observation                                    2021-02-06T16:32:24Z
#
#                                                                         14958  \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                   81.76726
# geospatial_lat_max                                                   81.76726
# geospatial_lon_min                                                   25.45806
# geospatial_lon_max                                                   25.45806
# time_coverage_start                                      2021-02-06T04:57:20Z
# time_coverage_end                                        2021-02-06T04:57:20Z
# institution                 Bundesamt fur Seeschifffahrt und Hydrographie ...
# date_update                                              2021-02-08T17:01:44Z
# data_mode                                                                   R
# parameters                  PRES VERTICAL_SAMPLING_SCHEME PSAL DC_REFERENC...
# netcdf                                           GL_PR_PF_7900550_20210206.nc
# file_type                                                                  PR
# data_type                                                                  PF
# platform_code                                                         7900550
# wmo_platform_code                                                     7900550
# institution_edmo_code                                                    1850
# last_latitude_observation                                            81.76726
# last_longitude_observation                                           25.45806
# last_date_observation                                    2021-02-06T04:57:20Z
#
#                                                                         14961  \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                   59.97444
# geospatial_lat_max                                                   60.01332
# geospatial_lon_min                                                  -24.32733
# geospatial_lon_max                                                  -24.27061
# time_coverage_start                                      2021-02-08T00:00:00Z
# time_coverage_end                                        2021-02-08T23:45:00Z
# institution                 National Data Buoy Center (NDBC)  National Oce...
# date_update                                              2021-02-09T02:30:29Z
# data_mode                                                                   R
# parameters                                             ATMS DC_REFERENCE DEPH
# netcdf                                           GL_TS_DB_4401894_20210208.nc
# file_type                                                                  TS
# data_type                                                                  DB
# platform_code                                                         4401894
# wmo_platform_code                                                     4401894
# institution_edmo_code                                                    1463
# last_latitude_observation                                            60.01328
# last_longitude_observation                                          -24.32126
# last_date_observation                                    2021-02-08T23:45:00Z
#
#                                                                         14962  \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                   60.00202
# geospatial_lat_max                                                   60.04506
# geospatial_lon_min                                                  -24.33221
# geospatial_lon_max                                                  -24.15729
# time_coverage_start                                      2021-02-09T00:00:00Z
# time_coverage_end                                        2021-02-09T23:45:00Z
# institution                 National Data Buoy Center (NDBC)  National Oce...
# date_update                                              2021-02-10T02:32:23Z
# data_mode                                                                   R
# parameters                                             ATMS DC_REFERENCE DEPH
# netcdf                                           GL_TS_DB_4401894_20210209.nc
# file_type                                                                  TS
# data_type                                                                  DB
# platform_code                                                         4401894
# wmo_platform_code                                                     4401894
# institution_edmo_code                                                    1463
# last_latitude_observation                                            60.01328
# last_longitude_observation                                          -24.32126
# last_date_observation                                    2021-02-08T23:45:00Z
#
#                                                                         14963  \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                   60.04714
# geospatial_lat_max                                                   60.15346
# geospatial_lon_min                                                  -24.21477
# geospatial_lon_max                                                  -24.11694
# time_coverage_start                                      2021-02-10T00:02:00Z
# time_coverage_end                                        2021-02-10T23:45:00Z
# institution                 National Data Buoy Center (NDBC)  National Oce...
# date_update                                              2021-02-11T02:34:55Z
# data_mode                                                                   R
# parameters                                             ATMS DC_REFERENCE DEPH
# netcdf                                           GL_TS_DB_4401894_20210210.nc
# file_type                                                                  TS
# data_type                                                                  DB
# platform_code                                                         4401894
# wmo_platform_code                                                     4401894
# institution_edmo_code                                                    1463
# last_latitude_observation                                            60.01328
# last_longitude_observation                                          -24.32126
# last_date_observation                                    2021-02-08T23:45:00Z
#
#                                                                         14964  \
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                   60.04803
# geospatial_lat_max                                                   60.11469
# geospatial_lon_min                                                  -24.26212
# geospatial_lon_max                                                  -24.20898
# time_coverage_start                                      2021-02-11T00:04:00Z
# time_coverage_end                                        2021-02-11T22:15:00Z
# institution                 National Data Buoy Center (NDBC)  National Oce...
# date_update                                              2021-02-12T04:39:05Z
# data_mode                                                                   R
# parameters                                             ATMS DC_REFERENCE DEPH
# netcdf                                           GL_TS_DB_4401894_20210211.nc
# file_type                                                                  TS
# data_type                                                                  DB
# platform_code                                                         4401894
# wmo_platform_code                                                     4401894
# institution_edmo_code                                                    1463
# last_latitude_observation                                            60.01328
# last_longitude_observation                                          -24.32126
# last_date_observation                                    2021-02-08T23:45:00Z
#
#                                                                         14965
# # product_id                                                        COP-AR-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_ARC_NRT_OBSE...
# geospatial_lat_min                                                    59.9998
# geospatial_lat_max                                                    60.1628
# geospatial_lon_min                                                   -19.7312
# geospatial_lon_max                                                   -19.3808
# time_coverage_start                                      2021-02-11T00:00:00Z
# time_coverage_end                                        2021-02-11T22:00:00Z
# institution                 Meteo-France / Centre de Meteorologie Marine (...
# date_update                                              2021-02-12T04:27:26Z
# data_mode                                                                   R
# parameters                                        ATMS DC_REFERENCE DEPH TEMP
# netcdf                                           GL_TS_DB_4101658_20210211.nc
# file_type                                                                  TS
# data_type                                                                  DB
# platform_code                                                         4101658
# wmo_platform_code                                                     4101658
# institution_edmo_code                                                    1190
# last_latitude_observation                                             60.1628
# last_longitude_observation                                           -19.3808
# last_date_observation                                    2021-02-11T22:00:00Z
#
# [21 rows x 7367 columns]

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>IMPORTANT</b>
#
# ***
# Please remember available options for the collection:
# <ul>
#     <li><i>latest</i>: daily files from platforms (last 30 days of data)</li>
#     <li><i>monthly</i>: monthly files from platforms (last 5 years of data)</li>
#     <li><i>history</i>: one file per platform (all platform data)</li>
# </ul>

# %% [markdown]
# ### 3.3. Overview

# %% [markdown]
# #### 3.3.1. Platforms

# %% [markdown]
# Any In Situ NRT products/datasets collections are composed by files reported by a network of platforms located in the area.

# %% [markdown]
# Let's `run the next cell` to know how many platforms are contributing to this product/dataset collection with files:

# %%
len(targeted_collection_info.groupby('platform_code').groups)
# Out:
# 351

# %% [markdown]
# Let's get a closer look to this list of platforms: `run the next cells`:

# %%
data_platforms = [{
    'code':code, 
    'provider(s)': files['institution_edmo_code'].iloc[0],
    'files': {
        'nfiles': len(files), 
        'feature(s)': [{'code': ftype, 'nfiles':len(files.groupby('file_type').get_group(ftype)),'sources(s)': [{'code': dtype, 'nfiles': len(files.groupby('file_type').get_group(ftype).groupby('data_type').get_group(dtype)), 'parameters': [param for param in sum([files.groupby('file_type').get_group(ftype).groupby('data_type').get_group(dtype)['parameters'].unique().tolist()],[])[0].split(' ') if '_' not in param and param not in ['DEPH', 'PRES'] and param != '']} for dtype in files[files['file_type']==ftype]['data_type'].unique().tolist()]} for ftype in files['file_type'].unique().tolist()]}
} for code,files in targeted_collection_info.groupby(['platform_code'])]

# %%
IPython.display.HTML(json2html.convert(data_platforms))
# Out:
# <table border="1"><thead><tr><th>code</th><th>provider(s)</th><th>files</th></tr></thead><tbody><tr><td>2101800</td><td> </td><td><table border="1"><tr><th>nfiles</th><td>29</td></tr><tr><th>feature(s)</th><td><table border="1"><thead><tr><th>code</th><th>nfiles</th><th>sources(s)</th></tr></thead><tbody><tr><td>TS</td><td>29</td><td><table border="1"><thead><tr><th>code</th><th>nfiles</th><th>parameters</th></tr></thead><tbody><tr><td>DB</td><td>29</td><td><ul><li>ATMS</li><li>TEMP</li></ul></td></tr></tbody></table></td></tr></tbody></table></td></tr></table></td></tr><tr><td>2101801</td><td> </td><td><table border="1"><tr><th>nfiles</th><td>16</td></tr><tr><th>feature(s)</th><td><table border="1"><thead><tr><th>code</th><th>nfiles</th><th>sources(s)</th></tr></thead><tbody><tr><td>TS</td><td>16</td><td><table border="1"><thead><tr><th>code</th><th>nfiles</th><th>parameters</th></tr></thead><tbody><tr><td>DB</td><td>16</td><td><ul><li>ATMS</li><li>TEMP</li></ul></td></tr></tbody></table></td></tr></tbody></table></td></tr></table></td></tr><tr><td>2101803</td><td> </td><td><table border="1"><tr><th>nfiles</th><td>13</td></tr><tr><th>feature(s)</th><td><table border="1"><thead><tr><th>code</th><th>nfiles</th><th>sources(s)</th></tr></thead><tbody><tr><td>TS</td><td>13</td><td><table border="1"><thead><tr><th>code</th><th>nfiles</th><th>parameters</th></tr></thead><tbody><tr><td>DB</td><td>13</td><td><ul><li>ATMS</li><li>TEMP</li></ul></td></tr></tbody></table></td></tr></tbody></table></td></tr></table></td></tr><tr><td>2101804</td><td> </td><td><table border="1"><tr><th>nfiles</th><td>15</td></tr><tr><th>feature(s)</th><td><table border="1"><thead><tr><th>code</th><th>nfiles</th><th>sources(s)</th></tr></thead><tbody><tr><td>TS</td><td>15</td><td><table border="1"><thead><tr><th>code</th><th>nfiles</th><th>parameters</th></tr></thead><tbody><tr><td>DB</td><td>15</td><td><ul><li>ATMS</li><li>TEMP</li></ul></td></tr></tbody></table></td></tr></tbody></table></td></tr></table></td></tr><tr><td>2101805</td><td> </td><td><table border="1"><tr><th>nfiles</th><td>25</td></tr><tr><th>feature(s)</th><td><table border="1"><thead><tr><th>code</th><th>nfiles</th><th>sources(s)</th></tr></thead><tbody><tr><td>TS</td><td>25</td><td><table border="1"><thead><tr><th>code</th><th>nfiles</th><th>parameters</th></tr></thead><tbody><tr><td>DB</td><td>25</td><td><ul><li>ATMS</li><li>TEMP</li></ul></td></tr></tbody></table></td></tr></tbody></table></td></tr></table></td></tr><tr><td>2101806</td><td> </td><td><table border="1"><tr><th>nfiles</th><td>28</td></tr><tr><th>feature(s)</th><td><table border="1"><thead><tr><th>code</th><th>nfiles</th><th>sources(s)</th></tr></thead><tbody><tr><td>TS</td><td>28</td><td><table border="1"><thead><tr><th>code</th><th>nfiles</th><th>parameters</th></tr></thead><tbody><tr><td>DB</td><td>28</td><td><ul><li>ATMS</li><li>TEMP</li></ul></td></tr></tbody></table></td></tr></tbody></table></td></tr></table></td></tr><tr><td>2501510</td><td> </td><td><table border="1"><tr><th>nfiles</th><td>23</td></tr><tr><th>feature(s)</th><td><table border="1"><thead><tr><th>code</th><th>nfiles</th><th>sources(s)</th></tr></thead><tbody><tr><td>TS</td><td>23</td><td><table border="1"><thead><tr><th>code</th><th>nfiles</th><th>parameters</th></tr></thead><tbody><tr><td>DB</td><td>23</td><td></td></tr></tbody></table></td></tr></tbody></table></td></tr></table></td></tr><tr><td>2501512</td><td> </td><td><table border="1"><tr><th>nfiles</th><td>4</td></tr><tr><th>feature(s)</th><td><table border="1"><thead><tr><th>code</th><th>nfiles</th><th>sources(s)</th></tr></thead><tbody><tr><td>TS</td><td>4</td><td><table border="1"><thead><tr><th>code</th><th>nfiles</th><th>parameters</th></tr></thead><tbody><tr><td>DB</td><td>4</td><td></td></tr></tbody></table></td></tr></tbody></table></td></tr></table></td></tr><tr><td>2501514</td><td> </td><td><table border="1"><tr><th>nfiles</th><td>2</td></tr><tr><th>feature(s)</th><td><table border="1 ...

# %% [markdown]
# Too much info? Let's see one in particular! `Run the next cells`:
# <a id='platform_selected'></a>

# %%
code = '46081'

# %%
selection = [platform for platform in data_platforms if platform['code'] == code]
IPython.display.HTML(json2html.convert(selection))
# Out:
# <table border="1"><thead><tr><th>code</th><th>provider(s)</th><th>files</th></tr></thead><tbody><tr><td>46081</td><td>1463</td><td><table border="1"><tr><th>nfiles</th><td>61</td></tr><tr><th>feature(s)</th><td><table border="1"><thead><tr><th>code</th><th>nfiles</th><th>sources(s)</th></tr></thead><tbody><tr><td>TS</td><td>31</td><td><table border="1"><thead><tr><th>code</th><th>nfiles</th><th>parameters</th></tr></thead><tbody><tr><td>MO</td><td>31</td><td><ul><li>WSPD</li><li>DEWT</li><li>GSPD</li><li>DRYT</li><li>TEMP</li><li>ATMP</li><li>VHM0</li><li>WDIR</li><li>VTPK</li></ul></td></tr></tbody></table></td></tr><tr><td>WS</td><td>30</td><td><table border="1"><thead><tr><th>code</th><th>nfiles</th><th>parameters</th></tr></thead><tbody><tr><td>MO</td><td>30</td><td><ul><li>THETA2</li><li>FREQUENCY</li><li>THETA1</li><li>STHETA2</li><li>STHETA1</li><li>VSPEC1D</li></ul></td></tr></tbody></table></td></tr></tbody></table></td></tr></table></td></tr></tbody></table>

# %% [markdown]
# So far we can see that each platform:
# * Can have one or more providers - identified by a blank-separated list of one or more codes: the so called *edmo code* (we will see more about this later).
# * Produces different type of files (see above `TS` and `WS` *feature* bigram) from one or more data sources (see above `MO` *source* bigram) and containing more or less parameters (see *parameters* codes). We will see next more about this!

# %% [markdown]
# Ok but...where is it located? There are some geographical references that we can use to infer the location of the platform:
# * the bounding box of the produced files (this is, the spatial coverage - a rectangular simplification actually - of the data measured by the platform)
# * the last position reported.

# %% [markdown]
# Let's draw all them on a map to get an idea!: `run the next cell`

# %%
#initializing map
m = folium.Map(location=[39.0, 0], zoom_start=4)
#Looping over each file produced by the platform above
for idx,file in targeted_collection_info[targeted_collection_info['platform_code'] == code].iterrows():
    #Bounding-box of each file to map as polygon
    upper_left = [file['geospatial_lat_max'], file['geospatial_lon_min']]
    upper_right = [file['geospatial_lat_max'], file['geospatial_lon_max']]
    lower_right = [file['geospatial_lat_min'], file['geospatial_lon_max']]
    lower_left = [file['geospatial_lat_min'], file['geospatial_lon_min']]
    edges = [upper_left, upper_right, lower_right, lower_left]
    m.add_child(folium.vector_layers.Polygon(locations=edges, popup='file bbox: '+file['netcdf']))
#Last reported position to map as marker
m.add_child(folium.Marker([file['last_latitude_observation'], file['last_longitude_observation']], popup=file['platform_code']+' last position' ))
#Zooming closer
m.fit_bounds(edges, max_zoom=6)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_0a287b26e6364f0e823794bedb6d229c%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_0a287b26e6364f0e823794bedb6d229c%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_0a287b26e6364f0e823794bedb6d229c%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_0a287b26e6364f0e823794bedb6d229c%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B39.0%2C%200.0%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20crs ...

# %% [markdown]
# On the next tutorial we will see how to use this very same geographical info to select only those files covering a specific area.

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>WARNING</b>
#
# ***
# **Don't you see the map?** Please open the notebook in a different browser (i.e Chrome!) as some have problems rendering folium maps.

# %% [markdown]
# #### 3.3.2. Source types (data types)

# %% [markdown]
# `Data sources` represents the elements that report oceanographic data. <br>So far the In Situ TAC distinguishes:

# %% [markdown]
# | code | description |
# | ------- | ------- |
# |BO | Bottle |
# |BA | Data from Bathy messages on GTS |
# |DB | Drifting buoys |
# |DC | Drifting buoy reporting calculated sea water current |
# |FB | FerryBox |
# |MO | Fixed buoys or moorings |
# |TG | Tide gauges |
# |GL | Gliders |
# |ML | Mini logger |
# |CT | Oceanographic CTD profiles | //historic index file el data_type es "oceanographic CTD profiles"
# |PF | Profiling floats vertical profiles |
# |RE | Recopesca |
# |RF | River flows |
# |SF | Scanfish profiles |
# |TS | Thermosalinograph data |
# |XB | XBT or XCTD profiles |
# |TE | Data from TESAC messages on GTS |
# |SM | Sea-mammals |
# |HF | High Frequency Radar |
# |SD | Saildrone |
# |VA | Vessel mounted ADCP |
# |XX | Unknown |

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>TIP</b>
#
# ***
# To find the updated catalog of possible codes for data sources (`data types` in documentation) please check the <a href="https://archimer.ifremer.fr/doc/00324/43494/" target="_blank">Product User Manual</a>.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b style="margin-right: 2em">CHALLENGE</b> Do you find in there the data type of <a href="#platform_selected">the platform</a> we were looking at in the platform section?
#
# ***
# In the end the platform we are checking is a:
# * Fixed-buoy or mooring (MO)

# %% [markdown]
# Ok, this is the full list but; which ones are actually available in this product/dataset/collection?<br> `Run the next cell` to discover them:

# %%
targeted_collection_info['data_type'].unique().tolist()
# Out:
# ['CT', 'GL', 'MO', 'PF', 'SM', 'HF', 'DB', 'RF', 'TG', 'TS']

# %% [markdown]
# And, How many of each? `Run the next cells`...

# %%
data_types = [{
    'code':code,
    'platforms': {'nplatforms': len(files.groupby('platform_code')),'files': {'nfiles': len(files), 'features(s)': [{'code':ftype, 'nfiles': len(files.groupby('data_type').get_group(code).groupby('file_type').get_group(ftype)), 'nplatforms': len(files.groupby('data_type').get_group(code).groupby('platform_code'))} for ftype in files[files['data_type']==code]['file_type'].unique().tolist()]}}
} for code,files in targeted_collection_info.groupby(['data_type'])]

# %%
IPython.display.HTML(json2html.convert(data_types))
# Out:
# <table border="1"><thead><tr><th>code</th><th>platforms</th></tr></thead><tbody><tr><td>CT</td><td><table border="1"><tr><th>nplatforms</th><td>6</td></tr><tr><th>files</th><td><table border="1"><tr><th>nfiles</th><td>149</td></tr><tr><th>features(s)</th><td><table border="1"><thead><tr><th>code</th><th>nfiles</th><th>nplatforms</th></tr></thead><tbody><tr><td>PR</td><td>149</td><td>6</td></tr></tbody></table></td></tr></table></td></tr></table></td></tr><tr><td>DB</td><td><table border="1"><tr><th>nplatforms</th><td>179</td></tr><tr><th>files</th><td><table border="1"><tr><th>nfiles</th><td>4711</td></tr><tr><th>features(s)</th><td><table border="1"><thead><tr><th>code</th><th>nfiles</th><th>nplatforms</th></tr></thead><tbody><tr><td>TS</td><td>4711</td><td>179</td></tr></tbody></table></td></tr></table></td></tr></table></td></tr><tr><td>GL</td><td><table border="1"><tr><th>nplatforms</th><td>2</td></tr><tr><th>files</th><td><table border="1"><tr><th>nfiles</th><td>50</td></tr><tr><th>features(s)</th><td><table border="1"><thead><tr><th>code</th><th>nfiles</th><th>nplatforms</th></tr></thead><tbody><tr><td>PR</td><td>50</td><td>2</td></tr></tbody></table></td></tr></table></td></tr></table></td></tr><tr><td>HF</td><td><table border="1"><tr><th>nplatforms</th><td>4</td></tr><tr><th>files</th><td><table border="1"><tr><th>nfiles</th><td>120</td></tr><tr><th>features(s)</th><td><table border="1"><thead><tr><th>code</th><th>nfiles</th><th>nplatforms</th></tr></thead><tbody><tr><td>RV</td><td>90</td><td>4</td></tr><tr><td>TV</td><td>30</td><td>4</td></tr></tbody></table></td></tr></table></td></tr></table></td></tr><tr><td>MO</td><td><table border="1"><tr><th>nplatforms</th><td>16</td></tr><tr><th>files</th><td><table border="1"><tr><th>nfiles</th><td>550</td></tr><tr><th>features(s)</th><td><table border="1"><thead><tr><th>code</th><th>nfiles</th><th>nplatforms</th></tr></thead><tbody><tr><td>TS</td><td>490</td><td>16</td></tr><tr><td>WS</td><td>60</td><td>16</td></tr></tbody></table></td></tr></table></td></tr></table></td></tr><tr><td>PF</td><td><table border="1"><tr><th>nplatforms</th><td>94</td></tr><tr><th>files</th><td><table border="1"><tr><th>nfiles</th><td>334</td></tr><tr><th>features(s)</th><td><table border="1"><thead><tr><th>code</th><th>nfiles</th><th>nplatforms</th></tr></thead><tbody><tr><td>PR</td><td>334</td><td>94</td></tr></tbody></table></td></tr></table></td></tr></table></td></tr><tr><td>RF</td><td><table border="1"><tr><th>nplatforms</th><td>22</td></tr><tr><th>files</th><td><table border="1"><tr><th>nfiles</th><td>629</td></tr><tr><th>features(s)</th><td><table border="1"><thead><tr><th>code</th><th>nfiles</th><th>nplatforms</th></tr></thead><tbody><tr><td>TS</td><td>629</td><td>22</td></tr></tbody></table></td></tr></table></td></tr></table></td></tr><tr><td>SM</td><td><table border="1"><tr><th>nplatforms</th><td>3</td></tr><tr><th>files</th><td><table border="1"><tr><th>nfiles</th><td>64</td></tr><tr><th>features(s)</th><td><table border="1"><thead><tr><th>code</th><th>nfiles</th><th>nplatforms</th></tr></thead><tbody><tr><td>PR</td><td>64</td><td>3</td></tr></tbody></table></td></tr></table></td></tr></table></td></tr><tr><td>TG</td><td><table border="1"><tr><th>nplatforms</th><td>24</td></tr><tr><th>files</th><td><table border="1"><tr><th>nfiles</th><td>744</td></tr><tr><th>features(s)</th><td><table border="1"><thead><tr><th>code</th><th>nfiles</th><th>nplatforms</th></tr></thead><tbody><tr><td>TS</td><td>744</td><td>24</td></tr></tbody></table></td></tr></table></td></tr></table></td></tr><tr><td>TS</td><td><table border="1"><tr><th>nplatforms</th><td>1</td></tr><tr><th>files</th><td><table border="1"><tr><th>nfiles</th><td>16</td></tr><tr><th>features(s)</th><td><table border="1"><thead><tr><th>code</th><th>nfiles</th><th>nplatforms</th></tr></thead><tbody><tr><td>TS</td><td>16</td><td>1</td></tr></tbody></table></td></tr></table></td></tr></table></td></tr></tbody></table>

# %% [markdown]
# Too much info? Choose just one! `Run the next cell`:

# %%
code = 'DB'

# %%
selection = [dtype for dtype in data_types if dtype['code'] == code]
IPython.display.HTML(json2html.convert(selection))
# Out:
# <table border="1"><thead><tr><th>code</th><th>platforms</th></tr></thead><tbody><tr><td>DB</td><td><table border="1"><tr><th>nplatforms</th><td>179</td></tr><tr><th>files</th><td><table border="1"><tr><th>nfiles</th><td>4711</td></tr><tr><th>features(s)</th><td><table border="1"><thead><tr><th>code</th><th>nfiles</th><th>nplatforms</th></tr></thead><tbody><tr><td>TS</td><td>4711</td><td>179</td></tr></tbody></table></td></tr></table></td></tr></table></td></tr></tbody></table>

# %% [markdown]
# #### 3.3.3. Feature types (file types)

# %% [markdown]
# `Feature types` represents the shape of the data reported by a given platform data source. <br>So far the In Situ TAC distinguishes 4 feature types:

# %% [markdown]
# | code | description |
# | ------- | ------- |
# |TS | Time Serie or trajectories |
# |PR | Profile |
# |TV | Grided data - High Frequency Radar total velocity fields |
# |RV | Grided data - High Frequency Radar radial velocity fields |
# |WS | Wave spectra |

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>TIP</b>
#
# ***
# To find the updated catalog of possible codes for feature types (`file types` in documentation) please check the <a href="https://archimer.ifremer.fr/doc/00324/43494/" target="_blank">Product User Manual</a>.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b style="margin-right: 2em">CHALLENGE</b>Do you find in there the feature types of <a href="#platform_selected">the platform</a> we were looking at in the platform section?
#
# ***
# * WS  - Wave spectra
# * TS - Time series of certain oceanographic parameters

# %% [markdown]
# Ok, this is the full list but; which ones are actually available in this product/dataset/collection?<br> `Run the next cell`to know!

# %%
targeted_collection_info['file_type'].unique().tolist()
# Out:
# ['PR', 'TS', 'RV', 'WS', 'TV']

# %% [markdown]
# And, How many of each? `Run the next cells`...

# %%
file_types = [{
    'code':code,
    'platforms': {'nplatforms': len(files.groupby('platform_code')),'files': {'nfiles': len(files), 'sources(s)': [{'code':dtype, 'nfiles': len(files.groupby('file_type').get_group(code).groupby('data_type').get_group(dtype)), 'nplatforms': len(files.groupby('file_type').get_group(code).groupby('data_type').get_group(dtype).groupby('platform_code'))} for dtype in files[files['file_type']==code]['data_type'].unique().tolist()]}}
} for code,files in targeted_collection_info.groupby(['file_type'])]

# %%
IPython.display.HTML(json2html.convert(file_types))
# Out:
# <table border="1"><thead><tr><th>code</th><th>platforms</th></tr></thead><tbody><tr><td>PR</td><td><table border="1"><tr><th>nplatforms</th><td>105</td></tr><tr><th>files</th><td><table border="1"><tr><th>nfiles</th><td>597</td></tr><tr><th>sources(s)</th><td><table border="1"><thead><tr><th>code</th><th>nfiles</th><th>nplatforms</th></tr></thead><tbody><tr><td>CT</td><td>149</td><td>6</td></tr><tr><td>GL</td><td>50</td><td>2</td></tr><tr><td>PF</td><td>334</td><td>94</td></tr><tr><td>SM</td><td>64</td><td>3</td></tr></tbody></table></td></tr></table></td></tr></table></td></tr><tr><td>RV</td><td><table border="1"><tr><th>nplatforms</th><td>3</td></tr><tr><th>files</th><td><table border="1"><tr><th>nfiles</th><td>90</td></tr><tr><th>sources(s)</th><td><table border="1"><thead><tr><th>code</th><th>nfiles</th><th>nplatforms</th></tr></thead><tbody><tr><td>HF</td><td>90</td><td>3</td></tr></tbody></table></td></tr></table></td></tr></table></td></tr><tr><td>TS</td><td><table border="1"><tr><th>nplatforms</th><td>242</td></tr><tr><th>files</th><td><table border="1"><tr><th>nfiles</th><td>6590</td></tr><tr><th>sources(s)</th><td><table border="1"><thead><tr><th>code</th><th>nfiles</th><th>nplatforms</th></tr></thead><tbody><tr><td>MO</td><td>490</td><td>16</td></tr><tr><td>DB</td><td>4711</td><td>179</td></tr><tr><td>RF</td><td>629</td><td>22</td></tr><tr><td>TG</td><td>744</td><td>24</td></tr><tr><td>TS</td><td>16</td><td>1</td></tr></tbody></table></td></tr></table></td></tr></table></td></tr><tr><td>TV</td><td><table border="1"><tr><th>nplatforms</th><td>1</td></tr><tr><th>files</th><td><table border="1"><tr><th>nfiles</th><td>30</td></tr><tr><th>sources(s)</th><td><table border="1"><thead><tr><th>code</th><th>nfiles</th><th>nplatforms</th></tr></thead><tbody><tr><td>HF</td><td>30</td><td>1</td></tr></tbody></table></td></tr></table></td></tr></table></td></tr><tr><td>WS</td><td><table border="1"><tr><th>nplatforms</th><td>2</td></tr><tr><th>files</th><td><table border="1"><tr><th>nfiles</th><td>60</td></tr><tr><th>sources(s)</th><td><table border="1"><thead><tr><th>code</th><th>nfiles</th><th>nplatforms</th></tr></thead><tbody><tr><td>MO</td><td>60</td><td>2</td></tr></tbody></table></td></tr></table></td></tr></table></td></tr></tbody></table>

# %% [markdown]
# #### 3.3.4. Parameters
# `parameters` represents the oceanographic variables measured by the platform and therefore present in its files. <br>So far the In Situ TAC distinguishes the next ones (zoom with the -|+ controls if you do not see it properly): `run the next cell`

# %%
IPython.display.IFrame('https://archimer.ifremer.fr/doc/00422/53381/72333.pdf', width='100%', height=350)
# Out:
#         <iframe
#             width="100%"
#             height="350"
#             src="https://archimer.ifremer.fr/doc/00422/53381/72333.pdf"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>TIP</b>
#
# ***
# To find the updated catalog of parameters please check <a href="https://archimer.ifremer.fr/doc/00422/53381/" target="_blank">this</a>.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b style="margin-right: 2em">CHALLENGE</b> Do you find in there the feature types of <a href="#platform_selected">the platform</a> we were looking at in the platform section?
#
# ***
# In the end the platform we are checking is a profiler reporting:
# * Temperature, Significant Wave Height, Average period highest 1/3 wave, Wave scalar spectral density etc

# %% [markdown]
# Ok, this is the full list but; which ones are actually available in this product/dataset collection? `Run the next cell`and discover it!:

# %%
parameter_list = [param for param in list(set(sum([parameter.split(' ') for parameter in targeted_collection_info['parameters'].tolist()],[]))) if '_' not in param and param not in ['DEPH', 'PRES'] and param != '']
parameter_list
# Out:
# ['SLTR',
#  'SSJT',
#  'SCDR',
#  'VAVH',
#  'PSAL',
#  'EWCS',
#  'ATMP',
#  'NSCS',
#  'MAXV',
#  'TEMP',
#  'BEAR',
#  'STHETA2',
#  'PHPH',
#  'SLTT',
#  'VSPEC1D',
#  'crs',
#  'VTZA',
#  'MINV',
#  'ERTC',
#  'LGHT',
#  'FREQUENCY',
#  'ERSC',
#  'XDST',
#  'NSCT',
#  'WSPD',
#  'RDVA',
#  'VHM0',
#  'THETA1',
#  'SCDT',
#  'DRVA',
#  'SLEV',
#  'THETA2',
#  'SLNT',
#  'DOX2',
#  'QCflag',
#  'NTAW',
#  'WDIR',
#  'STHETA1',
#  'GDOP',
#  'SLNR',
#  'NARX',
#  'CPHL',
#  'YDST',
#  'NATX',
#  'SPRC',
#  'CCOV',
#  'CDOM',
#  'VTPK',
#  'ETMP',
#  'RVFL',
#  'DOXY',
#  'GSPD',
#  'ESPC',
#  'BBP700',
#  'RNGE',
#  'ATMS',
#  'EWCT',
#  'CNDC',
#  'DEWT',
#  'DRYT']

# %% [markdown]
# And, How many of each? `Run the next cells`...

# %%
parameters = [{
    'code':code,
    'platforms':{
        'nplatforms': len(targeted_collection_info[targeted_collection_info['parameters'].str.contains(code)].groupby('platform_code')),
        'files':{
            'nfiles': len(targeted_collection_info[targeted_collection_info['parameters'].str.contains(code)]), 
            'feature(s)': [{'code': ftype, 'nplatforms': len(targeted_collection_info[targeted_collection_info['parameters'].str.contains(code)].groupby('file_type').get_group(ftype).groupby('platform_code')), 'nfiles':len(targeted_collection_info[targeted_collection_info['parameters'].str.contains(code)].groupby('file_type').get_group(ftype)),'sources(s)': [{'code': dtype, 'nplatforms' : len(targeted_collection_info[targeted_collection_info['parameters'].str.contains(code)].groupby('file_type').get_group(ftype).groupby('data_type').get_group(dtype).groupby('platform_code')) ,'nfiles': len(targeted_collection_info[targeted_collection_info['parameters'].str.contains(code)].groupby('file_type').get_group(ftype).groupby('data_type').get_group(dtype))} for dtype in targeted_collection_info[targeted_collection_info['parameters'].str.contains(code)][targeted_collection_info['file_type']==ftype]['data_type'].unique().tolist()]} for ftype in targeted_collection_info[targeted_collection_info['parameters'].str.contains(code)]['file_type'].unique().tolist()]
        }
    }
} for code in parameter_list]

# %%
IPython.display.HTML(json2html.convert(parameters))
# Out:
# <table border="1"><thead><tr><th>code</th><th>platforms</th></tr></thead><tbody><tr><td>SLTR</td><td><table border="1"><tr><th>nplatforms</th><td>4</td></tr><tr><th>files</th><td><table border="1"><tr><th>nfiles</th><td>120</td></tr><tr><th>feature(s)</th><td><table border="1"><thead><tr><th>code</th><th>nplatforms</th><th>nfiles</th><th>sources(s)</th></tr></thead><tbody><tr><td>RV</td><td>3</td><td>90</td><td><table border="1"><thead><tr><th>code</th><th>nplatforms</th><th>nfiles</th></tr></thead><tbody><tr><td>HF</td><td>3</td><td>90</td></tr></tbody></table></td></tr><tr><td>TV</td><td>1</td><td>30</td><td><table border="1"><thead><tr><th>code</th><th>nplatforms</th><th>nfiles</th></tr></thead><tbody><tr><td>HF</td><td>1</td><td>30</td></tr></tbody></table></td></tr></tbody></table></td></tr></table></td></tr></table></td></tr><tr><td>SSJT</td><td><table border="1"><tr><th>nplatforms</th><td>1</td></tr><tr><th>files</th><td><table border="1"><tr><th>nfiles</th><td>15</td></tr><tr><th>feature(s)</th><td><table border="1"><thead><tr><th>code</th><th>nplatforms</th><th>nfiles</th><th>sources(s)</th></tr></thead><tbody><tr><td>TS</td><td>1</td><td>15</td><td><table border="1"><thead><tr><th>code</th><th>nplatforms</th><th>nfiles</th></tr></thead><tbody><tr><td>TS</td><td>1</td><td>15</td></tr></tbody></table></td></tr></tbody></table></td></tr></table></td></tr></table></td></tr><tr><td>SCDR</td><td><table border="1"><tr><th>nplatforms</th><td>4</td></tr><tr><th>files</th><td><table border="1"><tr><th>nfiles</th><td>120</td></tr><tr><th>feature(s)</th><td><table border="1"><thead><tr><th>code</th><th>nplatforms</th><th>nfiles</th><th>sources(s)</th></tr></thead><tbody><tr><td>RV</td><td>3</td><td>90</td><td><table border="1"><thead><tr><th>code</th><th>nplatforms</th><th>nfiles</th></tr></thead><tbody><tr><td>HF</td><td>3</td><td>90</td></tr></tbody></table></td></tr><tr><td>TV</td><td>1</td><td>30</td><td><table border="1"><thead><tr><th>code</th><th>nplatforms</th><th>nfiles</th></tr></thead><tbody><tr><td>HF</td><td>1</td><td>30</td></tr></tbody></table></td></tr></tbody></table></td></tr></table></td></tr></table></td></tr><tr><td>VAVH</td><td><table border="1"><tr><th>nplatforms</th><td>10</td></tr><tr><th>files</th><td><table border="1"><tr><th>nfiles</th><td>306</td></tr><tr><th>feature(s)</th><td><table border="1"><thead><tr><th>code</th><th>nplatforms</th><th>nfiles</th><th>sources(s)</th></tr></thead><tbody><tr><td>TS</td><td>10</td><td>306</td><td><table border="1"><thead><tr><th>code</th><th>nplatforms</th><th>nfiles</th></tr></thead><tbody><tr><td>MO</td><td>10</td><td>306</td></tr></tbody></table></td></tr></tbody></table></td></tr></table></td></tr></table></td></tr><tr><td>PSAL</td><td><table border="1"><tr><th>nplatforms</th><td>107</td></tr><tr><th>files</th><td><table border="1"><tr><th>nfiles</th><td>625</td></tr><tr><th>feature(s)</th><td><table border="1"><thead><tr><th>code</th><th>nplatforms</th><th>nfiles</th><th>sources(s)</th></tr></thead><tbody><tr><td>PR</td><td>105</td><td>593</td><td><table border="1"><thead><tr><th>code</th><th>nplatforms</th><th>nfiles</th></tr></thead><tbody><tr><td>CT</td><td>6</td><td>149</td></tr><tr><td>GL</td><td>2</td><td>50</td></tr><tr><td>PF</td><td>94</td><td>330</td></tr><tr><td>SM</td><td>3</td><td>64</td></tr></tbody></table></td></tr><tr><td>TS</td><td>2</td><td>32</td><td><table border="1"><thead><tr><th>code</th><th>nplatforms</th><th>nfiles</th></tr></thead><tbody><tr><td>DB</td><td>1</td><td>16</td></tr><tr><td>TS</td><td>1</td><td>16</td></tr></tbody></table></td></tr></tbody></table></td></tr></table></td></tr></table></td></tr><tr><td>EWCS</td><td><table border="1"><tr><th>nplatforms</th><td>1</td></tr><tr><th>files</th><td><table border="1"><tr><th>nfiles</th><td>30</td></tr><tr><th>feature(s)</th><td><table border="1"><thead><tr><th>code</th><th>nplatforms</th><th>nfiles</th><th>sources(s)</th></tr></thead><tbody><tr><td>TV</td><td>1</td><td>30</td><td>< ...

# %% [markdown]
# Too much info? Choose one! `Run the next cells`...

# %%
code = 'TEMP'

# %%
selection = [param for param in parameters if param['code'] == code]
IPython.display.HTML(json2html.convert(selection))
# Out:
# <table border="1"><thead><tr><th>code</th><th>platforms</th></tr></thead><tbody><tr><td>TEMP</td><td><table border="1"><tr><th>nplatforms</th><td>261</td></tr><tr><th>files</th><td><table border="1"><tr><th>nfiles</th><td>4702</td></tr><tr><th>feature(s)</th><td><table border="1"><thead><tr><th>code</th><th>nplatforms</th><th>nfiles</th><th>sources(s)</th></tr></thead><tbody><tr><td>PR</td><td>105</td><td>593</td><td><table border="1"><thead><tr><th>code</th><th>nplatforms</th><th>nfiles</th></tr></thead><tbody><tr><td>CT</td><td>6</td><td>149</td></tr><tr><td>GL</td><td>2</td><td>50</td></tr><tr><td>PF</td><td>94</td><td>330</td></tr><tr><td>SM</td><td>3</td><td>64</td></tr></tbody></table></td></tr><tr><td>TS</td><td>156</td><td>4109</td><td><table border="1"><thead><tr><th>code</th><th>nplatforms</th><th>nfiles</th></tr></thead><tbody><tr><td>MO</td><td>5</td><td>154</td></tr><tr><td>DB</td><td>150</td><td>3939</td></tr><tr><td>TS</td><td>1</td><td>16</td></tr></tbody></table></td></tr></tbody></table></td></tr></table></td></tr></table></td></tr></tbody></table>

# %% [markdown]
# #### 3.3.5. Providers

# %% [markdown]
# Any Situ NRT products/datasets collections are composed by the files reported by a network of platforms located in the area. It is interesting always to know who are procuring these platforms and to aknowledge them!

# %% [markdown]
# Let's `run the next cell` to know how many *known* providers are contributting to this product/dataset collection with files:

# %%
providers_list = list(set(sum([str(provider).split(' ') for provider in targeted_collection_info['institution_edmo_code'].str.strip().tolist() if str(provider).isdigit()],[])))
providers_list
# Out:
# ['1850',
#  '4614',
#  '396',
#  '1054',
#  '1979',
#  '100',
#  '4766',
#  '1212',
#  '17',
#  '2126',
#  '3839',
#  '3899',
#  '543',
#  '1190',
#  '3844',
#  '544',
#  '1463',
#  '1725',
#  '29',
#  '195',
#  '1351',
#  '540']

# %% [markdown]
# Not clear at all, right? These numbers are identifiers provided by [SeaDatanet](https://edmo.seadatanet.org/search). <br>
# Just check who is who by using SeaDataNet services: `run the next cell`!

# %%
code = '540' #change it by any other!
IPython.display.IFrame('https://edmo.seadatanet.org/report/'+code, width='100%', height=350)
# Out:
#         <iframe
#             width="100%"
#             height="350"
#             src="https://edmo.seadatanet.org/report/540"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# How much are they contributting to the product/datasetcollection?<br>`Run the next cells` to discover it!:

# %%
targeted_collection_info['institution_edmo_code'] = ' ' +targeted_collection_info['institution_edmo_code'].str.strip()+ ' '

# %%
providers = [{
    'code':code,
    'platforms':{
        'nplatforms': len(targeted_collection_info[targeted_collection_info['institution_edmo_code'].str.contains(' '+code+' ', na=False)].groupby('platform_code').groups.keys()),
        'files':{'nfiles': len(targeted_collection_info[targeted_collection_info['institution_edmo_code'].str.contains(' '+code+' ', na=False)]), 
        'feature(s)': [{'code': ftype, 'nplatforms':len(targeted_collection_info[targeted_collection_info['institution_edmo_code'].str.contains(' '+code+' ', na=False)].groupby('file_type').get_group(ftype).groupby('platform_code')), 'nfiles':len(targeted_collection_info[targeted_collection_info['institution_edmo_code'].str.contains(' '+code+' ', na=False)].groupby('file_type').get_group(ftype)),'sources(s)': [{'code': dtype, 'nplatforms': len(targeted_collection_info[targeted_collection_info['institution_edmo_code'].str.contains(' '+code+' ', na=False)].groupby('file_type').get_group(ftype).groupby('data_type').get_group(dtype).groupby('platform_code')), 'nfiles': len(targeted_collection_info[targeted_collection_info['institution_edmo_code'].str.contains(' '+code+' ', na=False)].groupby('file_type').get_group(ftype).groupby('data_type').get_group(dtype))} for dtype in targeted_collection_info[targeted_collection_info['institution_edmo_code'].str.contains(' '+code+' ', na=False)][targeted_collection_info['file_type']==ftype]['data_type'].unique().tolist()]} for ftype in targeted_collection_info[targeted_collection_info['institution_edmo_code'].str.contains(' '+code+' ', na=False)]['file_type'].unique().tolist()]}
    }
} for code in providers_list]

# %%
IPython.display.HTML(json2html.convert(providers))
# Out:
# <table border="1"><thead><tr><th>code</th><th>platforms</th></tr></thead><tbody><tr><td>1850</td><td><table border="1"><tr><th>nplatforms</th><td>12</td></tr><tr><th>files</th><td><table border="1"><tr><th>nfiles</th><td>34</td></tr><tr><th>feature(s)</th><td><table border="1"><thead><tr><th>code</th><th>nplatforms</th><th>nfiles</th><th>sources(s)</th></tr></thead><tbody><tr><td>PR</td><td>12</td><td>34</td><td><table border="1"><thead><tr><th>code</th><th>nplatforms</th><th>nfiles</th></tr></thead><tbody><tr><td>PF</td><td>12</td><td>34</td></tr></tbody></table></td></tr></tbody></table></td></tr></table></td></tr></table></td></tr><tr><td>4614</td><td><table border="1"><tr><th>nplatforms</th><td>4</td></tr><tr><th>files</th><td><table border="1"><tr><th>nfiles</th><td>12</td></tr><tr><th>feature(s)</th><td><table border="1"><thead><tr><th>code</th><th>nplatforms</th><th>nfiles</th><th>sources(s)</th></tr></thead><tbody><tr><td>PR</td><td>4</td><td>12</td><td><table border="1"><thead><tr><th>code</th><th>nplatforms</th><th>nfiles</th></tr></thead><tbody><tr><td>PF</td><td>4</td><td>12</td></tr></tbody></table></td></tr></tbody></table></td></tr></table></td></tr></table></td></tr><tr><td>396</td><td><table border="1"><tr><th>nplatforms</th><td>3</td></tr><tr><th>files</th><td><table border="1"><tr><th>nfiles</th><td>9</td></tr><tr><th>feature(s)</th><td><table border="1"><thead><tr><th>code</th><th>nplatforms</th><th>nfiles</th><th>sources(s)</th></tr></thead><tbody><tr><td>PR</td><td>3</td><td>9</td><td><table border="1"><thead><tr><th>code</th><th>nplatforms</th><th>nfiles</th></tr></thead><tbody><tr><td>PF</td><td>3</td><td>9</td></tr></tbody></table></td></tr></tbody></table></td></tr></table></td></tr></table></td></tr><tr><td>1054</td><td><table border="1"><tr><th>nplatforms</th><td>13</td></tr><tr><th>files</th><td><table border="1"><tr><th>nfiles</th><td>34</td></tr><tr><th>feature(s)</th><td><table border="1"><thead><tr><th>code</th><th>nplatforms</th><th>nfiles</th><th>sources(s)</th></tr></thead><tbody><tr><td>PR</td><td>13</td><td>34</td><td><table border="1"><thead><tr><th>code</th><th>nplatforms</th><th>nfiles</th></tr></thead><tbody><tr><td>PF</td><td>13</td><td>34</td></tr></tbody></table></td></tr></tbody></table></td></tr></table></td></tr></table></td></tr><tr><td>1979</td><td><table border="1"><tr><th>nplatforms</th><td>3</td></tr><tr><th>files</th><td><table border="1"><tr><th>nfiles</th><td>8</td></tr><tr><th>feature(s)</th><td><table border="1"><thead><tr><th>code</th><th>nplatforms</th><th>nfiles</th><th>sources(s)</th></tr></thead><tbody><tr><td>PR</td><td>3</td><td>8</td><td><table border="1"><thead><tr><th>code</th><th>nplatforms</th><th>nfiles</th></tr></thead><tbody><tr><td>PF</td><td>3</td><td>8</td></tr></tbody></table></td></tr></tbody></table></td></tr></table></td></tr></table></td></tr><tr><td>100</td><td><table border="1"><tr><th>nplatforms</th><td>1</td></tr><tr><th>files</th><td><table border="1"><tr><th>nfiles</th><td>16</td></tr><tr><th>feature(s)</th><td><table border="1"><thead><tr><th>code</th><th>nplatforms</th><th>nfiles</th><th>sources(s)</th></tr></thead><tbody><tr><td>TS</td><td>1</td><td>16</td><td><table border="1"><thead><tr><th>code</th><th>nplatforms</th><th>nfiles</th></tr></thead><tbody><tr><td>TS</td><td>1</td><td>16</td></tr></tbody></table></td></tr></tbody></table></td></tr></table></td></tr></table></td></tr><tr><td>4766</td><td><table border="1"><tr><th>nplatforms</th><td>2</td></tr><tr><th>files</th><td><table border="1"><tr><th>nfiles</th><td>61</td></tr><tr><th>feature(s)</th><td><table border="1"><thead><tr><th>code</th><th>nplatforms</th><th>nfiles</th><th>sources(s)</th></tr></thead><tbody><tr><td>TS</td><td>2</td><td>61</td><td><table border="1"><thead><tr><th>code</th><th>nplatforms</th><th>nfiles</th></tr></thead><tbody><tr><td>MO</td><td>2</td><td>61</td></tr></tbody></table></td></tr></tbody></table></td></tr></table></td></tr></table></td></tr><tr><td>1 ...

# %% [markdown]
# Too much info? Choose one! `Run the next cells`...

# %%
code = '540'

# %%
selection = [provider for provider in providers if provider['code'] == code]
IPython.display.HTML(json2html.convert(selection))
# Out:
# <table border="1"><thead><tr><th>code</th><th>platforms</th></tr></thead><tbody><tr><td>540</td><td><table border="1"><tr><th>nplatforms</th><td>8</td></tr><tr><th>files</th><td><table border="1"><tr><th>nfiles</th><td>31</td></tr><tr><th>feature(s)</th><td><table border="1"><thead><tr><th>code</th><th>nplatforms</th><th>nfiles</th><th>sources(s)</th></tr></thead><tbody><tr><td>PR</td><td>8</td><td>31</td><td><table border="1"><thead><tr><th>code</th><th>nplatforms</th><th>nfiles</th></tr></thead><tbody><tr><td>PF</td><td>8</td><td>31</td></tr></tbody></table></td></tr></tbody></table></td></tr></table></td></tr></table></td></tr></tbody></table>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b style="margin-right: 2em">IMPORTANT</b>
#
# ***
# **Are you a provider?**
# If you have one or more platforms (or know about some) producing data in the area and your institution edmo_code does not appear on the list please **contact us** by emailing the corresponding Regional CMEMS In Situ TAC Service Desk [here](http://www.marineinsitu.eu/submit-data/) **or let the speaker know**! <br>**We are interested in integrating your data!** :)

# %% [markdown]
# ---
#
# # 4. Wrap-up
# [Go back to the "Table of Contents"](#Table-of-Contents)
#
# So far you should already know what to expect about this product/dataset/collection: platform network, file types, source types, parameters and providers.<br> `If you don't please ask us! It is the moment!`
# <br>In the next tutorial we will see how to retrieve the files coming from a certain platform, source, provider, matching a certain type of file or/and containing certain parameter. Ready? Let's go!

# %% [markdown]
# ---
#
# # 5. Next tutorial
# [Go back to the "Table of Contents"](#Table-of-Contents)
#
# _Click on the hyperlink below to continue the training_
#
# [**13-02-NearRealTtime-product-subsetting-download.ipynb**](13-02-NearRealTtime-product-subsetting-download.ipynb)
